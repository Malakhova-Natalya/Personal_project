# %% [markdown]
# # 📖 Анализ моего личного читательского дневника с 2018 по 2023 годы 🕰️

# %% [markdown]
# ![book_stars.jpg](attachment:book_stars.jpg)

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Открытие-данных" data-toc-modified-id="Открытие-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Открытие данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-и-подготовка-данных" data-toc-modified-id="Предобработка-и-подготовка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка и подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Общие-сведения" data-toc-modified-id="Общие-сведения-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Общие сведения</a></span></li><li><span><a href="#Эпохи,-жанры,-страны" data-toc-modified-id="Эпохи,-жанры,-страны-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Эпохи, жанры, страны</a></span></li><li><span><a href="#Гендерное-распределение" data-toc-modified-id="Гендерное-распределение-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Гендерное распределение</a></span></li><li><span><a href="#Возраст-авторов" data-toc-modified-id="Возраст-авторов-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Возраст авторов</a></span></li><li><span><a href="#Распределение-по-темам" data-toc-modified-id="Распределение-по-темам-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Распределение по темам</a></span></li><li><span><a href="#Литературные-премии" data-toc-modified-id="Литературные-премии-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Литературные премии</a></span></li><li><span><a href="#Самый-читаемый-/-многословный-автор" data-toc-modified-id="Самый-читаемый-/-многословный-автор-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Самый читаемый / многословный автор</a></span></li><li><span><a href="#Художественная-литература-/-нонфикшн" data-toc-modified-id="Художественная-литература-/-нонфикшн-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Художественная литература / нонфикшн</a></span></li><li><span><a href="#Формат-и-издательства" data-toc-modified-id="Формат-и-издательства-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Формат и издательства</a></span></li><li><span><a href="#Как-менялся-мой-читательский-опыт" data-toc-modified-id="Как-менялся-мой-читательский-опыт-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Как менялся мой читательский опыт</a></span></li><li><span><a href="#Интенсивность-чтения-по-годам" data-toc-modified-id="Интенсивность-чтения-по-годам-4.11"><span class="toc-item-num">4.11&nbsp;&nbsp;</span>Интенсивность чтения по годам</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# В данном исследовании проводится **анализ моего личного читательского дневника с 2018 по 2023 год**⌛.
#
# 📙 **"Ты - это то, что ты читаешь"** - проверим, так ли это, и отражает ли читательский дневник изменения в жизни того, кто его ведёт.
#
# 📓 **Чтение - это моё хобби, и в разные годы жизни это проявлялось по-разному**: например, когда мне было около 15 лет, я любила Эдгара По, Лавкрафта, Энн Райс. В период 17-19 лет я ринулась осваивать различные монументальные произведения, такие как, например, "Иосиф и его братья" Томаса Манна или "Игра в бисер" Германа Гессе. Позднее я открыла для себя антиутопии, полюбила Ремарка, зачитывалась Достоевским. В какой-то момент я стала записывать полюбившиеся цитаты из Ремарка, впоследствии это преобразовалось в ведение настоящего читательского дневника. Сам Ремарк, по иронии, в него не попал, но - заложил основу хорошего дела.
#
# 📒 **Сегодня мне 32 года**, и последний период моего увлечения литературой связан с периодом декрета. В это время я заново открыла для себя чтение (после периода бессонных ночей и вечных синяков под глазами), и с жадностью стала читать всё, что попадалось мне под руку. Поэтому в начале 2021-го мой читательский дневник выглядел по-настоящему сумбурным. Затем я стала постепенно смещаться в сторону мировой классики (спасибо за это Евгению и Николаю Жариновым). Но далее в 2022-м году случилось то, что случилось. Мир перевернулся, и мой читательский дневник - тоже.  Теперь я молодой аналитик данных, и новые знания помогут мне взглянуть на опыт своего чтения под новым углом.
#
# ✒️ **Основная задача** - выявить основные черты моего литературного дневника и **ответить на вопросы**:
#
# 📖 сколько книг прочитано? а сколько страниц? за какое время?
#
# 📖 какие эпохи, жанры, страны преобладают?
#
# 📖 кого я читала больше: женщин или мужчин? Отличается ли преобладание количества книг от объёма в страницах?
#
# 📖 сколько авторам было лет на момент написания своих произведений? я больше читала молодых или уже умудрённых жизнью авторов? Каков средний возраст авторов на момент написания прочитанных мною книг? Отличается ли такой средний возраст в разрезе пола?
#
# 📖 если рассмотреть основные интересующие темы (худож.литература, научно-популярная/просветительская и т.д.) - как они отличаются друг от друга? Сколько в каждой теме авторов, книг, страниц, стран, каков возраст и пол авторов?
#
# 📖 какой процент авторов - лауреаты самых известных литературных премий? Кто эти авторы?
#
# 📖 какой автор - лидер по количеству прочитанных книг? а по количеству страниц - это тот же автор?
#
# 📖 какого направления больше: художественной литературы или нон-фикшн? Как это выглядит в количестве книг и в объёме страниц?
#
# 📖 в каком формате я читала больше: в бумажном или электронном? Какие издательства преобладают?
#
# 📖 на какие темы я обращала внимание и как эти темы сменяли друг друга в разные годы?
#
# 📖 как ещё изменялся мой читательский опыт с течением времени?
#
#
# **Описание данных**:
#
# - в исследовании используются данные моего личного читательского дневника за последние неполные 6 лет (имя автора, название произведения, дата прочтения книги)
#
# - годы жизни авторов, страна, годы вручения литературных премий (Нобелевская, Пулитцеровская, Букеровская) - взяты из открытых источников (в основном из Википедии - свободной энциклопедии*)
#
# - название издания, количество страниц - взяты из самих книг, которые я прочитала
#
#
# *РКН: сайт нарушает закон РФ

# %% [markdown]
# ## Открытие данных

# %% [markdown]
# Импортируем необходимые библиотеки:

# %%
import pandas as pd
import os

from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

import datetime as dt
from datetime import datetime, date, timedelta

import missingno as msno

# %% [markdown]
# Открываем файл:

# %%
if os.path.exists('/datasets/my_reading_diary.csv'):
    df = pd.read_csv('/datasets/my_reading_diary.csv', sep=';')
else:
    df = pd.read_csv('/C:/datasets/my_reading_diary.csv', sep=';')

# %% [markdown]
# Для ознакомления и проверки данных будем использовать собственную функцию:

# %%
def my_check_function (dataset):
    '''Функция для ознакомления и проверки даных'''
    print('Размер датасета (количество строк, столбцов):')
    print(dataset.shape)
    print('Как выглядят случайные 5 строк:')
    display(dataset.sample(5, random_state=42))
    print()
    print('Общая информация о данных, наименования столбцов, типы данных:')
    print(dataset.info())
    print()
    print('Есть ли пропуски, сколько их:')
    print(dataset.isna().sum())
    print('Доля пропущенных значений:')
    print(dataset.isna().mean())
    print()
    print('Есть ли явные дубликаты, сколько их:')
    print(dataset.duplicated().sum())
    print('Доля явных дубликатов:')
    print(dataset.duplicated().mean())
    print()
    print('Подробное описание данных:')
    display(dataset.describe())

# %%
my_check_function(df)
# Out:
# Размер датасета (количество строк, столбцов):
# (108, 19)
# Как выглядят случайные 5 строк:
#         author_full_name author_surname  Nobel_prize  Pulitzer_prize  \
# 77          Э.О.Чаровици       Чаровици          NaN             NaN
# 10            Джон Фаулз          Фаулз          NaN             NaN
# 4        Харуки Мураками       Мураками          NaN             NaN
# 83  Людмила Петрановская   Петрановская          NaN             NaN
# 62           Януш Корчак         Корчак          NaN             NaN
#
#     Man_Booker_prize author_gender      direction author_date_of_birth  \
# 77               NaN          male            NaN           11.05.1964
# 10               NaN          male  постмодернизм           31.03.1926
# 4                NaN          male  постмодернизм           12.01.1949
# 83               NaN        female            NaN           20.04.1967
# 62               NaN          male            NaN           22.07.1878
#
# ...

# %% [markdown]
# У нас нет дубликатов, но есть достаточно много разных пропусков.
#
# Визуализируем их расположение:

# %%
msno.matrix(df, labels=True);

# %% [markdown]
# В данном случае пропуски заполнять не нужно:
#
# - **Nobel_prize, Pulitzer_prize, Man_Booker_prize** - это нормально, что у нас очень мало сведений о Нобелевской и прочих премиях - так и есть в действительности, мало авторов имеют эти премии. Значениями-глушилками пока заполнять не вижу смысла
#
#
# - **direction** ("направление" или другими словами стиль писателя, например, реализм или постмодернизм) - эти сведения взяты со страниц Википедии*, и эта информация указана далеко не для всех авторов
#
#
# - **author_date_of_birth** (дата рождения автора) - иногда такие сведения неизвестны, особенно это касается молодых современных авторов (возможно, они хотят сохранить приватность и не афишировать личные данные на широкую публику)
#
#
# - **author_date_of_death** (дата смерти автора) - пропуски связаны с тем, что многие авторы являются нашими современниками. Нет ничего плохого в таких пропусках!:-)
#
#
# - **year_writing** (год написания) - невозможно указать для некоторых книг, в частности, для народных сказок. Так что нет смысла заполнять эти естественные пропуски
#
#
# *РКН: сайт нарушает закон РФ

# %% [markdown]
# ### Вывод

# %% [markdown]
# У нас есть небольшой объём данных: 108 строк, 19 столбцов.
#
# Данные пригодны для анализа. Есть пропуски (которые нет смысла заполнять).
#
# Для дальнейшей работы необходимо преобразовать формат данных в столбцах:
#
# - author_date_of_birth
# - author_date_of_death
# - date_reading

# %% [markdown]
# ## Предобработка и подготовка данных

# %% [markdown]
# Приведём данные о времени в нужный формат:

# %%
df['author_date_of_birth'] = pd.to_datetime(df['author_date_of_birth'], errors = 'coerce')
df['author_date_of_death'] = pd.to_datetime(df['author_date_of_death'], errors = 'coerce')
df['date_reading'] = pd.to_datetime(df['date_reading'])

# %% [markdown]
# Вычислим возраст, в котором авторы создали свои произведения:

# %%
df['age_writing'] = df['year_writing'] - df['author_date_of_birth'].dt.year

# %% [markdown]
# Выделим год прочтения:

# %%
df['year_reading'] = df['date_reading'].dt.year

# %% [markdown]
# Выделим век написания книги:

# %%
def find_century (year_writing):
    """
    Возвращает век по значению года написания произведения
    
    """
    if year_writing <= 1400:
        return '14-й век'
    elif year_writing <= 1500:
        return '15-й век'
    elif year_writing <= 1600:
        return '16-й век'
    elif year_writing <= 1700:
        return '17-й век'
    elif year_writing <= 1800:
        return '18-й век'
    elif year_writing <= 1900:
        return '19-й век'
    elif year_writing <= 2000:
        return '20-й век'
    elif year_writing <= 2100:
        return '21-й век'
    else:
        return 'неизвестно'

# %%
df['century_writing'] = df['year_writing'].apply(find_century)

# %% [markdown]
# Выделим категории возрастов авторов на момент написания произведений:

# %%
def find_age_category (age_writing):
    """
    Возвращает категорию возраста по значению возраста автора на момент написания произведения
    
    """
    if age_writing < 30:
        return 'до 30 лет'
    elif 30 <= age_writing < 40:
        return 'от 30 до 40 лет'
    elif 40 <= age_writing < 50:
        return 'от 40 до 50 лет'
    elif 50 <= age_writing < 60:
        return 'от 50 до 60 лет'
    elif 60 <= age_writing < 70:
        return 'от 60 до 70 лет'
    elif age_writing >= 70:
        return 'от 70 лет и старше'

# %%
df['age_writing_category'] = df['age_writing'].apply(find_age_category)

# %% [markdown]
# Зададим более обобщённое распределение по странам:

# %%
def find_country_type (author_country):
    """
    Возвращает принадлежность автора к стране по более обобщённым параметрам 
    (например, Франция, Испания и прочие европейские страны объединены в одно наименование - Европа)
    
    """
    if author_country == 'США':
        return 'США'
    elif author_country == 'Россия' or author_country == 'СССР':
        return 'Россия'
    elif author_country == 'Великобритания':
        return 'Великобритания'
    elif author_country == 'Япония':
        return 'Япония'
    elif author_country in ['Испания', 'Франция', 'Австрия', 'Польша', 'Румыния', 'Германская империя, Швейцария', 
                            'Флорентийская республика', 'Священная Римская империя, Германский союз']:
        return 'Европа'
    elif author_country in ['Турция', 'Беларусь', 'Колумбия', 'Армения', 'Российская империя, США', 'Израиль, США']:
        return 'другое'

# %%
df['author_country_type'] = df['author_country'].apply(find_country_type)

# %% [markdown]
# Вычислим количество дней от прочтения одной книги до прочтения другой:

# %%
df['days_reading_cnt'] = df['date_reading'] - df['date_reading'].shift(1)

# %%
df['days_reading_cnt'] = df['days_reading_cnt'].astype('str').str.strip('days') 
df['days_reading_cnt'] = pd.to_numeric(df['days_reading_cnt'], errors='coerce')

# %% [markdown]
# Вычислим интенсивность чтения (количество прочитанных страниц в день):

# %%
df['speed_reading'] = df['page_count'] / df['days_reading_cnt']

# %% [markdown]
# Зададим цветовое решение проекта:

# %%
color = 'lightsteelblue'
palette_gender = ['lightsteelblue', 'seagreen', 'darkgray']
palette_theme = ['lightsteelblue', 'seagreen', 'lightcoral', 'y', 'mediumslateblue','indigo']

# %% [markdown]
# ### Вывод

# %% [markdown]
# Данные готовы к исследованию.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Общие сведения
#
# 📖 сколько книг прочитано? а сколько страниц? за какое время?

# %%
fig = plt.figure(constrained_layout=True, figsize=(18, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Общие сведения', fontweight='bold', y=1.05)

spec = gridspec.GridSpec(ncols=3, nrows=3, figure=fig)
data = df.groupby('year_reading', as_index=False).agg({'book_title':'count', 'page_count':'sum'})

ax1 = fig.add_subplot(spec[0, :-2])
plt.title('Количество прочитанных книг', fontweight='bold')
sns.barplot(y=df.agg({'book_title':'count'}), color=color)
ax1.bar_label(ax1.containers[0], label_type='center', color='black')
ax1.set(yticklabels=[])  

ax2 = fig.add_subplot(spec[0, -2:-1])
plt.title('Количество прочитанных страниц', fontweight='bold')
sns.barplot(y=df.agg({'page_count':'sum'}), color=color)
ax2.bar_label(ax2.containers[0], label_type='center', color='black')
ax2.set(yticklabels=[])  

ax3 = fig.add_subplot(spec[0, -1])
plt.title('Количество лет', fontweight='bold')
sns.barplot(y=df.agg({'year_reading':'nunique'}), color=color)
ax3.bar_label(ax3.containers[0], label_type='center', color='black')
ax3.set(yticklabels=[])  

ax4 = fig.add_subplot(spec[1:, :-1])
birthday = pd.to_datetime('2020-03-26', format='%Y-%m-%d')
plt.title('Распределение во времени', fontweight='bold')
sns.scatterplot(data=df, x='date_reading', y='page_count', color=color)
plt.axvline(x=birthday, color='grey', linestyle='--', label='рождение дочери')
plt.legend(loc='upper right')
plt.xlabel('')
plt.ylabel('количество страниц')

ax5 = fig.add_subplot(spec[1, -1])
plt.title('Количество книг по годам', fontweight='bold')
sns.barplot(data=data, x='year_reading', y='book_title', color=color)
plt.xlabel('')
plt.ylabel('')

ax6 = fig.add_subplot(spec[2, -1])
plt.title('Количество страниц по годам', fontweight='bold')
sns.barplot(data=data, x='year_reading', y='page_count', color=color)
plt.xlabel('')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
#
# - прочитано 108 книг
# - 40900 страниц
# - за 6 уникальных лет (с 2018 по 2023)
#
# Дополнительно мы видим, что распределение по времени неравномерно:
# - например, 2020-й год очень "просел" по объёму чтения, зато 2021-й год резко вырвался вперёд.
#
# - пунктирная линия подсказывает основную причину изменения читательских привычек в 2020-м году - появление новорожденной дочери.

# %% [markdown]
# ### Эпохи, жанры, страны
#
# 📖 какие эпохи, жанры, страны преобладают?

# %%
fig = plt.figure(constrained_layout=True, figsize=(18, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Распределение книг', fontweight='bold', y=1.05)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax0 = fig.add_subplot(spec[0, :-1])
sns.barplot(data=(df.groupby('century_writing', as_index=False).agg({'book_title':'count'})
                  .sort_values(by='book_title', ascending=False)), 
            x='book_title', y='century_writing', color=color)
plt.title('Век', fontweight='bold')
plt.xlabel('количество книг')
plt.ylabel('')

ax1 = fig.add_subplot(spec[:, -1])
sns.barplot(data=(df.groupby('author_country', as_index=False).agg({'book_title':'count'})
            .sort_values(by='book_title', ascending=False)),
            x='book_title', y='author_country', color=color)
plt.title('Страна', fontweight='bold')
plt.xlabel('количество книг')
plt.ylabel('')

ax2 = fig.add_subplot(spec[1, :-1])
sns.barplot(data=(df.groupby('genre', as_index=False).agg({'book_title':'count'})
            .sort_values(by='book_title', ascending=False)),
            x='book_title', y='genre', color=color)
plt.title('Жанр', fontweight='bold')
plt.xlabel('количество книг')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
#
# - из эпох преобладают 20 и 21 века
#
#
# - среди жанров выделяются роман и нон-фикшн литература
#
#
# - среди множества стран на первых местах по количеству прочитанных книг США, Россия, Великобритания, Япония

# %% [markdown]
# ### Гендерное распределение
#
# 📖 кого я читала больше: женщин или мужчин? Отличается ли преобладание количества книг от объёма в страницах?

# %%
plt.figure(figsize=(18, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Гендерное распределение', fontweight='bold')

data = (df.groupby('author_gender', as_index=False).agg({'book_title':'count', 'page_count':'sum'})
        .sort_values(by='book_title', ascending=False))
data['avg_cnt_page'] = data['page_count'] / data['book_title']

ax1 = plt.subplot(1, 3, 1)
sns.barplot(data=data, x='author_gender', y='book_title', color=color)
plt.title('Суммарное количество \n книг', fontweight='bold')
plt.xlabel('')
plt.ylabel('')

ax2 = plt.subplot(1, 3, 2)
sns.barplot(data=data, x='author_gender', y='page_count', color=color)
plt.title('Суммарное количество \n страниц', fontweight='bold')
plt.xlabel('')
plt.ylabel('')

ax3 = plt.subplot(1, 3, 3)
sns.barplot(data=data, x='author_gender', y='avg_cnt_page', color=color)
plt.title('Среднее количество страниц \n на одну книгу', fontweight='bold')
plt.xlabel('')
plt.ylabel('')

plt.tight_layout()
plt.show();

# %% [markdown]
# **Вывод**:
#
# - по суммарному количеству книг и объёму страниц значительно преобладают авторы-мужчины (отличие более чем в 3 раза)
#
#
# - однако в среднем авторы-женщины чуть более многословны: в то время как в среднем на одну книгу автора-мужчины приходится около 370 страниц, на книгу автора-женщины приходится в среднем 410 страниц
#
#
# - кроме того, есть небольшое количество книг, написанных группой авторов

# %% [markdown]
# ### Возраст авторов
#
# 📖 сколько авторам было лет на момент написания своих произведений? я больше читала молодых или уже умудрённых жизнью авторов? Каков средний возраст авторов на момент написания прочитанных мною книг? Отличается ли такой средний возраст в разрезе пола?

# %%
fig = plt.figure(constrained_layout=True, figsize=(18, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Распределение по возрасту авторов на момент написания произведения', fontweight='bold', y=1.05)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax0 = fig.add_subplot(spec[0, :-1])
plt.title('Возраст автора и количество страниц', fontweight='bold')
sns.scatterplot(data=df, x='age_writing', y='page_count', color=color)
plt.xlabel('возраст автора')
plt.ylabel('кол-во страниц')

ax1 = fig.add_subplot(spec[0, -1])
plt.title('Средний возраст авторов', fontweight='bold')
sns.barplot(y=df.agg({'age_writing':'mean'}), color=color)
plt.ylabel('возраст автора')

ax2 = fig.add_subplot(spec[1, :-1])
plt.title('Возраст автора и количество книг', fontweight='bold')
sns.barplot(data=df.groupby('age_writing_category', as_index=False).agg({'book_title':'count'}),
            x='age_writing_category', y='book_title', color=color)
plt.xlabel('возраст автора')
plt.ylabel('кол-во книг')

ax3 = fig.add_subplot(spec[1, -1])
plt.title('Средний возраст в разрезе пола', fontweight='bold')
sns.barplot(data=df.groupby('author_gender', as_index=False).agg({'age_writing':'mean'}), 
            x='author_gender', y='age_writing', color=color)
plt.axhline(y=df['age_writing'].mean(), color='black', linestyle='--', label='средний возраст')
plt.xlabel('')
plt.ylabel('возраст автора')

plt.show()

# %% [markdown]
# **Вывод**:
#
# - на момент написания произведений авторам было от 19 до 80 лет
#
#
# - нельзя однозначно сказать, авторов какого возраста я читала больше, молодых или умудрённых жизнью: это зависит от того, что именно считать за молодость. Самые многочисленные категории: это авторы в возрасте от 30 до 40 лет, от 40 до 50, от 50 до 60 лет.
#
# - средний возраст авторов на момент написания произведений: около 45 лет
#
#
# - средний возраст отличается в разрезе пола: в среднем авторы-женщины старше - им около 50 лет, в то время как авторам-мужчинам в среднем около 44 лет

# %%
print(f'Книги с наименьшим и наибольшим возрастом авторов на момент написания:')
display(df.query(
'age_writing_category == "до 30 лет"|age_writing_category == "от 60 до 70 лет"|age_writing_category == "от 70 лет и старше"'
)
        [['author_full_name', 'book_title', 'age_writing', 'age_writing_category']]
         .sort_values(by='age_writing'))
# Out:
# Книги с наименьшим и наибольшим возрастом авторов на момент написания:
#                 author_full_name  \
# 9                  Трумен Капоте
# 100  Мана Такахаси, Сёко Адзума
# 70     Фрэнсис Скотт Фицджеральд
# 8                  Трумен Капоте
# 53                 Трумен Капоте
# 14                   Рю Мураками
# 50                 Ася Казанцева
# 55     Фрэнсис Скотт Фицджеральд
# 76                 Филиппа Перри
# 72         Иоганн Вольфганг Гёте
# 35               Харуки Мураками
# 42                Кадзуо Исигуро
# 69                  Масару Ибука
# 66             Юлия Гиппенрейтер
# 81               Евгений Жаринов
# 63               Евгений Жаринов
# 68               Евгений Жаринов
# 97              Александр Аузан
# 95                 Виктор Франкл
# 96              Даниэль Канеман
# 82             Юлия Гиппенрейтер
#
#                                             book_title  age_writing  \
# 9                                         Летний круиз         19.0
# ...

# %% [markdown]
# ### Распределение по темам
#
# 📖 если рассмотреть основные интересующие темы (худож.литература, научно-популярная/просветительская и т.д.) - как они отличаются друг от друга? Сколько в каждой теме авторов, книг, страниц, стран, каков возраст и пол авторов?

# %%
fig = plt.figure(constrained_layout=True, figsize=(18, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Распределение по темам', fontweight='bold', y=1.05)

spec = gridspec.GridSpec(ncols=3, nrows=3, figure=fig)

data=(df.groupby('theme', as_index=False)
      .agg({'author_full_name':'nunique', 'book_title':'count', 'page_count':'sum',
           'author_country':'nunique', 'age_writing':'mean'})
      .sort_values(by='author_full_name', ascending=False))

ax1 = fig.add_subplot(spec[0, :-2])
plt.title('Количество авторов', fontweight='bold')
sns.barplot(data=data, y='theme', x='author_full_name', color=color)
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -2:-1])
plt.title('Количество книг', fontweight='bold')
sns.barplot(data=data, y='theme', x='book_title', color=color)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[0, -1])
plt.title('Количество страниц', fontweight='bold')
sns.barplot(data=data, y='theme', x='page_count', color=color)
plt.xlabel('')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, :-1])
plt.title('Год написания и пол автора', fontweight='bold')
sns.scatterplot(data=df, x='year_writing', y='theme', hue='author_gender', palette=palette_gender)
plt.xlabel('')
plt.ylabel('')

ax5 = fig.add_subplot(spec[1, -1])
plt.title('Количество стран', fontweight='bold')
sns.barplot(data=data, y='theme', x='author_country', color=color)
plt.xlabel('')
plt.ylabel('')

ax6 = fig.add_subplot(spec[2, :-1])
plt.title('Дата прочтения и пол автора', fontweight='bold')
sns.scatterplot(data=df, x='date_reading', y='theme', hue='author_gender', palette=palette_gender)
plt.xlabel('')
plt.ylabel('')

ax7 = fig.add_subplot(spec[2, -1])
plt.title('Средний возраст авторов', fontweight='bold')
sns.barplot(data=data, y='theme', x='age_writing', color=color)
plt.xlabel('')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
#
# - самый распространённый тип литературы - **художественная**. Этой теме принадлежит большинство авторов, книг, наибольшее количество страниц и  стран авторов. Средний возраст авторов около 40 лет, и в основном это мужчины. Большинство книг написаны в 20 веке, но есть и книги из 21-го века, а также, что редкость - книги из других, более ранних, веков
#
#
# - литература, посвящённая **детям и родителям** - вторая по количеству авторов, книг, объёму прочитанных страниц, разнообразию стран происхождения авторов. Средний возраст авторов около 47 лет, и в основном авторы - женщины.
#
#
# - **научпоп/просвещение, обучение IT, психология и английский** - все эти темы менее распространены. Что можно выделить интересного: обучение IT и английский менее разнообразны по странам и имеют более молодой средний возраст авторов. Также для этих двух категорий характерно авторство группы людей. Среди же авторов научно-популярных и психологических книг встречаются женщины.

# %% [markdown]
# ### Литературные премии
#
# 📖 какой процент авторов - лауреаты самых известных литературных премий? Кто эти авторы?

# %%
fig = plt.figure(constrained_layout=True, figsize=(18, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Авторы - лауреаты литературных премий', fontweight='bold', y=1.05)

spec = gridspec.GridSpec(ncols=3, nrows=3, figure=fig)

authors = df[['author_full_name', 'Nobel_prize', 'Pulitzer_prize', 'Man_Booker_prize']].drop_duplicates()
authors_prizes = authors.query('Nobel_prize < 2024 | Pulitzer_prize < 2024 | Man_Booker_prize < 2024')

ax1 = fig.add_subplot(spec[0, :-2])
plt.title('Нобелевская премия: \n процент лауреатов', fontweight='bold')
plt.pie(x=[len(authors), authors_prizes['Nobel_prize'].count()], labels=['без премии', ''],  
         colors=palette_gender, counterclock=False, startangle=90, autopct='%.0f%%', pctdistance=1.15, labeldistance=1.4)

ax2 = fig.add_subplot(spec[0, -2:-1])
plt.title('Пулитцеровская премия: \n процент лауреатов', fontweight='bold')
plt.pie(x=[len(authors), authors_prizes['Pulitzer_prize'].count()], labels=['без премии', ''], 
         colors=palette_gender, counterclock=False, startangle=90, autopct='%.0f%%', pctdistance=1.15, labeldistance=1.4)

ax3 = fig.add_subplot(spec[0, -1])
plt.title('Букеровская премия: \n процент лауреатов', fontweight='bold')
plt.pie(x=[len(authors), authors_prizes['Man_Booker_prize'].count()], labels=['без премии', ''],  
         colors=palette_gender, counterclock=False, startangle=90, autopct='%.0f%%', pctdistance=1.15, labeldistance=1.4)

ax4 = fig.add_subplot(spec[1:, :-2])
plt.title('Нобелевская премия: \n имена лауреатов', fontweight='bold')
sns.barplot(data=authors_prizes.query('Nobel_prize < 2024').sort_values(by='Nobel_prize'), 
            y='author_full_name', x='Nobel_prize', color=color)
ax4.set(xticklabels=[]) 
ax4.bar_label(ax4.containers[0], label_type='center', color='black')
plt.xlabel('год вручения премии')
plt.ylabel('')

ax5 = fig.add_subplot(spec[1:, -2:-1])
plt.title('Пулитцеровская премия: \n имена лауреатов', fontweight='bold')
sns.barplot(data=authors_prizes.query('Pulitzer_prize < 2024').sort_values(by='Pulitzer_prize'), 
            y='author_full_name', x='Pulitzer_prize', color=color)
ax5.set(xticklabels=[]) 
ax5.bar_label(ax5.containers[0], label_type='center', color='black')
plt.xlabel('год вручения премии')
plt.ylabel('')

ax6 = fig.add_subplot(spec[1:, -1])
plt.title('Букеровская премия: \n имена лауреатов', fontweight='bold')
sns.barplot(data=authors_prizes.query('Man_Booker_prize < 2024').sort_values(by='Man_Booker_prize'), 
            y='author_full_name', x='Man_Booker_prize', color=color)
ax6.set(xticklabels=[]) 
ax6.bar_label(ax6.containers[0], label_type='center', color='black')
plt.xlabel('год вручения премии')
plt.ylabel('')


plt.show()

# %% [markdown]
# **Вывод**:
#
# - небольшая доля авторов (не более 10%) - лауреаты известных литературных премий (Нобелевская, Пулитецеровская, Букеровская премии - 10, 6, 4 процента от общего числа авторов и 8, 5 и 3 лауреата соответственно)
#
# некоторые авторы получили несколько премий:
# - Уильям Фолкнер
# - Эрнест Хэмингуэй
# - Джон Стейнбек
# - Уильям Голдинг
# - Кадзуо Исигуро
#
# некоторые - только одну из перечисленных:
# - Герман Гессе
# - Габриэль Гарсиа Маркес
# - Орхан Памук
# - Харпер Ли
# - Барбара Такман
# - Айрис Мёрдок

# %% [markdown]
# ### Самый читаемый / многословный автор
#
# 📖 какой автор - лидер по количеству прочитанных книг? а по количеству страниц - это тот же автор?

# %%
plt.figure(figsize=(18, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Самый читаемый / многословный автор', fontweight='bold')

data = (df.groupby('author_full_name', as_index=False).agg({'book_title':'count', 'page_count':'sum'}))
data['avg_cnt_page'] = data['page_count'] / data['book_title']

ax1 = plt.subplot(1, 3, 1)
sns.barplot(data=data.sort_values(by='book_title', ascending=False).head(10), 
            y='author_full_name', x='book_title', color=color)
plt.title('Суммарное количество \n книг', fontweight='bold')
plt.xlabel('')
plt.ylabel('')

ax2 = plt.subplot(1, 3, 2)
sns.barplot(data=data.sort_values(by='page_count', ascending=False).head(10),
            y='author_full_name', x='page_count', color=color)
plt.title('Суммарное количество \n страниц', fontweight='bold')
plt.xlabel('')
plt.ylabel('')

ax3 = plt.subplot(1, 3, 3)
sns.barplot(data=data.sort_values(by='avg_cnt_page', ascending=False).head(10),
            y='author_full_name', x='avg_cnt_page', color=color)
plt.title('Среднее количество страниц \n на одну книгу', fontweight='bold')
plt.xlabel('')
plt.ylabel('')

plt.tight_layout()
plt.show();

# %% [markdown]
# **Вывод**:
#
# - лидер по количеству прочитанных книг (7 произведений) - Харуки Мураками, он же лидер по суммарному объёму прочитанного - более 3000 прочитанных страниц
#
#
# - в остальном лидеры по количеству книг не всегда совпадают с лидерами по объёму прочитанных страниц
#
#
# - самыми "многословными" оказались Мариам Петросян и Мигель Сервантес. Справедливости ради отметим, что их произведения поделены на несколько томов ("Дом, в котором..." Мариам Петросян - 3 тома, "Дон Кихот" Мигеля Сервантеса - 2 тома), однако многотомники в сумме это одно произведение, поэтому они не разделены на отдельные книги в нашем исследовании.
#
#
# - отдельный интерес представляет набор самых "многословных" авторов - это как раз пример некоторой сумбурности и разноообразия моего чтения в последние годы - здесь и классика мировой литературы (Сервантес "Дон Кихот", Теккерей "Ярмарка тщеславия") и, например, Марта и Уильям Сирс с их книгой о детях ("Ваш малыш от рождения до 2 лет"), и современная художественная литература (Мариам Петросян "Дом, в котором..."), и научно-популярные издания, напрмер, Даниэль Канеман ("ДУмай медленно, решай быстро") или исторический исследовательский труд Барбары Такман ("Августовские пушки").

# %% [markdown]
# ### Художественная литература / нонфикшн
#
# 📖 какого направления больше: художественной литературы или нон-фикшн? Как это выглядит в количестве книг и в объёме страниц?

# %%
plt.figure(figsize=(18, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Художественная литература / нонфикшн', fontweight='bold')

data = (df.groupby('type', as_index=False).agg({'book_title':'count', 'page_count':'sum'})
        .sort_values(by='book_title', ascending=False))
data['avg_cnt_page'] = data['page_count'] / data['book_title']

ax1 = plt.subplot(1, 3, 1)
sns.barplot(data=data, x='type', y='book_title', color=color)
plt.title('Суммарное количество \n книг', fontweight='bold')
plt.xlabel('')
plt.ylabel('')

ax2 = plt.subplot(1, 3, 2)
sns.barplot(data=data, x='type', y='page_count', color=color)
plt.title('Суммарное количество \n страниц', fontweight='bold')
plt.xlabel('')
plt.ylabel('')

ax3 = plt.subplot(1, 3, 3)
sns.barplot(data=data, x='type', y='avg_cnt_page', color=color)
plt.title('Среднее количество страниц \n на одну книгу', fontweight='bold')
plt.xlabel('')
plt.ylabel('')

plt.tight_layout()
plt.show();

# %% [markdown]
# **Вывод**:
#
# - художественная литература уверенно преобладает и по количеству прочитанных книг, и по объёму прочитанного, и по среднему количеству страниц на одну книгу
#
#
# - больше всего разница видна в соотношении объёма прочитанного: нонфикшн литературы прочитано около 15 тысяч страниц, а художественной литературы - более 25 тысяч страниц

# %% [markdown]
# ### Формат и издательства
#
# 📖 в каком формате я читала больше: в бумажном или электронном? Какие издательства преобладают?

# %%
fig = plt.figure(constrained_layout=True, figsize=(18, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Формат и издательства', fontweight='bold', y=1.05)

spec = gridspec.GridSpec(ncols=2, nrows=3, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
plt.title('Формат книги', fontweight='bold')
sns.barplot(data=(df.groupby('paper or electronic', as_index=False).agg({'book_title':'count'})
            .sort_values(by='book_title', ascending=False)),
           y='paper or electronic', x='book_title', color=color)
plt.xlabel('количество книг')
plt.ylabel('')

ax2 = fig.add_subplot(spec[1:, :-1])
plt.title('Издательства: электронные книги', fontweight='bold')
sns.barplot(data=(df.loc[df['paper or electronic'] == "электронная"].groupby('publishing', as_index=False)
                 .agg({'book_title':'count'}).sort_values(by='book_title', ascending=False)),
           y='publishing', x='book_title', color=color)
plt.xlabel('количество книг')
plt.ylabel('')

ax3 = fig.add_subplot(spec[0:, -1])
plt.title('Издательства: бумажные книги', fontweight='bold')
sns.barplot(data=(df.loc[df['paper or electronic'] == "бумажная"].groupby('publishing', as_index=False)
                 .agg({'book_title':'count'}).sort_values(by='book_title', ascending=False)),
           y='publishing', x='book_title', color=color)
plt.xlabel('количество книг')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
#
# - большинство прочитанных книг - бумажные, и только 4 книги - электронные
#
#
# - большинство бумажных книг выпущены издательствами АСТ, Эксмо, Азбука

# %% [markdown]
# ### Как менялся мой читательский опыт
#
# 📖 на какие темы я обращала внимание и как эти темы сменяли друг друга в разные годы?
#
# 📖 как ещё изменялся мой читательский опыт с течением времени?

# %%
plt.figure(figsize=(18, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Как менялся мой читательский опыт', fontweight='bold')

ax1 = plt.subplot(3, 1, 1)
plt.title('Дата прочтения, тема и век написания', fontweight='bold')
sns.scatterplot(data=df, x='date_reading', y='theme', hue='century_writing', palette=palette_theme)
sns.move_legend(ax1, "upper left", bbox_to_anchor=(1, 1))
plt.xlabel('')
plt.ylabel('')

ax2 = plt.subplot(3, 1, 2)
plt.title('Дата прочтения, тема и страна', fontweight='bold')
sns.scatterplot(data=df, x='date_reading', y='theme', hue='author_country_type', palette=palette_theme)
sns.move_legend(ax2, "upper left", bbox_to_anchor=(1, 1))
plt.xlabel('')
plt.ylabel('')

ax3 = plt.subplot(3, 1, 3)
plt.title('Дата прочтения, тема и возраст автора', fontweight='bold')
sns.scatterplot(data=df, x='date_reading', y='theme', hue='age_writing_category', palette=palette_theme)
sns.move_legend(ax3, "upper left", bbox_to_anchor=(1, 1))
plt.xlabel('')
plt.ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод**:
#
# - если изначально (в 2018 году) мой читательский дневник был посвящён художественной литературе, то затем в него стали добавляться и другие темы:
#     - тема родительства и детства - около 2020-го года,
#     - научно-популярная/просветительская литература и психология - в начале 2021 года
#     - английский язык и обучение IT в первой половине 2022-го года
#
#
# - если в художественной литературе чаще присутствует 20-й век и изредка другие, иногда экзотичные, варианты, то в остальных темах преобладает 21-й век
#
#
# - художественная литература полна книг авторов из разных стран. В других темах страны представлены менее разнообразно: например, в научпоп/просветительской литературе чаще всего встречаются российские авторы, в английском языке - Великобритания, в обучении IT - Россия и США.
#
#
# - что касается возраста авторов, то во всех темах мы видим разнообразие. Интересный момент: читательский дневник начинался с книг авторов, написавших свои произведения в молодом возрасте

# %%
plt.figure(figsize=(18, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Как менялся мой читательский опыт', fontweight='bold')

ax1 = plt.subplot(3, 1, 1)
plt.title('Дата прочтения, объём и тема', fontweight='bold')
sns.scatterplot(data=df, x='date_reading', y='page_count', hue='theme', palette=palette_theme)
sns.move_legend(ax1, "upper left", bbox_to_anchor=(1, 1))
plt.xlabel('')
plt.ylabel('количество страниц')

ax2 = plt.subplot(3, 1, 2)
plt.title('Дата прочтения, объём и страна', fontweight='bold')
sns.scatterplot(data=df, x='date_reading', y='page_count', hue='author_country_type', palette=palette_theme)
sns.move_legend(ax2, "upper left", bbox_to_anchor=(1, 1))
plt.xlabel('')
plt.ylabel('количество страниц')

ax3 = plt.subplot(3, 1, 3)
plt.title('Дата прочтения, объём и возраст автора', fontweight='bold')
sns.scatterplot(data=df, x='date_reading', y='page_count', hue='age_writing_category', palette=palette_theme)
sns.move_legend(ax3, "upper left", bbox_to_anchor=(1, 1))
plt.xlabel('')
plt.ylabel('количество страниц')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Выводы**:
#
# - что касается объёма и интенсивности чтения, то можно заметить, что самой объёмной является художественная литература (объём доходит до 1500 страниц в одной книге), а самым интенсивным периодом чтения является период с начала 2021-года до февраля 2022-го.
#
#
# - если первому интенсивному периоду (с конца 2018 года до начала 2020-го года) присущ только один жанр - художественная литература, а в остальном (например, объём книги, страна, возраст автора) характерно разнообразие, то периоду с 2021 по 2022 год присуще разнообразие по всем направлениям, и жанровое в том числе.
#
#
# - обучение новой профессии в 2022 году стало занимать практически всё свободное время, и объём чтения значительно сократился. Так что можно сказать, что читательский дневник отреагировал на изменения в жизни и в объёме, и в тематике чтения.

# %% [markdown]
# ### Интенсивность чтения по годам

# %% [markdown]
# **Дополнительно** изучим среднюю сокрость чтения.
#
# **В конце 2020-го года я составила конкретный план действий на следующий год**: в какое время дня я собираюсь ежедневно читать, сколько я планирую читать книг в месяц, какие книги/темы мне интересны.
#
# На практике я **вывела желательную для себя среднюю скорость чтения: 50 страниц в день**. В зависимости от жанра, формата издания и содержания книги скорость колебалась. Иногда я читала около сотни страниц в день, а иногда и не дотягивала до своего ориентира.
#
# Посмотрим, что покажут данные - какова интенсивность чтения в разные годы? **Насколько сильно отличается средняя скорость чтения в год, когда у меня был определённый, заранее сформулированный, план действий, от остальных лет**, когда чтение не было основной деятельностью в свободное время?

# %%
fig = plt.figure(constrained_layout=True, figsize=(18, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Интенсивность чтения по годам', fontweight='bold', y=1.05)

spec = gridspec.GridSpec(ncols=2, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :])
plt.title('Изменения по годам', fontweight='bold')
sns.scatterplot(data=df, x='date_reading', y='speed_reading', color=color)
plt.axhline(y=df['speed_reading'].mean(), color='grey', linestyle='--', 
            label='средний уровень \n скорости чтения \n за все годы')
plt.legend()
plt.xlabel('')
plt.ylabel('прочитано страниц в день')

ax2 = fig.add_subplot(spec[1, :-1])
plt.title('Расположение данных по годам: целиком', fontweight='bold')
sns.boxplot(data=df, x='year_reading', y='speed_reading', color=color)
plt.axhline(y=df['speed_reading'].mean(), color='grey', linestyle='--', 
            label='средний уровень \n скорости чтения \n за все годы')
plt.legend(loc='upper left')
plt.xlabel('')
plt.ylabel('прочитано страниц в день')

ax3 = fig.add_subplot(spec[1, -1])
plt.title('Расположение данных по годам: медиана в приближении', fontweight='bold')
sns.boxplot(data=df, x='year_reading', y='speed_reading', color=color)
plt.axhline(y=df['speed_reading'].mean(), color='grey', linestyle='--', 
            label='средний уровень \n скорости чтения \n за все годы')
plt.legend(loc='upper left')
plt.xlabel('')
plt.ylabel('прочитано страниц в день')
plt.ylim([0, 80])

plt.show()

# %% [markdown]
# **Вывод**:
#
# - интенсивность чтения в разные годы заметно отличается: в 2021-м году, когда я читала ежедневно и у меня был сформулирован конкретный план действий, средняя скорость составляла около 60 страниц в день. В 2022-м году какое-то время я придерживалась этого плана, поэтому средняя скорость чтения тоже достаточно высокая - около 55 страниц в день.
#
#
# - в остальные годы интенсивность чтения заметно ниже, вплоть до среднего значения в 10 страниц в день

# %% [markdown]
# Посмотрим, какие книги стали самыми медленно и быстро читаемыми:

# %%
print(f'Книги с наименьшей и наибольшей скоростью прочтения:')
display(df.query('speed_reading < 9 |speed_reading > 120')
        [['author_full_name', 'book_title', 'date_reading','year_reading', 'speed_reading']]
         .sort_values(by='speed_reading'))
# Out:
# Книги с наименьшей и наибольшей скоростью прочтения:
#                 author_full_name  \
# 26             Полина Казимирова
# 23          Людмила Петрановская
# 27        Габриэль Гарсиа Маркес
# 91                    Collective
# 107             Массимо Пильюччи
# 100  Мана Такахаси, Сёко Адзума
# 17                   Орхан Памук
# 98            Александр Богачев
# 93             Владимир Савельев
# 106                   Collective
# 104                Lewis Carroll
# 47    Аркадий и Борис Стругацкие
# 30                Солвей Бергрен
# 79               Харуки Мураками
# 84              Мигель Сервантес
# 34                Радмила Хакова
# 22                Уильям Голдинг
# 77                  Э.О.Чаровици
# 70     Фрэнсис Скотт Фицджеральд
# 86              Владимир Набоков
#
#                                             book_title date_reading  \
# 26        Мой ребёнок ест сам. Прикорм с удовольствием   2020-08-20
# ...

# %% [markdown]
# ## Выводы

# %% [markdown]
# В ходе исследования был проанализирован мой личный читательский дневник и были даны ответы на все поставленные вопросы:
#
# 📖 **сколько книг прочитано? а сколько страниц? за какое время?**
# - прочитано 108 книг
#
#
# - 40900 страниц
#
#
# - за 6 неполных уникальных лет (с 2018 по 2023)
#
# 📖 **какие эпохи, жанры, страны преобладают?**
# - из эпох преобладают 20-й и 21-й века
#
#
# - среди жанров выделяются роман и нон-фикшн литература
#
#
# - среди множества стран на первых местах по количеству прочитанных книг США, Россия, Великобритания, Япония
#
#
# 📖 **кого я читала больше: женщин или мужчин? Отличается ли преобладание количества книг от объёма в страницах?**
# - по суммарному количеству книг и объёму страниц значительно преобладают авторы-мужчины (отличие более чем в 3 раза)
#
#
# - однако в среднем авторы-женщины чуть более многословны: в то время как в среднем на одну книгу автора-мужчины приходится около 370 страниц, на книгу автора-женщины приходится в среднем 410 страниц
#
#
# - кроме того, есть небольшое количество книг, написанных группой авторов
#
#
# 📖 **сколько авторам было лет на момент написания своих произведений? я больше читала молодых или уже умудрённых жизнью авторов? Каков средний возраст авторов на момент написания прочитанных мною книг? Отличается ли такой средний возраст в разрезе пола?**
#
# - на момент написания произведений авторам было от 19 до 80 лет
#
#
# - нельзя однозначно сказать, авторов какого возраста я читала больше, молодых или умудрённых жизнью: это зависит от того, что именно считать за молодость. Самые многочисленные категории: это авторы в возрасте от 30 до 40 лет, от 40 до 50, от 50 до 60 лет.
#
#
# - средний возраст авторов на момент написания произведений: около 45 лет
#
#
# - средний возраст отличается в разрезе пола: в среднем авторы-женщины старше - им около 50 лет, в то время как авторам-мужчинам в среднем около 44 лет
#
#
# 📖 **если рассмотреть основные интересующие темы (худож.литература, научно-популярная/просветительская и т.д.) - как они отличаются друг от друга? Сколько в каждой теме авторов, книг, страниц, стран, каков возраст и пол авторов?**
#
# - самый распространённый тип литературы - **художественная**. Этой теме принадлежит большинство авторов, книг, наибольшее количество страниц и  стран авторов. Средний возраст авторов около 40 лет, и в основном это мужчины. Большинство книг написаны в 20 веке, но есть и книги из 21-го века, а также, что редкость - книги из других, более ранних, веков
#
#
# - литература, посвящённая **детям и родителям** - вторая по количеству авторов, книг, объёму прочитанных страниц, разнообразию стран происхождения авторов. Средний возраст авторов около 47 лет, и в основном авторы - женщины.
#
#
# - **научпоп/просвещение, обучение IT, психология и английский** - все эти темы менее распространены. Что можно выделить интересного: обучение IT и английский менее разнообразны по странам и имеют более молодой средний возраст авторов. Также для этих двух категорий характерно авторство группы людей. Среди же авторов научно-популярных и психологических книг встречаются женщины.
#
# 📖 **какой процент авторов - лауреаты самых известных литературных премий? Кто эти авторы?**
#
# - небольшая доля авторов (не более 10%) - лауреаты известных литературных премий (Нобелевская, Пулитецеровская, Букеровская премии - 10, 6, 4 процента от общего числа авторов и 8, 5 и 3 лауреата соответственно)
#
#
# несколько премий получили следующие авторы:
# - Уильям Фолкнер, Эрнест Хэмингуэй, Джон Стейнбек, Уильям Голдинг, Кадзуо Исигуро
#
# по одной премии получили:
# - Герман Гессе, Габриэль Гарсиа Маркес, Орхан Памук, Харпер Ли, Барбара Такман, Айрис Мёрдок
#
#
# 📖 **какой автор - лидер по количеству прочитанных книг? а по количеству страниц - это тот же автор?**
#
# - лидер по количеству прочитанных книг (7 произведений) - Харуки Мураками, он же лидер по суммарному объёму прочитанного - более 3000 прочитанных страниц
#
#
# - в остальном лидеры по количеству книг не всегда совпадают с лидерами по объёму прочитанных страниц
#
#
# - самыми "многословными" оказались Мариам Петросян и Мигель Сервантес. Справедливости ради отметим, что их произведения поделены на несколько томов ("Дом, в котором..." Мариам Петросян - 3 тома, "Дон Кихот" Мигеля Сервантеса - 2 тома), однако многотомники в сумме это одно произведение, поэтому они не разделены на отдельные книги в нашем исследовании.
#
# 📖 **какого направления больше: художественной литературы или нон-фикшн? Как это выглядит в количестве книг и в объёме страниц?**
#
# - художественная литература уверенно преобладает и по количеству прочитанных книг, и по объёму прочитанного, и по среднему количеству страниц на одну книгу
#
#
# - больше всего разница видна в соотношении объёма прочитанного: нонфикшн литературы прочитано около 15 тысяч страниц, а художественной литературы - более 25 тысяч страниц
#
# 📖 **в каком формате я читала больше: в бумажном или электронном? Какие издательства преобладают?**
#
# - большинство прочитанных книг - бумажные, и только 4 книги - электронные
#
#
# - большинство бумажных книг выпущены издательствами АСТ, Эксмо, Азбука
#
# 📖 **на какие темы я обращала внимание и как эти темы сменяли друг друга в разные годы?**
#
# - если изначально (в 2018 году) мой читательский дневник был посвящён художественной литературе, то затем в него стали добавляться и другие темы:
#     - тема родительства и детства - около 2020-го года,
#     - научно-популярная/просветительская литература и психология - в начале 2021 года
#     - английский язык и обучение IT в первой половине 2022-го года
#
#
# - если в художественной литературе чаще присутствует 20-й век и изредка другие, иногда экзотичные, варианты, то в остальных темах преобладает 21-й век
#
#
# - художественная литература полна книг авторов из разных стран. В других темах страны представлены менее разнообразно: например, в научпоп/просветительской литературе чаще всего встречаются российские авторы, в английском языке - Великобритания, в обучении IT - Россия и США.
#
#
# - что касается возраста авторов, то во всех темах мы видим разнообразие. Интересный момент: читательский дневник начинался с книг авторов, написавших свои произведения в молодом возрасте
#
# 📖 **как ещё изменялся мой читательский опыт с течением времени?**
#
# - что касается объёма и интенсивности чтения, то можно заметить, что самой объёмной является художественная литература (объём доходит до 1500 страниц в одной книге), а самым интенсивным периодом чтения является период с начала 2021-года до февраля 2022-го.
#
#
# - если первому интенсивному периоду (с конца 2018 года до начала 2020-го года) присущ только один жанр - художественная литература, а в остальном (например, объём книги, страна, возраст автора) характерно разнообразие, то периоду с 2021 по 2022 год присуще разнообразие по всем направлениям, и жанровое в том числе.
#
#
# - обучение новой профессии в 2022 году стало занимать практически всё свободное время, и объём чтения значительно сократился. Так что можно сказать, что читательский дневник отреагировал на изменения в жизни и в объёме, и в тематике чтения.
#
# **Дополнительно была изучена интенсивность чтения по годам**:
# - интенсивность чтения в разные годы заметно отличается: в 2021-м году, когда я читала ежедневно и у меня был сформулирован конкретный план действий, средняя скорость составляла около 60 страниц в день. В 2022-м году какое-то время я придерживалась этого плана, поэтому средняя скорость чтения тоже достаточно высокая - около 55 страниц в день.
#
#
# - в остальные годы интенсивность чтения заметно ниже, вплоть до среднего значения в 10 страниц в день
#
# **Таким образом** можно утверждать, что читательский дневник действительно отражает изменения в жизни человека, который его ведёт.
#
# Поэтому фраза **"Ты - то, что ты читаешь"** имеет право на существование.
# _____________________________________________________________________________________________________________________________
# Исследование выполнила: аналитик данных Малахова Наталья
#
# Дата выполнения: 25 мая 2023 года
#
# Мой телеграм-канал: [Дневник аналитика](https://t.me/diary_musician_analyst "Дневник аналитика")
#
# Портфолио: [GitHub](https://github.com/Malakhova-Natalya "GitHub")
#
# Спасибо за внимание!
