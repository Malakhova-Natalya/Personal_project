# %% [markdown]
# # Книги 📖: сравнение двух разных видеоканалов🎬

# %% [markdown]
# ![%D0%BB%D0%BE%D0%B3%D0%BE%D1%82%D0%B8%D0%BF%D1%8B.png](attachment:%D0%BB%D0%BE%D0%B3%D0%BE%D1%82%D0%B8%D0%BF%D1%8B.png)

# %% [markdown]
# *на фото: Ирина Шихман, автор канала "А поговорить", признана Минюстом РФ иноагентом

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Открытие-данных" data-toc-modified-id="Открытие-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Открытие данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Главные-цифры" data-toc-modified-id="Главные-цифры-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Главные цифры</a></span></li><li><span><a href="#Даты-появления-видео" data-toc-modified-id="Даты-появления-видео-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Даты появления видео</a></span></li><li><span><a href="#Интерес" data-toc-modified-id="Интерес-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Интерес</a></span></li><li><span><a href="#Вовлечение" data-toc-modified-id="Вовлечение-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Вовлечение</a></span></li><li><span><a href="#Одобрение" data-toc-modified-id="Одобрение-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Одобрение</a></span></li><li><span><a href="#Обсуждение" data-toc-modified-id="Обсуждение-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Обсуждение</a></span></li><li><span><a href="#Ажиотаж/негатив" data-toc-modified-id="Ажиотаж/негатив-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Ажиотаж/негатив</a></span></li><li><span><a href="#Ищем-взаимосвязи-(корреляция)" data-toc-modified-id="Ищем-взаимосвязи-(корреляция)-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Ищем взаимосвязи (корреляция)</a></span></li><li><span><a href="#Длительность-видео-и-реакция-аудитории" data-toc-modified-id="Длительность-видео-и-реакция-аудитории-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Длительность видео и реакция аудитории</a></span></li><li><span><a href="#Год-выхода-и-реакция-аудитории" data-toc-modified-id="Год-выхода-и-реакция-аудитории-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Год выхода и реакция аудитории</a></span></li><li><span><a href="#Реакция-аудитории-по-годам" data-toc-modified-id="Реакция-аудитории-по-годам-4.11"><span class="toc-item-num">4.11&nbsp;&nbsp;</span>Реакция аудитории по годам</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# В данном исследовании проводится **анализ и сравнение двух русскоязычных видеоканалов о книгах**🎬.
#
# Это "большой" и "маленький" каналы, где количество подписчиков отличается на порядок. В ходе проекта я проведу **сравнение реакции аудитории на контент разных по объёму и формату видеоканалов одной тематики**.
#
# Это каналы:
# - "А поговорить*" рубрика книжный клуб - "А почитать*"
# - "PunkMonk", канал Николая Жаринова
#
# *автор канала Ирина Шихман признана Минюстом РФ иноагентом
#
# **Основные задачи**:
#
# 👩‍💻 сравнить каналы между собой, используя открытые данные
#
# 💡 использовать самостоятельно придуманные метрики для раскрытия данных
#
# 👄 рассказать о каналах доступным и понятным языком
#
# 📈 визуализировать данные
#
# **Описание данных**:
#
# В исследовании используются данные из открытых источников, полученные через api youtube*. Данные были получены 5 и 11 мая 2023 года.
#
# *РКН: сайт нарушает законодательство РФ

# %% [markdown]
# ## Открытие данных

# %% [markdown]
# Импортируем необходимые библиотеки:

# %%
import pandas as pd
import os

from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

import datetime as dt
from datetime import datetime, date, timedelta
import numpy as np

# %% [markdown]
# Открываем файлы:

# %%
if os.path.exists('/datasets/video_collection/apochitat_main.xlsx'):
    apochitat_main = pd.read_excel('/datasets/video_collection/apochitat_main.xlsx')
else:
    apochitat_main = pd.read_excel('/C:/datasets/video_collection/apochitat_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/apochitat.xlsx'):
    apochitat = pd.read_excel('/datasets/video_collection/apochitat.xlsx')
else:
    apochitat = pd.read_excel('/C:/datasets/video_collection/apochitat.xlsx')

# %%
if os.path.exists('/datasets/video_collection/punkmonk_main.xlsx'):
    punkmonk_main = pd.read_excel('/datasets/video_collection/punkmonk_main.xlsx')
else:
    punkmonk_main = pd.read_excel('/C:/datasets/video_collection/punkmonk_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/punkmonk.xlsx'):
    punkmonk = pd.read_excel('/datasets/video_collection/punkmonk.xlsx')
else:
    punkmonk = pd.read_excel('/C:/datasets/video_collection/punkmonk.xlsx')

# %% [markdown]
# Поскольку нас интересует только рубрика "А почитать*", редактируем общие данные:

# %%
apochitat_main['view_count'] = apochitat['view_count'].sum()
apochitat_main['video_count'] = len(apochitat)

# %% [markdown]
# Объединим данные о разных каналах:

# %%
main = pd.concat([apochitat_main, punkmonk_main])
main['name'] = ['А почитать*', 'PunkMonk']

# зададим имя 
apochitat['name'] = 'А почитать*'
punkmonk['name'] = 'PunkMonk'

# зададим порядок 
apochitat['order'] = 'a'
punkmonk['order'] = 'b'

# добавим данные о количестве подписчиков
apochitat['subscriber_count'] = int(apochitat_main['subscriber_count']) 
punkmonk['subscriber_count'] = int(punkmonk_main['subscriber_count'])

df = pd.concat([apochitat, punkmonk])

# %% [markdown]
# Для того, чтобы было удобно рассматривать большие числа, сделаем разделение пробелами:

# %%
class _IntArrayFormatter(pd.io.formats.format.GenericArrayFormatter):

    def _format_strings(self):
        formatter = self.formatter or (lambda x: ' {:,}'.format(x).replace(',', ' '))
        fmt_values = [formatter(x) for x in self.values]
        return fmt_values

pd.io.formats.format.IntArrayFormatter = _IntArrayFormatter

# %% [markdown]
# Для ознакомления и проверки данных будем использовать собственную функцию:

# %%
def my_check_function (dataset):
    '''Функция для ознакомления и проверки даных'''
    print('Размер датасета (количество строк, столбцов):')
    print(dataset.shape)
    print('Как выглядят случайные 5 строк:')
    display(dataset.sample(5, random_state=42))
    print()
    print('Общая информация о данных, наименования столбцов, типы данных:')
    print(dataset.info())
    print()
    print('Есть ли пропуски, сколько их:')
    print(dataset.isna().sum())
    print('Доля пропущенных значений:')
    print(dataset.isna().mean())
    print()
    print('Есть ли явные дубликаты, сколько их:')
    print(dataset.duplicated().sum())
    print('Доля явных дубликатов:')
    print(dataset.duplicated().mean())
    print()
    print('Подробное описание данных:')
    display(dataset.describe())

# %% [markdown]
# Проверяем наши данные:

# %%
my_check_function(df)
# Out:
# Размер датасета (количество строк, столбцов):
# (41, 11)
# Как выглядят случайные 5 строк:
#        video_id                                        video_title  \
# 14  yzkBMw5Wi_M        Матрица | История альтернативной реальности
# 3   9Db1n-qHjuA  Трудно быть Богом | Братья Стругацкие и социал...
# 8   GFNgu3frr2s  1984 - история самой продаваемой книги в Росси...
# 15  yw8Y75I35g8         Рецепт бестселлера | Код Да Винчи | Террор
# 4   ViBdWkuxV5o  Евгений Водолазкин «Оправдание острова». Когда...
#
#    upload_date  view_count  like_count  comment_count  duration_seconds  \
# 14  2022-01-29      83 224       7 496            459             1 130
# 3   2022-10-08     131 841       6 505            439             4 438
# 8   2022-08-15   1 310 774      43 657          4 950             4 913
# 15  2022-02-12      61 425       5 756            312             1 137
# 4   2021-10-31     311 319       9 450            933             7 190
#
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# - в данных нет пропусков, дубликатов, они пригодны для анализа
#
#
# - единственное, что нужно поправить - формат данных в столбцах upload_date и duration

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Теперь изменим форматы в нужных столбцах:

# %%
df['upload_date'] = pd.to_datetime(df['upload_date'], format='%Y-%m-%d')

df['duration'] = pd.to_datetime(df['duration'],format='%H:%M:%S').dt.time

# %% [markdown]
# ### Вывод

# %% [markdown]
# - данные в столбцах upload_date и duration приведены к нужным форматам

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Главные цифры

# %% [markdown]
# Для удобства чтения графиков данные о количестве просмотров и подписчиков переведём в миллионы:

# %%
main['view_count_mln'] = main['view_count'] / 1000000
main['subscriber_count_mln'] = main['subscriber_count'] / 1000000

# %% [markdown]
# Зададим цветовое решение проекта:

# %%
color = '#c4cbe3'

# %% [markdown]
# Визуализируем наши данные:

# %%
plt.figure(figsize=(20, 8))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Главные цифры каналов:', fontweight='bold')

ax1 = plt.subplot(1, 3, 1)
sns.barplot(data=main,  x='view_count_mln', y='name', color=color)
plt.title('суммарное количество просмотров', fontweight='bold', y=1.02)
plt.xlabel('миллионы')
plt.ylabel('')

ax2 = plt.subplot(1, 3, 2)
sns.barplot(data=main, x='subscriber_count_mln', y='name', color=color)
plt.title('количество подписчиков', fontweight='bold', y=1.02)
plt.xlabel('миллионы')
plt.ylabel('')

ax3 = plt.subplot(1, 3, 3)
sns.barplot(data=main, x='video_count', y='name', color=color)
plt.title('количество видео', fontweight='bold', y=1.02)
plt.xlabel('единицы')
plt.ylabel('')

plt.tight_layout()
plt.show();

# %% [markdown]
# *автор канала Ирина Шихман признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - рубрика "А почитать*" находится в крупном по числу подписчиков канале - у канала "А поговорить*" более 2.5 млн подписчиков. И это чень большой разрыв с каналом PunkMonk - здесь около 100 тыс. подписчиков
#
#
# - однако по суммарному числу просмотров разрыв между каналами не такой большой: 9 млн у "А почитать*" и 4.5 млн у "PunkMonk"
#
#
# - по числу видео и вовсе канал "PunkMonk" опережает книжную рубрику Ирины Шихман*: 31 против 10 видео
#
#
# *автор канала Ирина Шихман признана иноагентом

# %% [markdown]
# ### Даты появления видео

# %%
plt.figure(figsize=(20, 6))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')

sns.scatterplot(data=df, x='upload_date', y='name', color=color, s=200)
plt.title('Даты появления видео на каналах', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

plt.show();

# %% [markdown]
# *автор канала Ирина Шихман признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - каналы созданы практически одновременно - в начале 2021 года
#
#
# - в рубрике "А почитать*" видео выходят с перерывами, иногда с большими. А на канале "PunkMonk" с конца 2021 года выпуски выходят достаточно часто
#
# *автор канала Ирина Шихман признана иноагентом

# %% [markdown]
# ### Интерес

# %% [markdown]
# Предположим, что **просмотры - это выражение заинтересованности**.
#
# Посмотрим, как различается эта метрика у каналов.

# %% [markdown]
# Для удобства чтения графиков большие значения переведём в миллионы:

# %%
df['view_count_mln'] = df['view_count'] / 1000000

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Интерес', fontweight='bold')

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='view_count_mln', y='name', s=200, color=color)
plt.title('Сколько миллионов человек просмотрели видео', fontweight='bold')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'view_count_mln':'mean'})
            .sort_values(by='order'), y='name', x='view_count_mln', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df, x='view_count_mln', y='name', color=color)
plt.title('Сколько миллионов человек просмотрели видео', fontweight='bold')
plt.xlabel('просмотры, млн')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'view_count_mln':'median'})
            .sort_values(by='order'), y='name', x='view_count_mln', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('просмотры, млн')
plt.ylabel('')

plt.show()

# %% [markdown]
# *автор канала Ирина Шихман признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - видео на каналах значительно отличаются по количеству просмотров: от 350 тысяч до 2.3 млн на канале Шихман*, до 400 тысяч на канале PunkMonk
#
#
# - на первый взгляд "А почитать*" находится в более выгодном положении. Но есть интересный момент: если мы вспомним количество подписчиков, то мы поймём, что на канале Ирины Шихман* далеко не все подписчики смотрят книжную рубрику (в среднем в лучшем случае только каждый 3 подписчик), в то время как канал "PunkMonk" иногда превосходит по просмотрам свою аудиторию
#
# *автор канала Ирина Шихман признана иноагентом
#
# Посмотрим на видео с самыми большими просмотрами:

# %%
pd.set_option('display.max_colwidth', None)
(df[['name','video_title', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='view_count', ascending=False).head(10))
# Out:
#            name  \
# 7   А почитать*
# 8   А почитать*
# 5   А почитать*
# 9   А почитать*
# 1   А почитать*
# 6   А почитать*
# 0   А почитать*
# 2   А почитать*
# 22     PunkMonk
# 0      PunkMonk
#
#                                                                                      video_title  \
# 7   Как «Пост» Дмитрия Глуховского* предсказал судьбу России. И что будет дальше? // А почитать?
# 8                 1984 - история самой продаваемой книги в России // Джордж Оруэлл «А почитать?»
# 5                                  Гэлвины: самая сумасшедшая семья Америки. Любовь и шизофрения
# 9          Добро победит? 5 научных доказательств того, что мы становимся лучше // А почитать?..
# 1                              Радмила Хакова. Как найти себя за 147 свиданий?! // А почитать?..
# 6                          Платье королевы. Как после войны сплотить целую нацию? // А почитать?
# 0                   «Риф» Алексея Поляринова. Секты, культы, религии, память // А поговорить?...
# ...

# %% [markdown]
# *автор канала Ирина Шихман и писатель Дмитрий Глуховский признаны иноагентами

# %% [markdown]
# ### Вовлечение

# %% [markdown]
# Кроме интереса, мы можем выделить ещё **вовлечение** подписчиков.
#
# Рассчитаем процент вовлечения как соотношение числа просмотров и подписчиков.
#
# - **если этот показатель небольшой** - значит, не все подписчики активно просмтаривают видео на канале
#
#
# - **если же показатель большой** (например из 100 подписчиков видео просмотрели 100 человек - метрика будет 100%), и значит, у канала очень лояльная, вовлечённая аудитория.
#
#
# - **если показатель выше 100%** - значит, видео на канале привлекает внешнюю аудиторию, которая не является подписчиками
#
# Добавляем новые данные:

# %%
df['subscr_perc'] = df['view_count'] / df['subscriber_count'] * 100

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Процент вовлечения', fontweight='bold')

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='subscr_perc', y='name', s=200, color=color)
plt.title('Сколько человек из 100 подписчиков просмотрели видео', fontweight='bold')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'subscr_perc':'mean'})
            .sort_values(by='order'), y='name', x='subscr_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='subscr_perc', y='name', color=color)
plt.title('Сколько человек из 100 подписчиков просмотрели видео', fontweight='bold')
plt.xlabel('просмотры от подписок, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'subscr_perc':'median'})
            .sort_values(by='order'), y='name', x='subscr_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('просмотры от подписок, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# *автор канала Ирина Шихман признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - у канала "PunkMonk" более устойчивая и лояльная аудитория - в среднем процент вовлечения около 100%, а бывает и больше - до 300%
#
#
# - в рубрике "А почитать*" метрика в среднем составляет примерно 30% - далеко не все подписчики канала "А поговорить*" смотрят книжную рубрику, даже максимальное значение только на уровне 90%
#
#
# *автор канала Ирина Шихман признана иноагентом

# %% [markdown]
# ### Одобрение

# %% [markdown]
# Предположим, что **одобрение** - это не просто количество лайков, а соотношение лайков и просмотров.

# %% [markdown]
# Вычисляем данные для новой метрики - процент лайков от просмотров:

# %%
df['like_perc'] = df['like_count'] / df['view_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Одобрение', fontweight='bold')

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='like_perc', y='name', s=200, color=color)
plt.title('Сколько человек из 100 посмотревших поставили лайк', fontweight='bold')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'like_perc':'mean'})
            .sort_values(by='order'), y='name', x='like_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='like_perc', y='name', color=color)
plt.title('Сколько человек из 100 посмотревших поставили лайк', fontweight='bold')
plt.xlabel('лайки от просмотров, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'like_perc':'median'})
            .sort_values(by='order'), y='name', x='like_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('лайки от просмотров, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# *автор канала Ирина Шихман признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - мы видим очень большую разницу в одобрении аудитории: на небольшом специализированном канале уровень одобрения от 4 до 12%, а в книжной рубрике большого неспециализированного канала этот уровень от 2 до 4%
#
#
# - в среднем каждый 3-й зритель "А почитать*" ставит лайк просмотренному видео, и каждый 7-й зритель - на канале "PunkMonk" (и это пока лучший результат за мою историю наблюдений)
#
# *автор канала Ирина Шихман признана иноагентом
#
# Посмотрим, какие видео получили максимум одобрения:

# %%
(df[['name','video_title', 'like_perc', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='like_perc', ascending=False).head(10))
# Out:
#         name  \
# 28  PunkMonk
# 12  PunkMonk
# 18  PunkMonk
# 13  PunkMonk
# 30  PunkMonk
# 15  PunkMonk
# 25  PunkMonk
# 16  PunkMonk
# 14  PunkMonk
# 17  PunkMonk
#
#                                                                video_title  \
# 28                                             Лучшая повесть? Лев Толстой
# 12                                 Крик Эдварда Мунка и Голгофа Николая Ге
# 18                             Рождение антиутопии | Приключения Гулливера
# 13                                        Гений и безумие | Михаил Врубель
# 30  Удар судьбы! Лучший роман ХХ века? Хрупкое равновесие Рохинтона Мистри
# 15                              Рецепт бестселлера | Код Да Винчи | Террор
# 25               Крестовый поход детей, Курт Воннегут и его роман Бойня №5
# 16                                                           Зачем читать?
# 14                             Матрица | История альтернативной реальности
# ...

# %% [markdown]
# - складывается впечатление, что максимум одобрения имеют средне-небольшие по длине ролики - большинство имеют длину от 12 до 26 минут
#
#
# - также можно отметить, что эти видео часто имеют довольно небольшое количество просмотров - из 10 видео только 2 набрали более сотни тысяч просмотров

# %% [markdown]
# ### Обсуждение

# %% [markdown]
# Добавляем данные для ещё одной новой метрики - процент комментариев от просмотров покажет нам, насколько видео обсуждаемые:

# %%
df['comment_perc'] = df['comment_count'] / df['view_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Обсуждение', fontweight='bold')

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='comment_perc', y='name', s=200, color=color)
plt.title('Сколько человек из 100 посмотревших оставили комментарий', fontweight='bold')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_perc':'mean'})
            .sort_values(by='order'), y='name', x='comment_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='comment_perc', y='name', color=color)
plt.title('Сколько человек из 100 посмотревших оставили комментарий', fontweight='bold')
plt.xlabel('комментарии от просмотров, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_perc':'median'})
            .sort_values(by='order'), y='name', x='comment_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('комментарии от просмотров, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# *автор канала Ирина Шихман признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - в среднем поведение пользователей на каналах похоже, 3-4 человека из 1000 посмотревших оставляют комментарий. Ддя сравнения: это в целом чуть более активное поведение зрителей по сравнению с другими сферами: на каналах с интервью или про финансы в среднем 2 человека из 1000 посмотревших пишут комментарии
#
#
# - однако заметим, что на канале Ирины Шихман* в целом поведение зрителей менее активное, и есть один очень выдающийся "выброс"
#
# *автор канала Ирина Шихман признана иноагентом
#
# Посмотрим, какие выпуски имеют наибольший показатель обсуждения:

# %%
(df[['name','video_title', 'comment_perc', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='comment_perc', ascending=False).head(10))
# Out:
#            name  \
# 3   А почитать*
# 30     PunkMonk
# 28     PunkMonk
# 25     PunkMonk
# 14     PunkMonk
# 19     PunkMonk
# 22     PunkMonk
# 12     PunkMonk
# 15     PunkMonk
# 24     PunkMonk
#
#                                                                                              video_title  \
# 3   Гузель Яхина. Эшелон на Самарканд. Плагиат, фальсификация истории, голод в Поволжье // А почитать?..
# 30                                Удар судьбы! Лучший роман ХХ века? Хрупкое равновесие Рохинтона Мистри
# 28                                                                           Лучшая повесть? Лев Толстой
# 25                                             Крестовый поход детей, Курт Воннегут и его роман Бойня №5
# 14                                                           Матрица | История альтернативной реальности
# 19                                                                                 Читать вредно?  || ЖЖ
# ...

# %% [markdown]
# ### Ажиотаж/негатив

# %% [markdown]
# Добавим ещё одну новую метрику: процент комментариев от лайков. Этот показатель поможет определить отношение активной аудитории, в каком-то смысле это **показатель ажиотажа и, возможно, негатива в комментариях**: если мы увидим "выбросы" - это повод насторожиться: в комментариях может быть не совсем дружественная дискуссия.
#
# Добавим новые данные в датафрейм:

# %%
df['comment_like_perc'] = df['comment_count'] / df['like_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Ажиотаж/негатив', fontweight='bold')

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='comment_like_perc', y='name', s=200, color=color)
plt.title('Сколько человек из 100 лайкнувших оставили комментарий', fontweight='bold')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_like_perc':'mean'})
            .sort_values(by='order'), y='name', x='comment_like_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='comment_like_perc', y='name', color=color)
plt.title('Сколько человек из 100 лайкнувших оставили комментарий', fontweight='bold')
plt.xlabel('комментарии от лайков, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_like_perc':'median'})
            .sort_values(by='order'), y='name', x='comment_like_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('комментарии от лайков, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# *автор канала Ирина Шихман признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - нельзя сказать, что на каналах есть ощутимый негатив: нет ни одного видео с метрикой свыше 50% (что обычно указывает на необычность поведения пользователей). Есть один "выброс" в рубрике "А почитать*" с метрикой около 35%. В остальном мы видим небольшие значения ажиотажа/негатива: от 3 до 16% (то есть можно сказать, что собственно ажиотажа/негатива и не замечено)
#
#
# - в среднем от 6 до 13 человек из 100 лайкнувших написали комментарий
#
# *автор канала Ирина Шихман признана иноагентом
#
# Посмотрим на выпуски с наибольшим значением метрики:

# %%
(df[['name','video_title', 'comment_like_perc', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='comment_like_perc', ascending=False).head(10))
# Out:
#            name  \
# 3   А почитать*
# 1   А почитать*
# 2   А почитать*
# 0   А почитать*
# 8   А почитать*
# 7   А почитать*
# 4   А почитать*
# 9   А почитать*
# 19     PunkMonk
# 5   А почитать*
#
#                                                                                              video_title  \
# 3   Гузель Яхина. Эшелон на Самарканд. Плагиат, фальсификация истории, голод в Поволжье // А почитать?..
# 1                                      Радмила Хакова. Как найти себя за 147 свиданий?! // А почитать?..
# 2             «Пищеблок» Алексея Иванова. Ужастик про пионеров-вампиров, мифы СССР и вечно живое прошлое
# 0                           «Риф» Алексея Поляринова. Секты, культы, религии, память // А поговорить?...
# 8                         1984 - история самой продаваемой книги в России // Джордж Оруэлл «А почитать?»
# 7           Как «Пост» Дмитрия Глуховского* предсказал судьбу России. И что будет дальше? // А почитать?
# ...

# %% [markdown]
# *автор канала Ирина Шихман и писатель Дмитрий Глуховский признаны иноагентами

# %% [markdown]
# ### Ищем взаимосвязи (корреляция)

# %% [markdown]
# Теперь посмотрим, какие признаки взаимосвязаны между собой:

# %%
plt.figure(figsize=(20,10))
sns.set(font_scale=1.2)
plt.style.use('seaborn-white')
plt.title('Корреляция признаков', fontweight='bold', y=1.02)

table = df.drop(columns=['view_count_mln'])
table['year'] = df['upload_year'] = pd.to_datetime(df['upload_date']).dt.year

corr_m = table.corr()

sns.heatmap(data=corr_m, square=True, annot=True, cmap='PuBuGn', fmt=".2f", linewidths=3, linecolor='white', 
            mask=np.triu(corr_m))
plt.show();

# %% [markdown]
# **Вывод**:
#
# Мы видим несколько сильных взаимосвязей, например:
# - с увеличением количества просмотров значительно растёт количество лайков, комментариев, подписчиков
# - реакции обсуждения и ажиотажа/негатива в комментариях тесно связаны между собой
#
# Все эти взаимосвязи (и несколько других схожих по логике) вполне ожидаемы, они, можно сказать, технически связаны между собой.
#
# Но есть ещё одна небольшая корреляция, которая представляет интерес:
# - при увеличении длины видео несколько падает реакция одобрения

# %% [markdown]
# ### Длительность видео и реакция аудитории

# %% [markdown]
# Ранее мы заметили, что аудитория часто любит короткие видео. Рассмотрим эту ситуацию подробнее.

# %%
plt.figure(figsize=(20, 6))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Продолжительность видео и реакция аудитории', fontweight='bold', y=1.02)

df['duration_minutes'] = df['duration_seconds'] / 60

ax=sns.scatterplot(data=df, x='duration_minutes', y='name', 
                    hue='like_perc', size="view_count", sizes=(100, 500), palette='PuBuGn_r')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('размер - интерес, цвет - одобрение', y=1.02)
plt.xlabel('продолжительность видео в минутах')
plt.ylabel('')

plt.show();

# %% [markdown]
# *автор канала Ирина Шихман признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - каналы существуют в разных форматах: "А почитать*" выпускает продолжительные видео от 70 до 140 минут, а "PunkMonk" выпускает много видео небольшой длины (около 20 минут, около 60 минут, и редко более 100 минут)
#
#
# - аудитория проявляет максимальное одобрение к небольшим по длине видео
#
# *автор канала Ирина Шихман признана иноагентом

# %% [markdown]
# ### Год выхода и реакция аудитории

# %%
plt.figure(figsize=(20, 6))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Дата выпуска видео и реакция аудитории', fontweight='bold', y=1.02)

ax=sns.scatterplot(data=df, x='upload_date', y='name', 
                    hue='like_perc', size="view_count", sizes=(100, 500), palette='PuBuGn_r')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('размер - интерес, цвет - одобрение', y=1.02)
plt.xlabel('время выхода видео')
plt.ylabel('')

plt.show();

# %% [markdown]
# *автор канала Ирина Шихман признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - мы не видим одной устойчивой тенденции в изменении отношение аудитории с годами, но, похоже "золотое" время для каналов было в период конца 2021 - начала 2022 годов

# %% [markdown]
# ### Реакция аудитории по годам

# %% [markdown]
# Посмотрим, как изменялись главные показатели реакции аудитории с течением времени:

# %%
plt.figure(figsize=(20, 12))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Изменение отношения аудитории', fontweight='bold')

ax1=plt.subplot(4, 3, 1)
sns.lineplot(data=df.query('name == "А почитать*"'), x='upload_date',  y='view_count_mln', 
             color=color, linewidth=3)
plt.title("А почитать*: интерес", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('просмотры, млн')

ax2=plt.subplot(4, 3, 2)
sns.lineplot(data=df.query('name == "А почитать*"'), x='upload_date', y='like_perc', 
             color=color, linewidth=3)
plt.title("А почитать*: одобрение", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% одобрения')

ax3=plt.subplot(4, 3, 3)
sns.lineplot(data=df.query('name == "А почитать*"'), x='upload_date', y='comment_like_perc', 
             color=color, linewidth=3)
plt.title("А почитать*: ажиотаж/негатив", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% ажиотажа')

ax4=plt.subplot(4, 3, 4, sharey=ax1, sharex=ax1)
sns.lineplot(data=df.query('name == "PunkMonk"'), x='upload_date',  y='view_count_mln', 
             color=color, linewidth=3)
plt.title("PunkMonk: интерес", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('просмотры, млн')

ax5=plt.subplot(4, 3, 5, sharey=ax2, sharex=ax2)
sns.lineplot(data=df.query('name == "PunkMonk"'), x='upload_date', y='like_perc', 
             color=color, linewidth=3)
plt.title("PunkMonk: одобрение", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% одобрения')

ax6=plt.subplot(4, 3, 6, sharey=ax3, sharex=ax3)
sns.lineplot(data=df.query('name == "PunkMonk"'), x='upload_date', y='comment_like_perc', 
             color=color, linewidth=3)
plt.title("PunkMonk: ажиотаж/негатив", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% ажиотажа')

plt.tight_layout()
plt.show();

# %% [markdown]
# *автор канала Ирина Шихман признана иноагентом

# %% [markdown]
# - мы видим, что рубрика "А почитать*" собирает больше просмотров, и привлекает бОльший интерес и иногда вызывает небольшой ажиотаж у публики. А канал "PunkMonk" имеет значительно бОльшее одобрение

# %% [markdown]
# ## Выводы

# %% [markdown]
# **Главные цифры**:
#
# - рубрика "А почитать*" находится в крупном по числу подписчиков канале - у канала "А поговорить*" более 2.5 млн подписчиков. И это чень большой разрыв с каналом PunkMonk - здесь около 100 тыс. подписчиков
#
#
# - однако по суммарному числу просмотров разрыв между каналами не такой большой: 9 млн у "А почитать*" и 4.5 млн у "PunkMonk"
#
#
# - по числу видео и вовсе канал "PunkMonk" опережает книжную рубрику Ирины Шихман*: 31 против 10 видео
#
#
# **Даты появления видео**:
#
# - каналы созданы практически одновременно - в начале 2021 года
#
#
# - в рубрике "А почитать*" видео выходят с перерывами, иногда с большими. А на канале "PunkMonk" с конца 2021 года выпуски выходят достаточно часто
#
# **Интерес**:
#
# - видео на каналах значительно отличаются по количеству просмотров: от 350 тысяч до 2.3 млн на канале Шихман*, до 400 тысяч на канале PunkMonk
#
#
# - на первый взгляд "А почитать*" находится в более выгодном положении. Но есть интересный момент: если мы вспомним количество подписчиков, то мы поймём, что на канале Ирины Шихман* далеко не все подписчики смотрят книжную рубрику (в среднем в лучшем случае только каждый 3 подписчик), в то время как канал "PunkMonk" иногда превосходит по просмотрам свою аудиторию
#
# **Вовлечение**:
#
# - у канала "PunkMonk" более устойчивая и лояльная аудитория - в среднем процент вовлечения около 100%, а бывает и больше - до 300%
#
#
# - в рубрике "А почитать*" метрика в среднем составляет примерно 30% - далеко не все подписчики канала "А поговорить*" смотрят книжную рубрику, даже максимальное значение только на уровне 90%
#
# **Одобрение**:
#
# - мы видим очень большую разницу в одобрении аудитории: на небольшом специализированном канале уровень одобрения от 4 до 12%, а в книжной рубрике большого неспециализированного канала этот уровень от 2 до 4%
#
#
# - в среднем каждый 3-й зритель "А почитать*" ставит лайк просмотренному видео, и каждый 7-й зритель - на канале "PunkMonk" (и это пока лучший результат за мою историю наблюдений)
#
# - складывается впечатление, что максимум одобрения имеют средне-небольшие по длине ролики - большинство имеют длину от 12 до 26 минут
#
#
# - также можно отметить, что эти видео часто имеют довольно небольшое количество просмотров - из 10 видео только 2 набрали более сотни тысяч просмотров
#
# **Обсуждение**:
#
# - в среднем поведение пользователей на каналах похоже, 3-4 человека из 1000 посмотревших оставляют комментарий. Ддя сравнения: это в целом чуть более активное поведение зрителей по сравнению с другими сферами: на каналах с интервью или про финансы в среднем 2 человека из 1000 посмотревших пишут комментарии
#
#
# - однако заметим, что на канале Ирины Шихман* в целом поведение зрителей менее активное, и есть один очень выдающийся "выброс"
#
# **Ажиотаж/негатив**:
#
# - нельзя сказать, что на каналах есть ощутимый негатив: нет ни одного видео с метрикой свыше 50% (что обычно указывает на необычность поведения пользователей). Есть один "выброс" в рубрике "А почитать*" с метрикой около 35%. В остальном мы видим небольшие значения ажиотажа/негатива: от 3 до 16% (то есть можно сказать, что собственно ажиотажа/негатива и не замечено)
#
#
# - в среднем от 6 до 13 человек из 100 лайкнувших написали комментарий
#
# **Взаимосвязи**:
#
# Мы видим несколько сильных взаимосвязей, например:
# - с увеличением количества просмотров значительно растёт количество лайков, комментариев, подписчиков
# - реакции обсуждения и ажиотажа/негатива в комментариях тесно связаны между собой
#
# Все эти взаимосвязи (и несколько других схожих по логике) вполне ожидаемы, они, можно сказать, технически связаны между собой.
#
# Но есть ещё одна небольшая корреляция, которая представляет интерес:
# - при увеличении длины видео несколько падает реакция одобрения
#
# **Длительность видео и реакция аудитории**:
#
# - каналы существуют в разных форматах: "А почитать*" выпускает продолжительные видео от 70 до 140 минут, а "PunkMonk" выпускает много видео небольшой длины (около 20 минут, около 60 минут, и редко более 100 минут)
#
#
# - аудитория проявляет максимальное одобрение к небольшим по длине видео
#
# **Год выхода и реакция аудитории**:
#
# - мы не видим одной устойчивой тенденции в изменении отношение аудитории с годами, но, похоже "золотое" время для каналов было в период конца 2021 - начала 2022 годов
#
# **Реакция аудитории по годам**:
#
# - мы видим, что рубрика "А почитать*" собирает больше просмотров, и привлекает бОльший интерес и иногда вызывает небольшой ажиотаж у публики. А канал "PunkMonk" имеет значительно бОльшее одобрение
#
#
# **Таким образом** мы выяснили, что:
# - не обязательно большому количеству просмотров сопутствует большое одобрение
# - большой аудитории канала не обязательно сопутствует большое вовлечение подписчиков
# - аудитория часто одобрительнее встречает небольшие по длине видео
# - **маленький специализированный на своей теме канал может иметь более тёплый и вовлечённый приём у аудитории**
# - канал "PunkMonk" имеет на данный момент наибольший из исследованных мной каналов процент одобрения - 7%
#
# _________________________________________________________________________________________________________________
# Дата выполнения проекта: 12 мая 2023 года
#
# Исследование выполнила: аналитик данных Малахова Наталья
#
# Мой телеграм-канал: [Дневник аналитика](https://t.me/diary_musician_analyst "Дневник аналитика")
#
# Портфолио: [GitHub](https://github.com/Malakhova-Natalya "GitHub")
#
# Спасибо за внимание! 🤍
