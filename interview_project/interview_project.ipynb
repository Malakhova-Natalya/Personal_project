# %% [markdown]
# # Интервью🎙️ : сравнение нескольких видеоканалов🎬

# %% [markdown]
# ![%D0%BB%D0%BE%D0%B3%D0%BE%D1%82%D0%B8%D0%BF%D1%8B.png](attachment:%D0%BB%D0%BE%D0%B3%D0%BE%D1%82%D0%B8%D0%BF%D1%8B.png)

# %% [markdown]
# *журналисты-авторы исследуемых каналов: Юрий Дудь, Ирина Шихман, Екатерина Гордеева признаны Минюстом РФ иноагентами

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Открытие-данных" data-toc-modified-id="Открытие-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Открытие данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Главные-цифры" data-toc-modified-id="Главные-цифры-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Главные цифры</a></span></li><li><span><a href="#Даты-появления-видео" data-toc-modified-id="Даты-появления-видео-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Даты появления видео</a></span></li><li><span><a href="#Интерес" data-toc-modified-id="Интерес-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Интерес</a></span></li><li><span><a href="#Привлечение" data-toc-modified-id="Привлечение-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Привлечение</a></span></li><li><span><a href="#Одобрение" data-toc-modified-id="Одобрение-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Одобрение</a></span></li><li><span><a href="#Обсуждение" data-toc-modified-id="Обсуждение-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Обсуждение</a></span></li><li><span><a href="#Ажиотаж/негатив" data-toc-modified-id="Ажиотаж/негатив-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Ажиотаж/негатив</a></span></li><li><span><a href="#Ищем-взаимосвязи-(корреляция)" data-toc-modified-id="Ищем-взаимосвязи-(корреляция)-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Ищем взаимосвязи (корреляция)</a></span></li><li><span><a href="#Длительность-видео-и-реакция-аудитории" data-toc-modified-id="Длительность-видео-и-реакция-аудитории-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Длительность видео и реакция аудитории</a></span></li><li><span><a href="#Год-выхода-и-реакция-аудитории" data-toc-modified-id="Год-выхода-и-реакция-аудитории-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Год выхода и реакция аудитории</a></span></li><li><span><a href="#Статус-иноагента-и-реакция-аудитории" data-toc-modified-id="Статус-иноагента-и-реакция-аудитории-4.11"><span class="toc-item-num">4.11&nbsp;&nbsp;</span>Статус иноагента и реакция аудитории</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# В данном исследовании проводится ***анализ и сравнение нескольких русскоязычных видеоканалов с интервью***🎬.
#
# Это:
# - "вДудь", канал Юрия Дудя*
# - "А поговорить?", канал Ирины Шихман*
# - "Скажи Гордеевой", канал Екатерины Гордеевой*
#
# *все три журналиста признаны Минюстом РФ иноагентами
#
# **Основные задачи**:
#
# 👩‍💻 сравнить каналы между собой, используя открытые данные
#
# 💡 использовать самостоятельно придуманные метрики для раскрытия данных
#
# 👄 рассказать о каналах доступным и понятным языком
#
# 📈 визуализировать данные
#
# **Описание данных**:
#
# В исследовании используются данные из открытых источников, полученные через api youtube*. Данные были получены 5 мая 2023 года.
#
# *РКН: сайт нарушает законодательство РФ

# %% [markdown]
# ## Открытие данных

# %% [markdown]
# Импортируем необходимые библиотеки:

# %%
import pandas as pd
import os

from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

import datetime as dt
from datetime import datetime, date, timedelta
import numpy as np

# %% [markdown]
# Открываем файлы:

# %%
if os.path.exists('/datasets/video_collection/vdud_main.xlsx'):
    vdud_main = pd.read_excel('/datasets/video_collection/vdud_main.xlsx')
else:
    vdud_main = pd.read_excel('/C:/datasets/video_collection/vdud_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/vdud.xlsx'):
    vdud = pd.read_excel('/datasets/video_collection/vdud.xlsx')
else:
    vdud = pd.read_excel('/C:/datasets/video_collection/vdud.xlsx')

# %%
if os.path.exists('/datasets/video_collection/apogovorit_main.xlsx'):
    apogovorit_main = pd.read_excel('/datasets/video_collection/apogovorit_main.xlsx')
else:
    apogovorit_main = pd.read_excel('/C:/datasets/video_collection/apogovorit_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/apogovorit.xlsx'):
    apogovorit = pd.read_excel('/datasets/video_collection/apogovorit.xlsx')
else:
    apogovorit = pd.read_excel('/C:/datasets/video_collection/apogovorit.xlsx')

# %%
if os.path.exists('/datasets/video_collection/skazhi_gord_main.xlsx'):
    skazhi_gord_main = pd.read_excel('/datasets/video_collection/skazhi_gord_main.xlsx')
else:
    skazhi_gord_main = pd.read_excel('/C:/datasets/video_collection/skazhi_gord_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/skazhi_gord.xlsx'):
    skazhi_gord = pd.read_excel('/datasets/video_collection/skazhi_gord.xlsx')
else:
    skazhi_gord = pd.read_excel('/C:/datasets/video_collection/skazhi_gord.xlsx')

# %% [markdown]
# Для того, чтобы было удобно рассматривать большие числа, сделаем разделение пробелами:

# %%
class _IntArrayFormatter(pd.io.formats.format.GenericArrayFormatter):

    def _format_strings(self):
        formatter = self.formatter or (lambda x: ' {:,}'.format(x).replace(',', ' '))
        fmt_values = [formatter(x) for x in self.values]
        return fmt_values

pd.io.formats.format.IntArrayFormatter = _IntArrayFormatter

# %% [markdown]
# Для ознакомления и проверки данных будем использовать собственную функцию:

# %%
def my_check_function (dataset):
    '''Функция для ознакомления и проверки даных'''
    print('Размер датасета (количество строк, столбцов):')
    print(dataset.shape)
    print('Как выглядят случайные 5 строк:')
    display(dataset.sample(5, random_state=42))
    print()
    print('Общая информация о данных, наименования столбцов, типы данных:')
    print(dataset.info())
    print()
    print('Есть ли пропуски, сколько их:')
    print(dataset.isna().sum())
    print('Доля пропущенных значений:')
    print(dataset.isna().mean())
    print()
    print('Есть ли явные дубликаты, сколько их:')
    print(dataset.duplicated().sum())
    print('Доля явных дубликатов:')
    print(dataset.duplicated().mean())
    print()
    print('Подробное описание данных:')
    display(dataset.describe())

# %% [markdown]
# Проверяем наши данные:

# %%
my_check_function(vdud)
# Out:
# Размер датасета (количество строк, столбцов):
# (168, 8)
# Как выглядят случайные 5 строк:
#         video_id                                        video_title  \
# 137  QAvHuGRTL0A  «Ширли-мырли» – недооцененный шедевр про 90-е ...
# 30   hUNU1Quk7T8       Хлебников - лучший русский фильм-2017/ вДудь
# 119  91yZNamfN1I     Антон Долин – стыдные вопросы про кино / вДудь
# 29   Ed47sWpgvf0  Сергей Бодров - главный русский супергерой / в...
# 142  5-3v8D8mxYY  Кватания – из чего получаются клипы и кино (En...
#
#     upload_date  view_count  like_count  comment_count  duration_seconds  \
# 137  2021-10-19   4 763 364     147 067         20 112             6 247
# 30   2017-10-03   3 041 597      74 646          8 286             3 346
# 119  2020-12-02  13 094 587     314 937         33 317             8 684
# 29   2017-09-26  14 135 789     495 450         24 276             4 035
# 142  2022-02-15   3 741 297     101 825         10 388             6 602
#
#     duration
# ...

# %%
my_check_function(apogovorit)
# Out:
# Размер датасета (количество строк, столбцов):
# (313, 8)
# Как выглядят случайные 5 строк:
#         video_id                                        video_title  \
# 46   OliE_ceE2o0  Виторган: о муже Собчак, сыне Виторгана, отце ...
# 9    gmLQxWIb3lg  Шахназаров: про шиномонтажки на Мосфильме, нео...
# 206  n3Xg-nImyow  Что делать при укусе змеи? Чей яд самый опасны...
# 139  TMpTaCzbDOQ  Михаил Гельфанд. Выживут худые и глупые, и даж...
# 60   b4bFvwivSFE  Ольга Медынич. Инстаграм, Петросян, ошибки жен...
#
#     upload_date  view_count  like_count  comment_count  duration_seconds  \
# 46   2018-11-09   3 562 260      35 428          5 785             4 511
# 9    2018-02-22     138 541       1 751            728             2 040
# 206  2022-06-12     999 773      34 780          3 049             4 456
# 139  2020-11-26   5 796 538     155 154         11 867             3 897
# 60   2019-03-02     923 061      21 979          1 739             3 731
#
#     duration
# ...

# %%
my_check_function(skazhi_gord)
# Out:
# Размер датасета (количество строк, столбцов):
# (132, 8)
# Как выглядят случайные 5 строк:
#        video_id                                        video_title  \
# 56  CL9bigv1hek  Александр Асмолов: «Если враг не существует, т...
# 83  k3Ncs0anYCI  Юрий Шевчук: «Родина, вернись домой» // «Скажи...
# 19  xn_NvwvdDd4  Федор Бондарчук: «Мне жалко времени на политик...
# 31  tET2NaTWo80  Светлана Ганнушкина: «У меня нет страха, что м...
# 76  W4JSKjcteDg  Мари Давтян:  «Нам показали, что сила насилия ...
#
#    upload_date  view_count  like_count  comment_count  duration_seconds  \
# 56  2022-03-05   2 782 278     106 356         10 940             3 567
# 83  2022-07-12   5 734 532     262 016         36 866             4 363
# 19  2021-03-05   1 028 835      17 816          1 968             5 751
# 31  2021-06-22     731 632      28 358          2 456             4 701
# 76  2022-05-24   1 443 885      60 336          7 865             5 474
#
#    duration
# 56  0:59:27
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# - в данных нет пропусков, дубликатов, они пригодны для анализа
#
#
# - единственное, что нужно поправить - формат данных в столбцах upload_date и duration

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Теперь изменим форматы в нужных столбцах:

# %%
vdud['upload_date'] = pd.to_datetime(vdud['upload_date'], format='%Y-%m-%d')
apogovorit['upload_date'] = pd.to_datetime(apogovorit['upload_date'], format='%Y-%m-%d')
skazhi_gord['upload_date'] = pd.to_datetime(skazhi_gord['upload_date'], format='%Y-%m-%d')

vdud['duration'] = pd.to_datetime(vdud['duration'],format='%H:%M:%S').dt.time
apogovorit['duration'] = pd.to_datetime(apogovorit['duration'],format='%H:%M:%S').dt.time
skazhi_gord['duration'] = pd.to_datetime(skazhi_gord['duration'],format='%H:%M:%S').dt.time

# %% [markdown]
# Дополнительно добавим в таблицы данные о количестве подписчиков:

# %%
vdud['subscriber_count'] = int(vdud_main['subscriber_count']) 
apogovorit['subscriber_count'] = int(apogovorit_main['subscriber_count'])
skazhi_gord['subscriber_count'] = int(skazhi_gord_main['subscriber_count'])

# %% [markdown]
# ### Вывод

# %% [markdown]
# - данные в столбцах upload_date и duration приведены к нужным форматам
#
#
# - в таблицы с данными о видео добавлены данные о подписчиках каждого канала

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Главные цифры

# %% [markdown]
# Рассмотрим главные цифры каналов. Для этого соединим таблицы main в одну:

# %%
main = pd.concat([vdud_main, apogovorit_main, skazhi_gord_main])
main['name'] = ['вДудь*', 'А поговорить*', 'Скажи Гордеевой*']

# %% [markdown]
# Для удобства чтения графиков данные о количестве просмотров и подписчиков переведём в миллионы:

# %%
main['view_count_mln'] = main['view_count'] / 1000000
main['subscriber_count_mln'] = main['subscriber_count'] / 1000000

# %% [markdown]
# Зададим цветовое решение проекта:

# %%
color = '#c4cbe3'

# %% [markdown]
# Визуализируем наши данные:

# %%
plt.figure(figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Количество:', fontweight='bold')

main = main.sort_values(by='view_count', ascending=False)

ax1 = plt.subplot(1, 3, 1)
sns.barplot(data=main,  x='view_count_mln', y='name', color=color)
plt.title('просмотров', fontweight='bold', y=1.02)
plt.xlabel('миллионы')
plt.ylabel('')

ax2 = plt.subplot(1, 3, 2)
sns.barplot(data=main, x='subscriber_count_mln', y='name', color=color)
plt.title('подписчиков', fontweight='bold', y=1.02)
plt.xlabel('миллионы')
plt.ylabel('')

ax3 = plt.subplot(1, 3, 3)
sns.barplot(data=main, x='video_count', y='name', color=color)
plt.title('видео', fontweight='bold', y=1.02)
plt.xlabel('единицы')
plt.ylabel('')

plt.tight_layout()
plt.show();

# %% [markdown]
# *авторы каналов признаны иноагентами

# %% [markdown]
# **Вывод**:
#
# - с большим отрывом от других каналов по количеству просмотров и подписчиков выделяется канал Юрия Дудя*. Это суммарно почти 2 млрд просмотров, более 10 млн подписчиков и более 150 видео
#
#
# - у канала "А поговорить"* суммарно почти 500 млн просмотров, более 2 млн подписчиков, и очень большое количество видео - их более 300. Скорее всего, это связано с наличием shorts/тизеров/нарезок, а также с тем, что на этом канале сразу несколько направлений - рубрики наука, история, книжный клуб.
#
#
# - "Скажи Гордеевой"* имеет суммарно около 200 млн просмотров, более 1.5 млн подписчиков и более 100 видео
#
# *авторы каналов признаны иноагентами

# %% [markdown]
# ### Даты появления видео

# %% [markdown]
# Для удобства визуализации соединим наши данные в одну таблицу:

# %%
# зададим имя для использования в визуализации
vdud['name'] = 'вДудь*'
apogovorit['name'] = 'А поговорить*'
skazhi_gord['name'] = 'Скажи Гордеевой*'

# зададим порядок в соответствии с главными цифрами
vdud['order'] = 'a'
apogovorit['order'] = 'b'
skazhi_gord['order'] = 'c'

df = pd.concat([vdud, apogovorit, skazhi_gord])

# %% [markdown]
# Построим график:

# %%
plt.figure(figsize=(20, 8))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')

sns.scatterplot(data=df, x='upload_date', y='name', color=color, s=200)
plt.title('Даты появления видео на каналах', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

plt.show();

# %% [markdown]
# *авторы каналов признаны иноагентами

# %% [markdown]
# **Вывод**:
#
# - каналы имеют разное время старта, и мы видим закономерность: чем раньше начал свою деятельность канал, тем он крупнее. Каналы появились в 2017, 2018 и конце 2020 гг.

# %% [markdown]
# ### Интерес

# %% [markdown]
# Предположим, что ***просмотры - это выражение заинтересованности***.
#
# Посмотрим, как различается эта метрика у каналов.

# %% [markdown]
# Для удобства чтения графиков большие значения переведём в миллионы:

# %%
df['view_count_mln'] = df['view_count'] / 1000000

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько миллионов человек просмотрели видео', fontweight='bold', y=1.02, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='view_count_mln', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'view_count_mln':'mean'})
            .sort_values(by='order'), y='name', x='view_count_mln', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df, x='view_count_mln', y='name', color=color)
plt.title('')
plt.xlabel('просмотры, млн')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'view_count_mln':'median'})
            .sort_values(by='order'), y='name', x='view_count_mln', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('просмотры, млн')
plt.ylabel('')

plt.show()

# %% [markdown]
# *авторы каналов признаны иноагентами

# %% [markdown]
# **Вывод**:
#
# - канал Юрия Дудя* заметно отличается от каналов его коллег-девушек. Его видео набирают минимум 3-4 млн просмотров, а максимум почти 50. Среднее около 12 млн просмотров, медиана около 9 млн. Здесь видна разница - она происходит из-за "выбросов", то есть исключительных, "нашумевших" выпусков
#
#
# - каналы девушек очень похожи между собой, видео набирают от 0 до 12 млн просмотров. Среднее превышает 1.5 млн просмотров, медиана около 1 млн. Причём заметим, что канал "Скажи Гордеевой"* , который возник позднее и имеет меньшую аудиторию, по среднему количеству просмотров всё же немного обгоняет канал Ирины Шихман* . Но возможно, это связано с разнообразием форматов и тематики на канале "А поговорить"* .
#
# *авторы каналов признаны иноагентами
#
# Посмотрим на видео с наибольшими просмотрами на каждом канале:

# %%
pd.set_option('display.max_colwidth', None)
(vdud[['name','video_title', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='view_count', ascending=False).head(3))
# Out:
#        name  \
# 105  вДудь*
# 65   вДудь*
# 61   вДудь*
#
#                                                               video_title  \
# 105  Как устроена IT-столица мира / Russian Silicon Valley (English subs)
# 65                          Нагиев - пенсии, стих в Кремле (English subs)
# 61                   Ивлеева - про Элджея, секс и пластику (English subs)
#
#      view_count upload_date  duration
# 105  49 604 175  2020-04-23  03:07:33
# 65   37 380 751  2018-09-18  01:20:39
# 61   36 490 595  2018-08-21  00:59:25

# %%
(apogovorit[['name','video_title', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='view_count', ascending=False).head(3))
# Out:
#               name  \
# 100  А поговорить*
# 129  А поговорить*
# 193  А поговорить*
#
#                                                                                    video_title  \
# 100  Опасные гастроли. Максим Галкин про Путина, страну, Примадонну и Грязь // А поговорить?..
# 129         Юлия Ахмедова: биполярное расстройство, одиночество, харассмент // А поговорить?..
# 193             Ирина Хакамада. Спецоперация, смерть мужа, долги, эмиграция // А поговорить?..
#
#      view_count upload_date  duration
# 100  12 191 388  2019-12-24  02:08:36
# 129   8 274 717  2020-09-10  01:11:47
# 193   7 510 806  2022-03-19  01:19:32

# %%
(skazhi_gord[['name','video_title', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='view_count', ascending=False).head(3))
# Out:
#                 name  \
# 73  Скажи Гордеевой*
# 39  Скажи Гордеевой*
# 62  Скажи Гордеевой*
#
#                                                                           video_title  \
# 73         Артур Смольянинов: «Вся его жизнь — это спецоперация» // «Скажи Гордеевой»
# 39  Лариса Гузеева: «Лучше пару годков в тюрьме, чем мне снова 24»//«Скажи Гордеевой»
# 62           Светлана Сорокина:  «Сложные люди теперь с клеймом» // «Скажи Гордеевой»
#
#     view_count upload_date  duration
# 73   9 008 173  2022-04-28  01:41:47
# 39   5 846 814  2021-09-22  01:38:33
# 62   5 745 943  2022-03-11  00:46:00

# %% [markdown]
# ### Привлечение

# %% [markdown]
# Кроме интереса, мы можем выделить ещё ***привлечение*** пользователей на канал.
#
# Рассчитаем процент привлечения как соотношение числа подписчиков и просмотров.
#
# - ***если этот показатель небольшой*** - значит, подписчиков мало, и мало кто из посмотревших подписан на канал (например если 1 человек из 100 посмотревших подписался на канал - данная метрика покажет 1%). Это значит у канала нет устоявшейся вовлечённой аудитории, а есть много случайных зрителей
#
#
# - ***если же показатель большой*** (например из 100 посмотревших подписались 100 человек - метрика будет 100%), и значит, у канала очень лояльная аудитория.
#
#
# - ***если показатель выше 100%*** - значит, подписчики у канала есть, но они не активно просматривают видео
#
# Добавляем новые данные:

# %%
df['subscr_perc'] = df['subscriber_count'] / df['view_count'] * 100

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько человек из 100 посмотревших подписаны на канал \n (процент привлечения)', 
             fontweight='bold', y=1.04, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='subscr_perc', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'subscr_perc':'mean'})
            .sort_values(by='order'), y='name', x='subscr_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='subscr_perc', y='name', color=color)
plt.title('')
plt.xlabel('подписки от просмотров, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'subscr_perc':'median'})
            .sort_values(by='order'), y='name', x='subscr_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('подписки от просмотров, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
#
# - мы видим заметную разницу между каналами: "А поговорить"* резко выделяется и процент привлечения иногда "зашкаливает", измеряясь тысячами процентов. Это значит, что на канале есть такие видео, которые основная часть подписчиков не просматривает.
#
# *авторы каналов признаны иноагентами

# %% [markdown]
# ### Одобрение

# %% [markdown]
# Предположим, что ***одобрение*** - это не просто количество лайков, а соотношение лайков и просмотров.

# %% [markdown]
# Вычисляем данные для новой метрики - процент лайков от просмотров:

# %%
df['like_perc'] = df['like_count'] / df['view_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько человек из 100 посмотревших поставили лайк', fontweight='bold', y=1.02, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='like_perc', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'like_perc':'mean'})
            .sort_values(by='order'), y='name', x='like_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='like_perc', y='name', color=color)
plt.title('')
plt.xlabel('лайки от просмотров, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'like_perc':'median'})
            .sort_values(by='order'), y='name', x='like_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('лайки от просмотров, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
#
# - с одной стороны, есть что-то общее между реакцией аудитории - наиболее часто от 2 до 4 человек из 100 посмотревших ставят лайк. Поэтому и среднее/медиана тоже находятся в одном, сопоставимом диапазоне - одобрение составляет от 2.5 до 3.5%.
#
#
# - но мы видим и разницу - и в распределении данных, и в точных значениях среднего/медианного процента одобрения. Канал Екатерины Гордеевой* опережает другие каналы. В среднем более 3 человек из 100 посмотревших ставят лайк её выпускам. Объяснения этому может быть два: на одобрение влияет либо сам контент, либо чуть более скромный размер аудитории.
#
# - у канала Ирины Шихман* есть ряд видео, которые имеют невысокое одобрение. Возможно, это связано с её экспериментами с форматами.
#
# *авторы каналов признаны иноагентами
#
# Посмотрим, какие видео получили максимум одобрения:

# %%
(df[['name','video_title', 'like_perc', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='like_perc', ascending=False).head(10))
# Out:
#                  name  \
# 118  Скажи Гордеевой*
# 243     А поговорить*
# 179     А поговорить*
# 186     А поговорить*
# 218     А поговорить*
# 182     А поговорить*
# 267     А поговорить*
# 233     А поговорить*
# 189     А поговорить*
# 141     А поговорить*
#
#                                                                                   video_title  \
# 118                         Юрий Шевчук впервые читает стихотворение «Родина, вернись домой!»
# 243                             Четыре аргумента в пользу цензуры // История. А поговорить?..
# 179                            История Max Factor. Как парикмахер из Рязани изменил Голливуд?
# 186  «Помоги милиции - побей себя сам». Веселая революция гномов // История. А поговорить?...
# 218      «Солдаты, не подчиняйтесь жестокости!» Комик против диктатора. История Чарли Чаплина
# 182                              Сталин «украл» рождество? Почему наш Новый год именно такой?
# ...

# %% [markdown]
# - складывается впечатление, что максимум одобрения имеют небольшие по длине ролики - на первом месте мы видим минутный shorts, и далее из 10 наиболее одобряемых видео большинство имеют длину около 20-35 минут, и только одно интервью длиной в час
#
#
# - также можно отметить, что эти видео часто имеют довольно небольшое количество просмотров - из 10 видео только 3 "миллионника"
#
#
# - и все они выложены в последние годы

# %% [markdown]
# ### Обсуждение

# %% [markdown]
# Добавляем данные для ещё одной новой метрики - процент комментариев от просмотров покажет нам, насколько видео обсуждаемые:

# %%
df['comment_perc'] = df['comment_count'] / df['view_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько человек из 100 посмотревших оставили комментарий', fontweight='bold', y=1.02, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='comment_perc', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_perc':'mean'})
            .sort_values(by='order'), y='name', x='comment_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='comment_perc', y='name', color=color)
plt.title('')
plt.xlabel('комментарии от просмотров, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_perc':'median'})
            .sort_values(by='order'), y='name', x='comment_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('комментарии от просмотров, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
#
# - по активности аудитории в комментариях все каналы более-менее схожи между собой: аудитория крайне не активно обсуждает видео, редко когда и 1 человек из 100 посмотревших оставляет комментарий. Подобное поведение характерно и не только для каналов с интервью - например, развлекательно-образовательный контент (каналы онлайн-школ английского языка Skyeng и т.п.) тоже имеет низкие показатели обсуждения, очень похожие на эти данные
#
#
# - среднее и медиана говорят нам о том, что около 3 человек из 1000 тысячи посмотревших оставляют свой комментарий
#
#
# - мы видим схожесть с реакцией одобрения: канал Екатерины Гордеевой* опережает другие, а канал Ирины Шихман* немного отстаёт (возможно, по тем же причинам, что написаны про реакцию одобрения)
#
# *авторы каналов признаны иноагентами
#
# Посмотрим, какие выпуски имеют наибольший показатель обсуждения:

# %%
(df[['name','video_title', 'comment_perc', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='comment_perc', ascending=False).head(10))
# Out:
#                  name  \
# 59   Скажи Гордеевой*
# 129  Скажи Гордеевой*
# 180     А поговорить*
# 162            вДудь*
# 131  Скажи Гордеевой*
# 212     А поговорить*
# 46   Скажи Гордеевой*
# 64   Скажи Гордеевой*
# 75   Скажи Гордеевой*
# 68   Скажи Гордеевой*
#
#                                                                                               video_title  \
# 59                                 Елена Драпеко: «Это называется превентивный удар» // «Скажи Гордеевой»
# 129                            Эдуард Бояков: «Путина любят. И в этом ваша проблема» // «Скажи Гордеевой»
# 180         Екатерина Мизулина: Моргенштерн - проект Запада, Дудь пропагандирует зло, Михалкову можно всё
# 162                       Разговор с тем, кто поддерживает армию России / The supporter of Russian troops
# 131                                              «Мама, ты не перебьёшь эту систему» // «Скажи Гордеевой»
# ...

# %% [markdown]
# - в отличие от реакции одобрения, здесь мы видим список из продолжительных видео, за исключением первого номера это интервью длиной час, два и даже больше
#
#
# - есть и схожесть с реакцией одобрения: все видео выпущены в последние годы
#
#
# - в остальном: "выводы у нас на канале вы делаете сами"

# %% [markdown]
# ### Ажиотаж/негатив

# %% [markdown]
# Добавим ещё одну новую метрику: процент комментариев от лайков. Этот показатель поможет определить отношение активной аудитории, в каком-то смысле это **показатель ажиотажа и, возможно, негатива в комментариях**: если мы увидим "выбросы" - это повод насторожиться: в комментариях может быть не совсем дружественная дискуссия.
#
# Добавим новые данные в датафрейм:

# %%
df['comment_like_perc'] = df['comment_count'] / df['like_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько человек из 100 лайкнувших оставили комментарий', fontweight='bold', y=1.02, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='comment_like_perc', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_like_perc':'mean'})
            .sort_values(by='order'), y='name', x='comment_like_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='comment_like_perc', y='name', color=color)
plt.title('')
plt.xlabel('комментарии от лайков, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_like_perc':'median'})
            .sort_values(by='order'), y='name', x='comment_like_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('комментарии от лайков, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
#
# - кажется, у нас есть не просто ажиотаж, но и негатив в комментариях, и он встречается на всех каналах. Есть видео, где свыше 50 человек из 100 лайкнувших оставили свои комментарии. Есть даже случай, когда комментариев больше, чем лайков (130 на канале "Скажи Гордеевой"* ). Это явное исключение из привычного поведения пользователей, когда много просмотров, на порядок меньше лайков, и ещё на порядок меньше комментариев.
#
#
# - среднее и медиана говорят нам, что стандартно от 10 до 13 человек из 100 лайкнувших оставляют комментарий
#
# *авторы каналов признаны иноагентами
#
# Посмотрим на выпуски, где возможен не просто ажиотаж, но негатив в комментариях:

# %%
(df[['name','video_title', 'comment_like_perc', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='comment_like_perc', ascending=False).head(10))
# Out:
#                  name  \
# 59   Скажи Гордеевой*
# 129  Скажи Гордеевой*
# 23      А поговорить*
# 162            вДудь*
# 45      А поговорить*
# 75             вДудь*
# 68   Скажи Гордеевой*
# 98      А поговорить*
# 212     А поговорить*
# 180     А поговорить*
#
#                                                                                               video_title  \
# 59                                 Елена Драпеко: «Это называется превентивный удар» // «Скажи Гордеевой»
# 129                            Эдуард Бояков: «Путина любят. И в этом ваша проблема» // «Скажи Гордеевой»
# 23                                           Дмитрий Певцов: 75% ворья - это нормально // А поговорить?..
# 162                       Разговор с тем, кто поддерживает армию России / The supporter of Russian troops
# 45      Мария Захарова: о грубых формулировках, чеченских геях, поэзии, муже и Украине // А поговорить?..
# ...

# %% [markdown]
# - как и в случае с обсуждением, мы видим в основном продолжительные интервью длиной 1-2 часа
#
#
# - в отличие от предыдущих метрик, здесь мы видим видео не только последних лет, но и выпуски 2018, 2019 годов
#
#
# - в основном эти видео имеют широкий охват и имеют по нескольку миллионов просмотров
#
#
# *авторы каналов признаны иноагентами

# %% [markdown]
# ### Ищем взаимосвязи (корреляция)

# %% [markdown]
# Теперь посмотрим, какие признаки взаимосвязаны между собой:

# %%
plt.figure(figsize=(20,10))
sns.set(font_scale=1.2)
plt.style.use('seaborn-white')
plt.title('Корреляция признаков', fontweight='bold', y=1.02)

table = df.drop(columns=['view_count_mln'])
table['year'] = df['upload_year'] = pd.to_datetime(df['upload_date']).dt.year

corr_m = table.corr()

sns.heatmap(data=corr_m, square=True, annot=True, cmap='PuBuGn', fmt=".2f", linewidths=3, linecolor='white', 
            mask=np.triu(corr_m))
plt.show();

# %% [markdown]
# **Вывод**:
#
# Мы видим несколько сильных взаимосвязей:
# - с увеличением количества просмотров значительно растёт количество лайков, комментариев и подписчиков
# - с увеличением количества лайков растёт количество комментариев и подписчиков
# - реакции обсуждения и ажиотажа/негатива в комментариях тесно связаны между собой
#
# Все эти взаимосвязи вполне ожидаемы, они, можно сказать, технически связаны между собой.

# %% [markdown]
# ### Длительность видео и реакция аудитории

# %% [markdown]
# Ранее из раздела про одобрение мы заметили, что аудитория часто любит короткие видео. Рассмотрим эту ситуацию подробнее.

# %%
plt.figure(figsize=(20, 8))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Продолжительность видео и реакция аудитории', fontweight='bold', y=1.02)

df['duration_minutes'] = df['duration_seconds'] / 60

ax=sns.scatterplot(data=df, x='duration_minutes', y='name', 
                    hue='like_perc', size="view_count", sizes=(100, 500), palette='PuBuGn_r')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('размер - интерес, цвет - одобрение', y=1.02)
plt.xlabel('продолжительность видео в минутах')
plt.ylabel('')

plt.show();

# %% [markdown]
# **Вывод**:
#
# - мы не видим устойчивой тенденции к тому, что именно длина видео влияет на интерес и одобрение. Но есть небольшой ряд непродолжительных видео на канале "А поговорить"* , который имеет более высокий уровень одобрения (более светлый оттенок). Возможно, на самом деле мы видим здесь одобрительную реакцию аудитории на некоторый формат, отличающийся по содержанию от ставшего привычным продолжительного интервью
#
#
# - а ещё мы видим, что на каналах девушек есть короткий формат shorts (видео около 1 минуты), а у Юрия Дудя* нет
#
# *авторы каналов признаны иноагентами

# %% [markdown]
# ### Год выхода и реакция аудитории

# %%
plt.figure(figsize=(20, 8))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Дата выпуска видео и реакция аудитории', fontweight='bold', y=1.02)

ax=sns.scatterplot(data=df, x='upload_date', y='name', 
                    hue='like_perc', size="view_count", sizes=(100, 500), palette='PuBuGn_r')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('размер - интерес, цвет - одобрение', y=1.02)
plt.xlabel('время выхода видео')
plt.ylabel('')

plt.show();

# %% [markdown]
# **Вывод**:
#
# - а вот здесь мы уже можем наблюдать тенденцию: с годами оттенок зачастую меняется - аудитория реагирует одобрительнее. Это видно на каналах девушек, особенно на примере "А поговорить"* . У Юрия Дудя* более смешанная картина, возможно, имеет значение очень большой размер аудитории - его видео смотрят не только люди его взглядов
#
#
# - на этом графике мы видим, какой прогресс сделала Ирина Шихман*, особенно впечатляет 2023 год (есть ряд очень светлых видео)
#
# *авторы каналов признаны иноагентами

# %% [markdown]
# ### Статус иноагента и реакция аудитории

# %% [markdown]
# Посмотрим, как изменились главные показатели реакции аудитории после объявления авторов каналов иноагентами. Пунктирной линией отметим дату присвоения статуса для каждого автора индивидуально:

# %%
plt.figure(figsize=(20, 12))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Изменение отношения аудитории после присвоения статуса иноагента', fontweight='bold')

date_status_vdud = pd.to_datetime('2022-04-15', format='%Y-%m-%d')
date_status_apogovorit = pd.to_datetime('2022-11-18', format='%Y-%m-%d')
date_status_skazhi_gord = pd.to_datetime('2022-09-02', format='%Y-%m-%d')

ax1=plt.subplot(3, 3, 1)

sns.lineplot(data=df.query('name == "вДудь*"'), x='upload_date',  y='view_count_mln', 
             color=color, linewidth=3)
plt.axvline(x=date_status_vdud, color='black', linestyle='--', label='статус иноагента')
plt.legend(loc='upper left')
plt.title("вДудь*: интерес", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('просмотры, млн')

ax2=plt.subplot(3, 3, 2)
sns.lineplot(data=df.query('name == "вДудь*"'), x='upload_date', y='like_perc', 
             color=color, linewidth=3)
plt.axvline(x=date_status_vdud, color='black', linestyle='--')
plt.title("вДудь*: одобрение", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% одобрения')

ax3=plt.subplot(3, 3, 3)
sns.lineplot(data=df.query('name == "вДудь*"'), x='upload_date', y='comment_like_perc', 
             color=color, linewidth=3)
plt.axvline(x=date_status_vdud, color='black', linestyle='--')
plt.title("вДудь*: ажиотаж/негатив", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% ажиотажа')

ax4=plt.subplot(3, 3, 4, sharey=ax1, sharex=ax1)
sns.lineplot(data=df.query('name == "А поговорить*"'), x='upload_date',  y='view_count_mln', 
             color=color, linewidth=3)
plt.axvline(x=date_status_apogovorit, color='black', linestyle='--', label='статус иноагента')
plt.legend(loc='upper left')
plt.title("А поговорить*: интерес", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('просмотры, млн')

ax5=plt.subplot(3, 3, 5, sharey=ax2, sharex=ax2)
sns.lineplot(data=df.query('name == "А поговорить*"'), x='upload_date', y='like_perc', 
             color=color, linewidth=3)
plt.axvline(x=date_status_apogovorit, color='black', linestyle='--')
plt.title("А поговорить*: одобрение", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% одобрения')

ax6=plt.subplot(3, 3, 6, sharey=ax3, sharex=ax3)
sns.lineplot(data=df.query('name == "А поговорить*"'), x='upload_date', y='comment_like_perc', 
             color=color, linewidth=3)
plt.axvline(x=date_status_apogovorit, color='black', linestyle='--')
plt.title("А поговорить*: ажиотаж/негатив", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% ажиотажа')

ax7=plt.subplot(3, 3, 7, sharey=ax1, sharex=ax1)
sns.lineplot(data=df.query('name == "Скажи Гордеевой*"'), x='upload_date',  y='view_count_mln', 
             color=color, linewidth=3)
plt.axvline(x=date_status_skazhi_gord, color='black', linestyle='--', label='статус иноагента')
plt.legend(loc='upper left')
plt.title("Скажи Гордеевой*: интерес", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('просмотры, млн')

ax8=plt.subplot(3, 3, 8, sharey=ax2, sharex=ax2)
sns.lineplot(data=df.query('name == "Скажи Гордеевой*"'), x='upload_date', y='like_perc', 
             color=color, linewidth=3)
plt.axvline(x=date_status_skazhi_gord, color='black', linestyle='--')
plt.title("Скажи Гордеевой*: одобрение", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% одобрения')

ax9=plt.subplot(3, 3, 9, sharey=ax3, sharex=ax3)
sns.lineplot(data=df.query('name == "Скажи Гордеевой*"'), x='upload_date', y='comment_like_perc', 
             color=color, linewidth=3)
plt.axvline(x=date_status_skazhi_gord, color='black', linestyle='--')
plt.title("Скажи Гордеевой*: ажиотаж/негатив", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% ажиотажа')

plt.tight_layout()
plt.show();

# %% [markdown]
# Чтобы было проще уловить тенденции, посмотрим на те же графики, но со скользящим средним (т.е. будем смотреть как менялись усреднённые значения):

# %%
plt.figure(figsize=(20, 12))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Изменение отношения аудитории после присвоения статуса иноагента: \n скользящее среднее',
             fontweight='bold')

date_status_vdud = pd.to_datetime('2022-04-15', format='%Y-%m-%d')
date_status_apogovorit = pd.to_datetime('2022-11-18', format='%Y-%m-%d')
date_status_skazhi_gord = pd.to_datetime('2022-09-02', format='%Y-%m-%d')

ax1=plt.subplot(3, 3, 1)
y = df.query('name == "вДудь*"')['view_count_mln'].rolling(window = 14).mean()
sns.lineplot(data=df.query('name == "вДудь*"'), x='upload_date',  y=y, color=color, linewidth=3)
plt.axvline(x=date_status_vdud, color='black', linestyle='--', label='статус иноагента')
plt.legend(loc='lower left')
plt.title("вДудь*: интерес", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('просмотры, млн')

ax2=plt.subplot(3, 3, 2)
y = df.query('name == "вДудь*"')['like_perc'].rolling(window = 14).mean()
sns.lineplot(data=df.query('name == "вДудь*"'), x='upload_date', y=y, color=color, linewidth=3)
plt.axvline(x=date_status_vdud, color='black', linestyle='--')
plt.title("вДудь*: одобрение", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% одобрения')

ax3=plt.subplot(3, 3, 3)
y = df.query('name == "вДудь*"')['comment_like_perc'].rolling(window = 14).mean()
sns.lineplot(data=df.query('name == "вДудь*"'), x='upload_date', y=y, color=color, linewidth=3)
plt.axvline(x=date_status_vdud, color='black', linestyle='--')
plt.title("вДудь*: ажиотаж/негатив", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% ажиотажа')

ax4=plt.subplot(3, 3, 4, sharey=ax1, sharex=ax1)
y = df.query('name == "А поговорить*"')['view_count_mln'].rolling(window = 14).mean()
sns.lineplot(data=df.query('name == "А поговорить*"'), x='upload_date',  y=y, color=color, linewidth=3)
plt.axvline(x=date_status_apogovorit, color='black', linestyle='--', label='статус иноагента')
plt.legend(loc='upper left')
plt.title("А поговорить*: интерес", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('просмотры, млн')

ax5=plt.subplot(3, 3, 5, sharey=ax2, sharex=ax2)
y = df.query('name == "А поговорить*"')['like_perc'].rolling(window = 14).mean()
sns.lineplot(data=df.query('name == "А поговорить*"'), x='upload_date', y=y, color=color, linewidth=3)
plt.axvline(x=date_status_apogovorit, color='black', linestyle='--')
plt.title("А поговорить*: одобрение", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% одобрения')

ax6=plt.subplot(3, 3, 6, sharey=ax3, sharex=ax3)
y = df.query('name == "А поговорить*"')['comment_like_perc'].rolling(window = 14).mean()
sns.lineplot(data=df.query('name == "А поговорить*"'), x='upload_date', y=y, color=color, linewidth=3)
plt.axvline(x=date_status_apogovorit, color='black', linestyle='--')
plt.title("А поговорить*: ажиотаж/негатив", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% ажиотажа')

ax7=plt.subplot(3, 3, 7, sharey=ax1, sharex=ax1)
y = df.query('name == "Скажи Гордеевой*"')['view_count_mln'].rolling(window = 14).mean()
sns.lineplot(data=df.query('name == "Скажи Гордеевой*"'), x='upload_date',  y=y, color=color, linewidth=3)
plt.axvline(x=date_status_skazhi_gord, color='black', linestyle='--', label='статус иноагента')
plt.legend(loc='upper left')
plt.title("Скажи Гордеевой*: интерес", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('просмотры, млн')

ax8=plt.subplot(3, 3, 8, sharey=ax2, sharex=ax2)
y = df.query('name == "Скажи Гордеевой*"')['like_perc'].rolling(window = 14).mean()
sns.lineplot(data=df.query('name == "Скажи Гордеевой*"'), x='upload_date', y=y, color=color, linewidth=3)
plt.axvline(x=date_status_skazhi_gord, color='black', linestyle='--')
plt.title("Скажи Гордеевой*: одобрение", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% одобрения')

ax9=plt.subplot(3, 3, 9, sharey=ax3, sharex=ax3)
y = df.query('name == "Скажи Гордеевой*"')['comment_like_perc'].rolling(window = 14).mean()
sns.lineplot(data=df.query('name == "Скажи Гордеевой*"'), x='upload_date', y=y, color=color, linewidth=3)
plt.axvline(x=date_status_skazhi_gord, color='black', linestyle='--')
plt.title("Скажи Гордеевой*: ажиотаж/негатив", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% ажиотажа')

plt.tight_layout()
plt.show();

# %% [markdown]
# - канал Юрия Дудя* пережил и новый взлёт, и некоторое падение интереса. Одобрение в среднем снизилось, а негатив возрос
#
#
# - канал "А поговорить"* потерял показатели по всем направлениям: и одобрение, и ажиотаж - в зоне турбулентности и в среднем упали. Видимо, это следствие общего падения интереса.
#
#
# - "Скажи Гордеевой"* тоже в среднем пережил падение интереса. Однако одобрение, несмотря на новый статус, только увеличивается. Ажиотаж же находится в зоне турбулентности.
#
# *авторы каналов признаны иноагентами

# %% [markdown]
# ## Выводы

# %% [markdown]
# **Главные цифры**:
#
# - с большим отрывом от других каналов по количеству просмотров и подписчиков выделяется канал Юрия Дудя*. Это суммарно почти 2 млрд просмотров, более 10 млн подписчиков и более 150 видео
#
#
# - у канала "А поговорить"* суммарно почти 500 млн просмотров, более 2 млн подписчиков, и очень большое количество видео - их более 300. Скорее всего, это связано с наличием shorts/тизеров/нарезок, а также с тем, что на этом канале сразу несколько направлений - рубрики наука, история, книжный клуб.
#
#
# - "Скажи Гордеевой"* имеет суммарно около 200 млн просмотров, более 1.5 млн подписчиков и более 100 видео
#
# **Даты появления видео**:
#
# - каналы имеют разное время старта, и мы видим закономерность: чем раньше начал свою деятельность канал, тем он крупнее. Каналы появились в 2017, 2018 и конце 2020 гг.
#
# **Интерес**:
#
# - канал Юрия Дудя* заметно отличается от каналов его коллег-девушек. Его видео набирают минимум 3-4 млн просмотров, а максимум почти 50. Среднее около 12 млн просмотров, медиана около 9 млн. Здесь видна разница - она происходит из-за "выбросов", то есть исключительных, "нашумевших" выпусков
#
#
# - каналы девушек очень похожи между собой, видео набирают от 0 до 12 млн просмотров. Среднее превышает 1.5 млн просмотров, медиана около 1 млн. Причём заметим, что канал "Скажи Гордеевой"* , который возник позднее и имеет меньшую аудиторию, по среднему количеству просмотров всё же немного обгоняет канал Ирины Шихман* . Но возможно, это связано с разнообразием форматов и тематики на канале "А поговорить"* .
#
# **Привлечение**:
#
# - мы видим заметную разницу между каналами: "А поговорить"* резко выделяется и процент привлечения иногда "зашкаливает", измеряясь тысячами процентов. Это значит, что на канале есть такие видео, которые основная часть подписчиков не просматривает.
#
# **Одобрение**:
#
# - с одной стороны, есть что-то общее между реакцией аудитории - наиболее часто от 2 до 4 человек из 100 посмотревших ставят лайк. Поэтому и среднее/медиана тоже находятся в одном, сопоставимом диапазоне - одобрение составляет от 2.5 до 3.5%.
#
#
# - но мы видим и разницу - и в распределении данных, и в точных значениях среднего/медианного процента одобрения. Канал Екатерины Гордеевой* опережает другие каналы. В среднем более 3 человек из 100 посмотревших ставят лайк её выпускам. Объяснения этому может быть два: на одобрение влияет либо сам контент, либо чуть более скромный размер аудитории.
#
# - у канала Ирины Шихман* есть ряд видео, которые имеют невысокое одобрение. Возможно, это связано с её экспериментами с форматами.
#
# - складывается впечатление, что максимум одобрения имеют небольшие по длине ролики - на первом месте мы видим минутный shorts, и далее из 10 наиболее одобряемых видео большинство имеют длину около 20-35 минут, и только одно интервью длиной в час
#
# - также можно отметить, что эти видео часто имеют довольно небольшое количество просмотров - из 10 видео только 3 "миллионника"
#
# - и все они выложены в последние годы
#
# **Обсуждение**:
#
# - по активности аудитории в комментариях все каналы более-менее схожи между собой: аудитория крайне не активно обсуждает видео, редко когда и 1 человек из 100 посмотревших оставляет комментарий. Подобное поведение характерно и не только для каналов с интервью - например, развлекательно-образовательный контент (каналы онлайн-школ английского языка Skyeng и т.п.) тоже имеет низкие показатели обсуждения, очень похожие на эти данные
#
#
# - среднее и медиана говорят нам о том, что около 3 человек из 1000 тысячи посмотревших оставляют свой комментарий
#
#
# - мы видим схожесть с реакцией одобрения: канал Екатерины Гордеевой* опережает другие, а канал Ирины Шихман* немного отстаёт (возможно, по тем же причинам, что написаны про реакцию одобрения)
#
# - в отличие от реакции одобрения, здесь мы видим список из продолжительных видео, за исключением первого номера это интервью длиной час, два и даже больше
#
# - есть и схожесть с реакцией одобрения: все видео выпущены в последние годы
#
# - в остальном: "выводы у нас на канале вы делаете сами"
#
# **Ажиотаж/негатив**:
#
# - кажется, у нас есть не просто ажиотаж, но и негатив в комментариях, и он встречается на всех каналах. Есть видео, где свыше 50 человек из 100 лайкнувших оставили свои комментарии. Есть даже случай, когда комментариев больше, чем лайков (130 на канале "Скажи Гордеевой"* ). Это явное исключение из привычного поведения пользователей, когда много просмотров, на порядок меньше лайков, и ещё на порядок меньше комментариев.
#
#
# - среднее и медиана говорят нам, что стандартно от 10 до 13 человек из 100 лайкнувших оставляют комментарий
#
# - как и в случае с обсуждением, мы видим в основном продолжительные интервью длиной 1-2 часа
#
# - в отличие от предыдущих метрик, здесь мы видим видео не только последних лет, но и выпуски 2018, 2019 годов
#
# - в основном эти видео имеют широкий охват и имеют по нескольку миллионов просмотров
#
# **Взаимосвязи**:
#
# Мы видим несколько сильных взаимосвязей:
# - с увеличением количества просмотров значительно растёт количество лайков, комментариев и подписчиков
# - с увеличением количества лайков растёт количество комментариев и подписчиков
# - реакции обсуждения и ажиотажа/негатива в комментариях тесно связаны между собой
#
# Все эти взаимосвязи вполне ожидаемы, они, можно сказать, технически связаны между собой.
#
#
# **Длительность видео и реакция аудитории**:
#
# - мы не видим устойчивой тенденции к тому, что именно длина видео влияет на интерес и одобрение. Но есть небольшой ряд непродолжительных видео на канале "А поговорить"* , который имеет более высокий уровень одобрения (более светлый оттенок). Возможно, на самом деле мы видим здесь одобрительную реакцию аудитории на некоторый формат, отличающийся по содержанию от ставшего привычным продолжительного интервью
#
#
# - а ещё мы видим, что на каналах девушек есть короткий формат shorts (видео около 1 минуты), а у Юрия Дудя* нет
#
# **Год выхода и реакция аудитории**:
#
# - а вот здесь мы уже можем наблюдать тенденцию: с годами оттенок зачастую меняется - аудитория реагирует одобрительнее. Это видно на каналах девушек, особенно на примере "А поговорить"* . У Юрия Дудя* более смешанная картина, возможно, имеет значение очень большой размер аудитории - его видео смотрят не только люди его взглядов
#
#
# - большой прогресс сделала Ирина Шихман*, особенно впечатляет 2023 год (есть ряд очень светлых видео)
#
# **Статус иноагента и реакция аудитории**:
#
# - канал Юрия Дудя* пережил и новый взлёт, и некоторое падение интереса. Одобрение в среднем снизилось, а негатив возрос
#
#
# - канал "А поговорить"* потерял показатели по всем направлениям: и одобрение, и ажиотаж - в зоне турбулентности и в среднем упали. Видимо, это следствие общего падения интереса.
#
#
# - "Скажи Гордеевой"* тоже в среднем пережил падение интереса. Однако одобрение, несмотря на новый статус, только увеличивается. Ажиотаж же находится в зоне турбулентности.
#
# В целом нельзя сказать, что присвоение статуса иноагента кардинально изменило жизнь каналов и реакцию на них аудитории - иноагентство частично снизило интерес, местами погрузило реакции одобрения и ажиотажа в зоны турбулентности. Однако заметим, что даже в этих условиях видео набирают миллионы просмотров. А у Екатерины Гордеевой* и вовсе реакция одобрения уверенно идёт вверх.
#
# *авторы каналов признаны иноагентами
#
# _________________________________________________________________________________________________________________
# Дата выполнения проекта: 6 мая 2023 года
#
# Исследование выполнила: аналитик данных Малахова Наталья
#
# Мой телеграм-канал: [Дневник аналитика](https://t.me/diary_musician_analyst "Дневник аналитика")
#
# Портфолио: [GitHub](https://github.com/Malakhova-Natalya "GitHub")
#
# Спасибо за внимание! 🤍
