# %% [markdown]
# # Финансы💰 : сравнение нескольких видеоканалов🎬

# %% [markdown]
# ![%D0%BB%D0%BE%D0%B3%D0%BE%D1%82%D0%B8%D0%BF%D1%8B%20%D1%87-%D0%B1.jpg](attachment:%D0%BB%D0%BE%D0%B3%D0%BE%D1%82%D0%B8%D0%BF%D1%8B%20%D1%87-%D0%B1.jpg)

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Открытие-данных" data-toc-modified-id="Открытие-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Открытие данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Главные-цифры" data-toc-modified-id="Главные-цифры-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Главные цифры</a></span></li><li><span><a href="#Даты-появления-видео" data-toc-modified-id="Даты-появления-видео-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Даты появления видео</a></span></li><li><span><a href="#Интерес" data-toc-modified-id="Интерес-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Интерес</a></span></li><li><span><a href="#Привлечение" data-toc-modified-id="Привлечение-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Привлечение</a></span></li><li><span><a href="#Одобрение" data-toc-modified-id="Одобрение-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Одобрение</a></span></li><li><span><a href="#Обсуждение" data-toc-modified-id="Обсуждение-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Обсуждение</a></span></li><li><span><a href="#Ажиотаж/негатив" data-toc-modified-id="Ажиотаж/негатив-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Ажиотаж/негатив</a></span></li><li><span><a href="#Ищем-взаимосвязи-(корреляция)" data-toc-modified-id="Ищем-взаимосвязи-(корреляция)-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Ищем взаимосвязи (корреляция)</a></span></li><li><span><a href="#Длительность-видео-и-реакция-аудитории" data-toc-modified-id="Длительность-видео-и-реакция-аудитории-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Длительность видео и реакция аудитории</a></span></li><li><span><a href="#Год-выхода-и-реакция-аудитории" data-toc-modified-id="Год-выхода-и-реакция-аудитории-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Год выхода и реакция аудитории</a></span></li><li><span><a href="#Реакция-аудитории-по-годам" data-toc-modified-id="Реакция-аудитории-по-годам-4.11"><span class="toc-item-num">4.11&nbsp;&nbsp;</span>Реакция аудитории по годам</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# В данном исследовании проводится ***анализ и сравнение нескольких русскоязычных видеоканалов о финансах***🎬.
#
# Это каналы:
# - Forbes (Forbes Russia)
# - "Деньги не спят"
# - "Это Осетинская*"
# - Private Talks
#
# *Елизавета Осетинская признана Минюстом РФ иноагентом
#
# **Основные задачи**:
#
# 👩‍💻 сравнить каналы между собой, используя открытые данные
#
# 💡 использовать самостоятельно придуманные метрики для раскрытия данных
#
# 👄 рассказать о каналах доступным и понятным языком
#
# 📈 визуализировать данные
#
# **Описание данных**:
#
# В исследовании используются данные из открытых источников, полученные через api youtube*. Данные были получены 8 мая 2023 года.
#
# *РКН: сайт нарушает законодательство РФ

# %% [markdown]
# ## Открытие данных

# %% [markdown]
# Импортируем необходимые библиотеки:

# %%
import pandas as pd
import os

from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

import datetime as dt
from datetime import datetime, date, timedelta
import numpy as np

# %% [markdown]
# Открываем файлы:

# %%
if os.path.exists('/datasets/video_collection/forbes_main.xlsx'):
    forbes_main = pd.read_excel('/datasets/video_collection/forbes_main.xlsx')
else:
    forbes_main = pd.read_excel('/C:/datasets/video_collection/forbes_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/forbes.xlsx'):
    forbes = pd.read_excel('/datasets/video_collection/forbes.xlsx')
else:
    forbes = pd.read_excel('/C:/datasets/video_collection/forbes.xlsx')

# %%
if os.path.exists('/datasets/video_collection/dengi_ne_spyat_main.xlsx'):
    dengi_ne_spyat_main = pd.read_excel('/datasets/video_collection/dengi_ne_spyat_main.xlsx')
else:
    dengi_ne_spyat_main = pd.read_excel('/C:/datasets/video_collection/dengi_ne_spyat_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/dengi_ne_spyat.xlsx'):
    dengi_ne_spyat = pd.read_excel('/datasets/video_collection/dengi_ne_spyat.xlsx')
else:
    dengi_ne_spyat = pd.read_excel('/C:/datasets/video_collection/dengi_ne_spyat.xlsx')

# %%
if os.path.exists('/datasets/video_collection/osetinskaya_main.xlsx'):
    osetinskaya_main = pd.read_excel('/datasets/video_collection/osetinskaya_main.xlsx')
else:
    osetinskaya_main = pd.read_excel('/C:/datasets/video_collection/osetinskaya_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/osetinskaya.xlsx'):
    osetinskaya = pd.read_excel('/datasets/video_collection/osetinskaya.xlsx')
else:
    osetinskaya = pd.read_excel('/C:/datasets/video_collection/osetinskaya.xlsx')

# %%
if os.path.exists('/datasets/video_collection/private_main.xlsx'):
    private_main = pd.read_excel('/datasets/video_collection/private_main.xlsx')
else:
    private_main = pd.read_excel('/C:/datasets/video_collection/private_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/private.xlsx'):
    private = pd.read_excel('/datasets/video_collection/private.xlsx')
else:
    private = pd.read_excel('/C:/datasets/video_collection/private.xlsx')

# %% [markdown]
# Объединим данные о разных каналах:

# %%
main = pd.concat([forbes_main, dengi_ne_spyat_main, osetinskaya_main, private_main])
main['name'] = ['Forbes', 'Деньги не спят', 'Это Осетинская*', 'Private Talks']

# зададим имя 
forbes['name'] = 'Forbes'
dengi_ne_spyat['name'] = 'Деньги не спят'
osetinskaya['name'] = 'Это Осетинская*'
private['name'] = 'Private Talks'

# зададим порядок 
forbes['order'] = 'a'
dengi_ne_spyat['order'] = 'b'
osetinskaya['order'] = 'c'
private['order'] = 'd'

# добавим данные о количестве подписчиков
forbes['subscriber_count'] = int(forbes_main['subscriber_count']) 
dengi_ne_spyat['subscriber_count'] = int(dengi_ne_spyat_main['subscriber_count'])
osetinskaya['subscriber_count'] = int(osetinskaya_main['subscriber_count'])
private['subscriber_count'] = int(private_main['subscriber_count'])

df = pd.concat([forbes, dengi_ne_spyat, osetinskaya, private])

# %% [markdown]
# Для того, чтобы было удобно рассматривать большие числа, сделаем разделение пробелами:

# %%
class _IntArrayFormatter(pd.io.formats.format.GenericArrayFormatter):

    def _format_strings(self):
        formatter = self.formatter or (lambda x: ' {:,}'.format(x).replace(',', ' '))
        fmt_values = [formatter(x) for x in self.values]
        return fmt_values

pd.io.formats.format.IntArrayFormatter = _IntArrayFormatter

# %% [markdown]
# Для ознакомления и проверки данных будем использовать собственную функцию:

# %%
def my_check_function (dataset):
    '''Функция для ознакомления и проверки даных'''
    print('Размер датасета (количество строк, столбцов):')
    print(dataset.shape)
    print('Как выглядят случайные 5 строк:')
    display(dataset.sample(5, random_state=42))
    print()
    print('Общая информация о данных, наименования столбцов, типы данных:')
    print(dataset.info())
    print()
    print('Есть ли пропуски, сколько их:')
    print(dataset.isna().sum())
    print('Доля пропущенных значений:')
    print(dataset.isna().mean())
    print()
    print('Есть ли явные дубликаты, сколько их:')
    print(dataset.duplicated().sum())
    print('Доля явных дубликатов:')
    print(dataset.duplicated().mean())
    print()
    print('Подробное описание данных:')
    display(dataset.describe())

# %% [markdown]
# Проверяем наши данные:

# %%
my_check_function(df)
# Out:
# Размер датасета (количество строк, столбцов):
# (824, 11)
# Как выглядят случайные 5 строк:
#         video_id                                        video_title  \
# 4    trnje_i0dQ0  Евгений Чичваркин - о новом проекте, `мишленов...
# 174  dEcSj-2_Wl4  БУСТЕР - как орать в Twitch и зарабатывать мил...
# 67   b3SOIDQ-bR4  «Биохакеры — самые приятные люди»: Александр О...
# 168  1riY8VTHK54  УТЯШЕВА: величие Винер, молодой Усманов, личны...
# 275  8krmAC_l9Ng  Биткойн всех обманул - Что с криптовалютой в 2...
#
#     upload_date  view_count  like_count  comment_count  duration_seconds  \
# 4    2018-04-16     172 706       2 536            297               668
# 174  2021-06-02     239 767      11 751            318             4 658
# 67   2020-01-03      72 420         387             49             2 357
# 168  2021-04-25     168 531       3 126            298             4 736
# 275  2023-01-19      88 289       2 217            268             5 394
#
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# - в данных нет пропусков, дубликатов, они пригодны для анализа
#
#
# - единственное, что нужно поправить - формат данных в столбцах upload_date и duration

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Теперь изменим форматы в нужных столбцах:

# %%
df['upload_date'] = pd.to_datetime(df['upload_date'], format='%Y-%m-%d')

df['duration'] = pd.to_datetime(df['duration'],format='%H:%M:%S').dt.time

# %% [markdown]
# ### Вывод

# %% [markdown]
# - данные в столбцах upload_date и duration приведены к нужным форматам

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Главные цифры

# %% [markdown]
# Для удобства чтения графиков данные о количестве просмотров и подписчиков переведём в миллионы:

# %%
main['view_count_mln'] = main['view_count'] / 1000000
main['subscriber_count_mln'] = main['subscriber_count'] / 1000000

# %% [markdown]
# Зададим цветовое решение проекта:

# %%
color = '#c4cbe3'

# %% [markdown]
# Визуализируем наши данные:

# %%
plt.figure(figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Количество:', fontweight='bold')

ax1 = plt.subplot(1, 3, 1)
sns.barplot(data=main,  x='view_count_mln', y='name', color=color)
plt.title('просмотров', fontweight='bold', y=1.02)
plt.xlabel('миллионы')
plt.ylabel('')

ax2 = plt.subplot(1, 3, 2)
sns.barplot(data=main, x='subscriber_count_mln', y='name', color=color)
plt.title('подписчиков', fontweight='bold', y=1.02)
plt.xlabel('миллионы')
plt.ylabel('')

ax3 = plt.subplot(1, 3, 3)
sns.barplot(data=main, x='video_count', y='name', color=color)
plt.title('видео', fontweight='bold', y=1.02)
plt.xlabel('единицы')
plt.ylabel('')

plt.tight_layout()
plt.show();

# %% [markdown]
# *Елизавета Осетинская признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - с большим отрывом от других каналов по количеству просмотров выделяется канал Forbes. Это суммарно более 110 млн просмотров. По 50 млн просмотров у каналов "Деньги не спят" и "Это Осетинская*", менее 5 млн просмотров у Private Talks.
#
#
# - каналы имеют небольшое количество подписчиков (ни у кого нет миллиона подписчиков) - от 160 до почти 600 тысяч подписчиков максимум
#
#
# - количество видео: от 60 до 340
#
# *Елизавета Осетинская признана иноагентом

# %% [markdown]
# ### Даты появления видео

# %%
plt.figure(figsize=(20, 8))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')

sns.scatterplot(data=df, x='upload_date', y='name', color=color, s=200)
plt.title('Даты появления видео на каналах', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

plt.show();

# %% [markdown]
# *Елизавета Осетинская признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - каналы созданы в период с 2018 по 2021 год
#
#
# - общую закономерность "чем старше канал - тем больше видео, подписчиков, просмотров" ломает канал Елизаветы Осетинской*. Канал создан в 2018 году, а канал "деньги не спят" через 1.5 года, в конце 2019. Однако более новый канал смог догнать тот же уровень по просмотрам и подписчикам

# %% [markdown]
# ### Интерес

# %% [markdown]
# Предположим, что ***просмотры - это выражение заинтересованности***.
#
# Посмотрим, как различается эта метрика у каналов.

# %% [markdown]
# Для удобства чтения графиков большие значения переведём в миллионы:

# %%
df['view_count_mln'] = df['view_count'] / 1000000

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько миллионов человек просмотрели видео', fontweight='bold', y=1.02, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='view_count_mln', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'view_count_mln':'mean'})
            .sort_values(by='order'), y='name', x='view_count_mln', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df, x='view_count_mln', y='name', color=color)
plt.title('')
plt.xlabel('просмотры, млн')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'view_count_mln':'median'})
            .sort_values(by='order'), y='name', x='view_count_mln', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('просмотры, млн')
plt.ylabel('')

plt.show()

# %% [markdown]
# *Елизавета Осетинская признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - средние и медианы говорят нам о том, что в основном видео набирают от 20 до 350 тысяч просмотров. Более стабильно набирают просмотры "Деньги не спят" и "Это Осетинская*" (медианы почти 200 тысяч просмотров). Выпуски с более широким охватом случаются на каналах Forbes и "Это Осетинская*" (среднее более 300 тысяч просмотров)
#
#
# - на каналах Forbes и "Это Осетинская" есть "выбросы" - выделяющиеся по просмотрам видео, набравшие миллионы просмотров
#
#
# Посмотрим на такие видео:

# %%
pd.set_option('display.max_colwidth', None)
(df[['name','video_title', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='view_count', ascending=False).head(10))
# Out:
#                 name  \
# 271           Forbes
# 257           Forbes
# 285           Forbes
# 265           Forbes
# 273           Forbes
# 140  Это Осетинская*
# 79            Forbes
# 289           Forbes
# 228           Forbes
# 52   Это Осетинская*
#
#                                                                                         video_title  \
# 271                                              Бизнесмен Андрей Ковалëв рассказал про свою охрану
# 257                                                                          Лучший кондитер в мире
# 285                                                              Шеф Ивлев: Продуктовая беда России
# 265                                                                   Угадает ли Агзамов свой торт?
# 273                                                                         Ренат Агзамов о роскоши
# 140                         «Представьте, что вместо России — море». Олег Тиньков о бизнесе и войне
# ...

# %% [markdown]
# - как мы видим, большинство просматриваемых видео - shorts (формат до 1 минуты)

# %% [markdown]
# ### Привлечение

# %% [markdown]
# Кроме интереса, мы можем выделить ещё ***привлечение*** пользователей на канал.
#
# Рассчитаем процент привлечения как соотношение числа подписчиков и просмотров.
#
# - ***если этот показатель небольшой*** - значит, подписчиков мало, и мало кто из посмотревших подписан на канал (например если 1 человек из 100 посмотревших подписался на канал - данная метрика покажет 1%). Это значит у канала нет устоявшейся вовлечённой аудитории, а есть много случайных зрителей
#
#
# - ***если же показатель большой*** (например из 100 посмотревших подписались 100 человек - метрика будет 100%), и значит, у канала очень лояльная аудитория.
#
#
# - ***если показатель выше 100%*** - значит, подписчики у канала есть, но они не активно просматривают видео
#
# Добавляем новые данные:

# %%
df['subscr_perc'] = df['subscriber_count'] / df['view_count'] * 100

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько человек из 100 посмотревших подписаны на канал \n (процент привлечения)', 
             fontweight='bold', y=1.04, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='subscr_perc', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'subscr_perc':'mean'})
            .sort_values(by='order'), y='name', x='subscr_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='subscr_perc', y='name', color=color)
plt.title('')
plt.xlabel('подписки от просмотров, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'subscr_perc':'median'})
            .sort_values(by='order'), y='name', x='subscr_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('подписки от просмотров, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# *Елизавета Осетинская признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - подписчики каналов Forbes и Private Talks просматривают не все выходящие видео
#
#
# - у каналов "Деньги не спят" и "Это Осетинская*" более устоявшаяся ситуация с аудиторией
#
# *Елизавета Осетинская признана иноагентом

# %% [markdown]
# ### Одобрение

# %% [markdown]
# Предположим, что ***одобрение*** - это не просто количество лайков, а соотношение лайков и просмотров.

# %% [markdown]
# Вычисляем данные для новой метрики - процент лайков от просмотров:

# %%
df['like_perc'] = df['like_count'] / df['view_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько человек из 100 посмотревших поставили лайк', fontweight='bold', y=1.02, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='like_perc', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'like_perc':'mean'})
            .sort_values(by='order'), y='name', x='like_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='like_perc', y='name', color=color)
plt.title('')
plt.xlabel('лайки от просмотров, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'like_perc':'median'})
            .sort_values(by='order'), y='name', x='like_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('лайки от просмотров, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# *Елизавета Осетинская признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - канал "Деньги не спят" имеют наилучшие показатели одобрения среди остальных исследуемых здесь каналов. В среднем более 4 человек из 100 посмотревших ставят видео лайк.
#
#
# - у других каналов сопоставимый уровень одобрения - около 2%, а у Private Talks со среднее значение около 3% (во многом за счёт нескольких "выбросов")
#
#
# Посмотрим, какие видео получили максимум одобрения:

# %%
(df[['name','video_title', 'like_perc', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='like_perc', ascending=False).head(10))
# Out:
#                name  \
# 12    Private Talks
# 37   Деньги не спят
# 16   Деньги не спят
# 164  Деньги не спят
# 18   Деньги не спят
# 14    Private Talks
# 86   Деньги не спят
# 171  Деньги не спят
# 87   Деньги не спят
# 161  Деньги не спят
#
#                                                                                            video_title  \
# 12   ЦБ vs мошенники | Валерий Лях о манипуляциях на рынке, запрете криптовалют и финансовых пирамидах
# 37                                                             Честно о BITCOIN. Ожидания и реальность
# 16                          Паника на фондовых рынках // Крах авиаотрасли // 5 причин купить Норникель
# 164                           Что станет защитной таблеткой для инвесторов? / Черная пятница на рынках
# 18                                                           Обвал рубля // Крах рынков. Что покупать?
# 14    Успешные неудачники Стэнфорда: кто и как меняет мир венчура | Профессор финансов Илья Стребулаев
# ...

# %% [markdown]
# - складывается впечатление, что максимум одобрения имеют средне-небольшие по длине ролики - большинство имеют длину от 20 до 50 минут, и только одно интервью длиной более 1 часа
#
#
# - также можно отметить, что эти видео часто имеют довольно небольшое количество просмотров - из 10 видео только половина набрала более сотни тысяч просмотров
#
#
# - большинство видео периода 2020 и 2021 годов

# %% [markdown]
# ### Обсуждение

# %% [markdown]
# Добавляем данные для ещё одной новой метрики - процент комментариев от просмотров покажет нам, насколько видео обсуждаемые:

# %%
df['comment_perc'] = df['comment_count'] / df['view_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько человек из 100 посмотревших оставили комментарий', fontweight='bold', y=1.02, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='comment_perc', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_perc':'mean'})
            .sort_values(by='order'), y='name', x='comment_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='comment_perc', y='name', color=color)
plt.title('')
plt.xlabel('комментарии от просмотров, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_perc':'median'})
            .sort_values(by='order'), y='name', x='comment_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('комментарии от просмотров, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# *Елизавета Осетинская признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - в основном поведение пользователей на разных каналах похоже, от 0 до максимум 2 человек из 100 посмотревших оставляют комментарий. Среднее и медиана говорят нам, что наиболее часто комментарии оставляют 2 человека из 1000 посмотревших
#
#
# - исключение составляют несколько выпусков на канале "Деньги не спят"
#
#
# Посмотрим, какие выпуски имеют наибольший показатель обсуждения:

# %%
(df[['name','video_title', 'comment_perc', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='comment_perc', ascending=False).head(10))
# Out:
#                name  \
# 170  Деньги не спят
# 131  Деньги не спят
# 126  Деньги не спят
# 5     Private Talks
# 77   Деньги не спят
# 14   Деньги не спят
# 115          Forbes
# 1    Деньги не спят
# 238          Forbes
# 132  Деньги не спят
#
#                                                                                               video_title  \
# 170  Каким будет 2022 год для рынков акций, валют и сырья? Версии мировых инвестбанков и Василия Олейника
# 131            Топ акций автопрома, за которыми будущее / Куда Василий Олейник вложит деньги на коррекции
# 126                           Чем хуже экономике, тем лучше рынкам / Чего стоит бояться инвесторам в июне
# 5                    Когда мир откажется от нефти и что будет с энергетикой к 2030 году | Татьяна Митрова
# 77   Как домохозяйки двигают рынки / Женщины в трейдинге, психология торговли, риски опционов и теханализ
# ...

# %% [markdown]
# - как и в случае с реакцией одобрения, здесь мы видим список из средне-продолжительных видео, за исключением первого номера в списке - видео длиной более часа
#
#
# - ещё одна схожесть с реакцией одобрения: большинство видео выпущено в 2020-2021 годы
#
#
# - в отличие от ситуации с одобрением, здесь в топ-10 мы видим не два канала, а три
#
#
# - ещё одно небольшое отличие заключается в количестве просмотров: всё-таки здесь на первых строчках видео с более чем 100 тысячами просмотров (а в реакции одобрения на первых строчках топ-10 были видео с десятками тысяч просмотров)

# %% [markdown]
# ### Ажиотаж/негатив

# %% [markdown]
# Добавим ещё одну новую метрику: процент комментариев от лайков. Этот показатель поможет определить отношение активной аудитории, в каком-то смысле это **показатель ажиотажа и, возможно, негатива в комментариях**: если мы увидим "выбросы" - это повод насторожиться: в комментариях может быть не совсем дружественная дискуссия.
#
# Добавим новые данные в датафрейм:

# %%
df['comment_like_perc'] = df['comment_count'] / df['like_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько человек из 100 лайкнувших оставили комментарий', fontweight='bold', y=1.02, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='comment_like_perc', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_like_perc':'mean'})
            .sort_values(by='order'), y='name', x='comment_like_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='comment_like_perc', y='name', color=color)
plt.title('')
plt.xlabel('комментарии от лайков, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_like_perc':'median'})
            .sort_values(by='order'), y='name', x='comment_like_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('комментарии от лайков, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# *Елизавета Осетинская признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - у нас точно иногда есть ажиотаж в комментариях, иногда возможен и негатив. Есть видео, где свыше 50 человек из 100 лайкнувших оставили свои комментарии. Есть даже случай, когда комментариев больше, чем лайков (350 на канале "Деньги не спят"). Это явное исключение из привычного поведения пользователей, когда много просмотров, на порядок меньше лайков, и ещё на порядок меньше комментариев.
#
#
# - среднее и медиана говорят нам, что стандартно от 8 до 13 человек из 100 лайкнувших оставляют комментарий
#
# Посмотрим на выпуски, где возможен не просто ажиотаж, но негатив в комментариях:

# %%
(df[['name','video_title', 'comment_like_perc', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='comment_like_perc', ascending=False).head(10))
# Out:
#                name  \
# 170  Деньги не спят
# 70           Forbes
# 115          Forbes
# 131  Деньги не спят
# 112          Forbes
# 238          Forbes
# 126  Деньги не спят
# 5     Private Talks
# 60           Forbes
# 43    Private Talks
#
#                                                                                               video_title  \
# 170  Каким будет 2022 год для рынков акций, валют и сырья? Версии мировых инвестбанков и Василия Олейника
# 70              Елизавета Пескова о блоге Навального, Собчак, французском гражданстве, митингах и деньгах
# 115                                                    Главный по кризисам. Интервью с Анатолием Чубайсом
# 131            Топ акций автопрома, за которыми будущее / Куда Василий Олейник вложит деньги на коррекции
# 112                    Предпринимательницы Кремниевой Долины о фильме Дудя, феминизме и женских стартапах
# ...

# %% [markdown]
# - ярко выраженным ажиотажем/негативом мы можем считать выпуски с метрикой свыше 50%
#
#
# - у нас есть 8 таких видео, и два из них просто зашкаливают по нашей метрике (353% и 114%). Это прогноз на 2022 год на канале "Деньги не спят" и видео с Елизаветой Песковой на канале "Forbes". Также заметная ажиотажно-негативная реакция и на выпуске с небольшим количеством просмотров с Анатолией Чубайсом
#
#
# - в отличие от реакции обсуждения, здесь нет линейной зависимости с количеством просмотров (то есть больше просмотров - больше обсуждения). Первые места топ-10 имеют очень разное количество просмотров, и это подводит нас к выводу, что здесь важнее всего содержание конкретного видео. Например, Елизавета Пескова и Анатолий Чубайс собрали 150 и 35 тысяч просмотров (т.е. количество просмотров отличается в несколько раз), однако уровень ажиотажа/негатива у обоих оказался высоким и они оказались на соседних строках в топ-10

# %% [markdown]
# ### Ищем взаимосвязи (корреляция)

# %% [markdown]
# Теперь посмотрим, какие признаки взаимосвязаны между собой:

# %%
plt.figure(figsize=(20,10))
sns.set(font_scale=1.2)
plt.style.use('seaborn-white')
plt.title('Корреляция признаков', fontweight='bold', y=1.02)

table = df.drop(columns=['view_count_mln'])
table['year'] = df['upload_year'] = pd.to_datetime(df['upload_date']).dt.year

corr_m = table.corr()

sns.heatmap(data=corr_m, square=True, annot=True, cmap='PuBuGn', fmt=".2f", linewidths=3, linecolor='white', 
            mask=np.triu(corr_m))
plt.show();

# %% [markdown]
# **Вывод**:
#
# Мы видим несколько сильных взаимосвязей:
# - с увеличением количества просмотров значительно растёт количество лайков
# - реакции обсуждения и ажиотажа/негатива в комментариях тесно связаны между собой
#
# И пару средне-сильных взаимосвязей:
# - с увеличением количества комментариев растёт метрика обсуждения и ажиотажа/негатива
#
# Все эти взаимосвязи вполне ожидаемы, они, можно сказать, технически связаны между собой.
#
# Но есть ещё одна небольшая корреляция:
# - при увеличении длины видео несколько падает процент привлечения (сколько человек из 100 посмотревших подписаны на канал)

# %% [markdown]
# ### Длительность видео и реакция аудитории

# %% [markdown]
# Ранее из разделов про интерес и одобрение мы заметили, что аудитория часто любит короткие видео. Рассмотрим эту ситуацию подробнее.

# %%
plt.figure(figsize=(20, 8))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Продолжительность видео и реакция аудитории', fontweight='bold', y=1.02)

df['duration_minutes'] = df['duration_seconds'] / 60

ax=sns.scatterplot(data=df, x='duration_minutes', y='name', 
                    hue='like_perc', size="view_count", sizes=(100, 500), palette='PuBuGn_r')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('размер - интерес, цвет - одобрение', y=1.02)
plt.xlabel('продолжительность видео в минутах')
plt.ylabel('')

plt.show();

# %% [markdown]
# *Елизавета Осетинская признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - мы не видим устойчивой тенденции к тому, что именно длина видео влияет на интерес и одобрение
#
#
# - на всех каналах есть короткий формат shorts (видео около 1 минуты)
#
#
# - в остальном мы видим разнообразие по вариантам длительности видео на всех каналах, кроме Private Talks. Здесь всё более организованно по формату (от 40 до 60 минут)

# %% [markdown]
# ### Год выхода и реакция аудитории

# %%
plt.figure(figsize=(20, 8))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Дата выпуска видео и реакция аудитории', fontweight='bold', y=1.02)

ax=sns.scatterplot(data=df, x='upload_date', y='name', 
                    hue='like_perc', size="view_count", sizes=(100, 500), palette='PuBuGn_r')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('размер - интерес, цвет - одобрение', y=1.02)
plt.xlabel('время выхода видео')
plt.ylabel('')

plt.show();

# %% [markdown]
# *Елизавета Осетинская признана иноагентом

# %% [markdown]
# **Вывод**:
#
# - мы видим цветовое отличие - "Деньги не спят" смогли собрать более лояльную и отзывчивую аудиторию. Причём 2020-2022 кажется более удачным периодом в плане одобрения
#
#
# - также порой мы видим проблески у Forbes и Private Talks в 2023 году
#
#
# - но в целом одной устойчивой закономерности мы не видим

# %% [markdown]
# ### Реакция аудитории по годам

# %% [markdown]
# Посмотрим, как изменялись главные показатели реакции аудитории с течением времени:

# %%
plt.figure(figsize=(20, 12))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Изменение отношения аудитории', fontweight='bold')

ax1=plt.subplot(4, 3, 1)
sns.lineplot(data=df.query('name == "Forbes"'), x='upload_date',  y='view_count_mln', 
             color=color, linewidth=3)
plt.title("Forbes: интерес", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('просмотры, млн')

ax2=plt.subplot(4, 3, 2)
sns.lineplot(data=df.query('name == "Forbes"'), x='upload_date', y='like_perc', 
             color=color, linewidth=3)
plt.title("Forbes: одобрение", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% одобрения')

ax3=plt.subplot(4, 3, 3)
sns.lineplot(data=df.query('name == "Forbes"'), x='upload_date', y='comment_like_perc', 
             color=color, linewidth=3)
plt.title("Forbes: ажиотаж/негатив", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% ажиотажа')

ax4=plt.subplot(4, 3, 4, sharey=ax1, sharex=ax1)
sns.lineplot(data=df.query('name == "Деньги не спят"'), x='upload_date',  y='view_count_mln', 
             color=color, linewidth=3)
plt.title("Деньги не спят: интерес", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('просмотры, млн')

ax5=plt.subplot(4, 3, 5, sharey=ax2, sharex=ax2)
sns.lineplot(data=df.query('name == "Деньги не спят"'), x='upload_date', y='like_perc', 
             color=color, linewidth=3)
plt.title("Деньги не спят: одобрение", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% одобрения')

ax6=plt.subplot(4, 3, 6, sharey=ax3, sharex=ax3)
sns.lineplot(data=df.query('name == "Деньги не спят"'), x='upload_date', y='comment_like_perc', 
             color=color, linewidth=3)
plt.title("Деньги не спят: ажиотаж/негатив", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% ажиотажа')

ax7=plt.subplot(4, 3, 7, sharey=ax1, sharex=ax1)
sns.lineplot(data=df.query('name == "Это Осетинская*"'), x='upload_date',  y='view_count_mln', 
             color=color, linewidth=3)
plt.title("Это Осетинская*: интерес", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('просмотры, млн')

ax8=plt.subplot(4, 3, 8, sharey=ax2, sharex=ax2)
sns.lineplot(data=df.query('name == "Это Осетинская*"'), x='upload_date', y='like_perc', 
             color=color, linewidth=3)
plt.title("Это Осетинская*: одобрение", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% одобрения')

ax9=plt.subplot(4, 3, 9, sharey=ax3, sharex=ax3)
sns.lineplot(data=df.query('name == "Это Осетинская*"'), x='upload_date', y='comment_like_perc', 
             color=color, linewidth=3)
plt.title("Это Осетинская*: ажиотаж/негатив", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% ажиотажа')

ax10=plt.subplot(4, 3, 10, sharey=ax1, sharex=ax1)
sns.lineplot(data=df.query('name == "Private Talks"'), x='upload_date',  y='view_count_mln', 
             color=color, linewidth=3)
plt.title("Private Talks: интерес", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('просмотры, млн')

ax11=plt.subplot(4, 3, 11, sharey=ax2, sharex=ax2)
sns.lineplot(data=df.query('name == "Private Talks"'), x='upload_date', y='like_perc', 
             color=color, linewidth=3)
plt.title("Private Talks: одобрение", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% одобрения')

ax12=plt.subplot(4, 3, 12, sharey=ax3, sharex=ax3)
sns.lineplot(data=df.query('name == "Private Talks"'), x='upload_date', y='comment_like_perc', 
             color=color, linewidth=3)
plt.title("Private Talks: ажиотаж/негатив", fontweight='bold')
plt.xlabel('время выхода видео')
plt.ylabel('% ажиотажа')

plt.tight_layout()
plt.show();

# %% [markdown]
# *Елизавета Осетинская признана иноагентом

# %% [markdown]
# - мы видим, что всплески различных реакций аудитории происходят на разных каналах в разное время
#
#
# - мощный всплеск интереса мы видим на канале Forbes в 2023 году; всплеск одобрения на канале "Деньги не спят" в 2020 году и негатива в начале 2022 года; всплеск одобрения на канале Private Talks в начале 2022 года

# %% [markdown]
# ## Выводы

# %% [markdown]
# **Главные цифры**:
#
# - с большим отрывом от других каналов по количеству просмотров выделяется канал Forbes. Это суммарно более 110 млн просмотров. По 50 млн просмотров у каналов "Деньги не спят" и "Это Осетинская*", менее 5 млн просмотров у Private Talks.
#
#
# - каналы имеют небольшое количество подписчиков (ни у кого нет миллиона подписчиков) - от 160 до почти 600 тысяч подписчиков максимум
#
#
# - количество видео: от 60 до 340
#
#
# **Даты появления видео**:
#
# - каналы созданы в период с 2018 по 2021 год
#
#
# - общую закономерность "чем старше канал - тем больше видео, подписчиков, просмотров" ломает канал Елизаветы Осетинской*. Канал создан в 2018 году, а канал "деньги не спят" через 1.5 года, в конце 2019. Однако более новый канал смог догнать тот же уровень по просмотрам и подписчикам
#
# **Интерес**:
#
# - средние и медианы говорят нам о том, что в основном видео набирают от 20 до 350 тысяч просмотров. Более стабильно набирают просмотры "Деньги не спят" и "Это Осетинская*" (медианы почти 200 тысяч просмотров). Выпуски с более широким охватом случаются на каналах Forbes и "Это Осетинская*" (среднее более 300 тысяч просмотров)
#
#
# - на каналах Forbes и "Это Осетинская" есть "выбросы" - выделяющиеся по просмотрам видео, набравшие миллионы просмотров
#
# - большинство наиболее просматриваемых видео - shorts (формат до 1 минуты)
#
# **Привлечение**:
#
# - подписчики каналов Forbes и Private Talks просматривают не все выходящие видео
#
#
# - у каналов "Деньги не спят" и "Это Осетинская*" более устоявшаяся ситуация с аудиторией
#
#
# **Одобрение**:
#
# - канал "Деньги не спят" имеют наилучшие показатели одобрения среди остальных исследуемых здесь каналов. В среднем более 4 человек из 100 посмотревших ставят видео лайк.
#
#
# - у других каналов сопоставимый уровень одобрения - около 2%, а у Private Talks со среднее значение около 3% (во многом за счёт нескольких "выбросов")
#
# - складывается впечатление, что максимум одобрения имеют средне-небольшие по длине ролики - большинство имеют длину от 20 до 50 минут, и только одно интервью длиной более 1 часа
#
#
# - также можно отметить, что эти видео часто имеют довольно небольшое количество просмотров - из 10 видео только половина набрала более сотни тысяч просмотров
#
#
# - большинство видео периода 2020 и 2021 годов
#
#
# **Обсуждение**:
#
# - в основном поведение пользователей на разных каналах похоже, от 0 до максимум 2 человек из 100 посмотревших оставляют комментарий. Среднее и медиана говорят нам, что наиболее часто комментарии оставляют 2 человека из 1000 посмотревших
#
#
# - исключение составляют несколько выпусков на канале "Деньги не спят"
#
# - как и в случае с реакцией одобрения, здесь мы видим список из средне-продолжительных видео, за исключением первого номера в списке - видео длиной более часа
#
#
# - ещё одна схожесть с реакцией одобрения: большинство видео выпущено в 2020-2021 годы
#
#
# - в отличие от ситуации с одобрением, здесь в топ-10 мы видим не два канала, а три
#
#
# - ещё одно небольшое отличие заключается в количестве просмотров: всё-таки здесь на первых строчках видео с более чем 100 тысячами просмотров (а в реакции одобрения на первых строчках топ-10 были видео с десятками тысяч просмотров)
#
#
# **Ажиотаж/негатив**:
#
# - у нас точно иногда есть ажиотаж в комментариях, иногда возможен и негатив. Есть видео, где свыше 50 человек из 100 лайкнувших оставили свои комментарии. Есть даже случай, когда комментариев больше, чем лайков (350 на канале "Деньги не спят"). Это явное исключение из привычного поведения пользователей, когда много просмотров, на порядок меньше лайков, и ещё на порядок меньше комментариев.
#
#
# - среднее и медиана говорят нам, что стандартно от 8 до 13 человек из 100 лайкнувших оставляют комментарий
#
# - ярко выраженным ажиотажем/негативом мы можем считать выпуски с метрикой свыше 50%
#
#
# - у нас есть 8 таких видео, и два из них просто зашкаливают по нашей метрике (353% и 114%). Это прогноз на 2022 год на канале "Деньги не спят" и видео с Елизаветой Песковой на канале "Forbes". Также заметная ажиотажно-негативная реакция и на выпуске с небольшим количеством просмотров с Анатолией Чубайсом
#
#
# - в отличие от реакции обсуждения, здесь нет линейной зависимости с количеством просмотров (то есть больше просмотров - больше обсуждения). Первые места топ-10 имеют очень разное количество просмотров, и это подводит нас к выводу, что здесь важнее всего содержание конкретного видео. Например, Елизавета Пескова и Анатолий Чубайс собрали 150 и 35 тысяч просмотров (т.е. количество просмотров отличается в несколько раз), однако уровень ажиотажа/негатива у обоих оказался высоким и они оказались на соседних строках в топ-10
#
# **Взаимосвязи**:
#
# Мы видим несколько сильных взаимосвязей:
# - с увеличением количества просмотров значительно растёт количество лайков
# - реакции обсуждения и ажиотажа/негатива в комментариях тесно связаны между собой
#
# И пару средне-сильных взаимосвязей:
# - с увеличением количества комментариев растёт метрика обсуждения и ажиотажа/негатива
#
# Все эти взаимосвязи вполне ожидаемы, они, можно сказать, технически связаны между собой.
#
# Но есть ещё одна небольшая корреляция:
# - при увеличении длины видео несколько падает процент привлечения (сколько человек из 100 посмотревших подписаны на канал)
#
#
# **Длительность видео и реакция аудитории**:
#
# - мы не видим устойчивой тенденции к тому, что именно длина видео влияет на интерес и одобрение
#
#
# - на всех каналах есть короткий формат shorts (видео около 1 минуты)
#
#
# - в остальном мы видим разнообразие по вариантам длительности видео на всех каналах, кроме Private Talks. Здесь всё более организованно по формату (от 40 до 60 минут)
#
# **Год выхода и реакция аудитории**:
#
# - мы видим цветовое отличие - "Деньги не спят" смогли собрать более лояльную и отзывчивую аудиторию. Причём 2020-2022 кажется более удачным периодом в плане одобрения
#
#
# - также порой мы видим проблески у Forbes и Private Talks в 2023 году
#
#
# - но в целом одной устойчивой закономерности мы не видим
#
#
# **Реакция аудитории по годам**:
#
# - мы видим, что всплески различных реакций аудитории происходят на разных каналах в разное время
#
#
# - мощный всплеск интереса мы видим на канале Forbes в 2023 году; всплеск одобрения на канале "Деньги не спят" в 2020 году и негатива в начале 2022 года; всплеск одобрения на канале Private Talks в начале 2022 года
#
# *Елизавета Осетинская признана иноагентом
#
# _________________________________________________________________________________________________________________
# Дата выполнения проекта: 10 мая 2023 года
#
# Исследование выполнила: аналитик данных Малахова Наталья
#
# Мой телеграм-канал: [Дневник аналитика](https://t.me/diary_musician_analyst "Дневник аналитика")
#
# Портфолио: [GitHub](https://github.com/Malakhova-Natalya "GitHub")
#
# Спасибо за внимание! 🤍
