# %% [markdown]
# # Английский💂: сравнение нескольких видеоканалов🎬

# %% [markdown]
# ![%D0%BB%D0%BE%D0%B3%D0%BE%D1%82%D0%B8%D0%BF%20skyeng.png](attachment:%D0%BB%D0%BE%D0%B3%D0%BE%D1%82%D0%B8%D0%BF%20skyeng.png)

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Открытие-данных" data-toc-modified-id="Открытие-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Открытие данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Главные-цифры" data-toc-modified-id="Главные-цифры-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Главные цифры</a></span></li><li><span><a href="#Даты-появления-видео" data-toc-modified-id="Даты-появления-видео-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Даты появления видео</a></span></li><li><span><a href="#Интерес" data-toc-modified-id="Интерес-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Интерес</a></span></li><li><span><a href="#Привлечение" data-toc-modified-id="Привлечение-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Привлечение</a></span></li><li><span><a href="#Одобрение" data-toc-modified-id="Одобрение-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Одобрение</a></span></li><li><span><a href="#Обсуждение" data-toc-modified-id="Обсуждение-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Обсуждение</a></span></li><li><span><a href="#Ажиотаж/негатив" data-toc-modified-id="Ажиотаж/негатив-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Ажиотаж/негатив</a></span></li><li><span><a href="#Ищем-взаимосвязи-(корреляция)" data-toc-modified-id="Ищем-взаимосвязи-(корреляция)-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Ищем взаимосвязи (корреляция)</a></span></li><li><span><a href="#Длительность-видео-и-реакция-аудитории" data-toc-modified-id="Длительность-видео-и-реакция-аудитории-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Длительность видео и реакция аудитории</a></span></li><li><span><a href="#Год-выхода-и-реакция-аудитории" data-toc-modified-id="Год-выхода-и-реакция-аудитории-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Год выхода и реакция аудитории</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# В данном исследовании проводится ***анализ и сравнение видеоканалов различных онлайн-школ английского языка***🎬.
#
# Это:
# - [Skyeng](https://www.youtube.com/@skyengschool/featured "Skyeng"): онлайн-школа английского языка
# - Онлайн-школа [«Инглекс»](https://www.youtube.com/@EnglexSchool/featured "Инглекс")
# - [Englishdom](https://www.youtube.com/@Englishdomcom-onlineschool/featured "EnglishDom") — онлайн-школа английского языка
#
# **Основные задачи**:
#
# 👩‍💻 сравнить каналы между собой, используя открытые данные
#
# 💡 использовать самостоятельно придуманные метрики для раскрытия данных
#
# 👄 рассказать о каналах доступным и понятным языком
#
# 📈 визуализировать данные
#
# **Описание данных**:
#
# В исследовании используются данные из открытых источников, полученные через api youtube*. Данные были получены 2 мая 2023 года.
#
# *РКН: сайт нарушает законодательство РФ

# %% [markdown]
# ## Открытие данных

# %% [markdown]
# Импортируем необходимые библиотеки:

# %%
import pandas as pd
import os

from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

import datetime as dt
from datetime import datetime, date, timedelta
import numpy as np

# %% [markdown]
# Открываем файлы:

# %%
if os.path.exists('/datasets/video_collection/skyeng_main.xlsx'):
    skyeng_main = pd.read_excel('/datasets/video_collection/skyeng_main.xlsx')
else:
    skyeng_main = pd.read_excel('/C:/datasets/video_collection/skyeng_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/skyeng.xlsx'):
    skyeng = pd.read_excel('/datasets/video_collection/skyeng.xlsx')
else:
    skyeng = pd.read_excel('/C:/datasets/video_collection/skyeng.xlsx')

# %%
if os.path.exists('/datasets/video_collection/englex_main.xlsx'):
    englex_main = pd.read_excel('/datasets/video_collection/englex_main.xlsx')
else:
    englex_main = pd.read_excel('/C:/datasets/video_collection/englex_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/englex.xlsx'):
    englex = pd.read_excel('/datasets/video_collection/englex.xlsx')
else:
    englex = pd.read_excel('/C:/datasets/video_collection/englex.xlsx')

# %%
if os.path.exists('/datasets/video_collection/englishdom_main.xlsx'):
    englishdom_main = pd.read_excel('/datasets/video_collection/englishdom_main.xlsx')
else:
    englishdom_main = pd.read_excel('/C:/datasets/video_collection/englishdom_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/englishdom.xlsx'):
    englishdom = pd.read_excel('/datasets/video_collection/englishdom.xlsx')
else:
    englishdom = pd.read_excel('/C:/datasets/video_collection/englishdom.xlsx')

# %% [markdown]
# Для того, чтобы было удобно рассматривать большие числа, сделаем разделение пробелами:

# %%
class _IntArrayFormatter(pd.io.formats.format.GenericArrayFormatter):

    def _format_strings(self):
        formatter = self.formatter or (lambda x: ' {:,}'.format(x).replace(',', ' '))
        fmt_values = [formatter(x) for x in self.values]
        return fmt_values

pd.io.formats.format.IntArrayFormatter = _IntArrayFormatter

# %% [markdown]
# Для ознакомления и проверки данных будем использовать собственную функцию:

# %%
def my_check_function (dataset):
    '''Функция для ознакомления и проверки даных'''
    print('Размер датасета (количество строк, столбцов):')
    print(dataset.shape)
    print('Как выглядят случайные 5 строк:')
    display(dataset.sample(5, random_state=42))
    print()
    print('Общая информация о данных, наименования столбцов, типы данных:')
    print(dataset.info())
    print()
    print('Есть ли пропуски, сколько их:')
    print(dataset.isna().sum())
    print('Доля пропущенных значений:')
    print(dataset.isna().mean())
    print()
    print('Есть ли явные дубликаты, сколько их:')
    print(dataset.duplicated().sum())
    print('Доля явных дубликатов:')
    print(dataset.duplicated().mean())
    print()
    print('Подробное описание данных:')
    display(dataset.describe())

# %% [markdown]
# Проверяем наши данные:

# %%
my_check_function(skyeng)
# Out:
# Размер датасета (количество строк, столбцов):
# (500, 8)
# Как выглядят случайные 5 строк:
#         video_id                                        video_title  \
# 361  oNN9u8RIvf8  Отличие произношения R в британском и американ...
# 73   nlxvrTeLzVo  ЧТО ОБСУЖДАЮТ В США? Каминг аут NikkieTutorial...
# 374  6L7NVKUjmGc             Как сказать `за границей` по-английски
# 155  Ymw-GGucuMs  Американец оценивает русские адаптации америка...
# 104  6qeKHAZ7NYk  Так звучит настоящая Англия: самые жуткие акце...
#
#     upload_date  view_count  like_count  comment_count  duration_seconds  \
# 361  2022-07-09      34 574       3 258             59                60
# 73   2020-01-21     207 615      17 595            650               932
# 374  2023-02-04     165 943      13 109            160                60
# 155  2021-03-23     274 897      16 444          1 483             1 532
# 104  2020-08-26     290 976      14 388          1 232             1 131
#
#     duration
# ...

# %%
my_check_function(englex)
# Out:
# Размер датасета (количество строк, столбцов):
# (313, 8)
# Как выглядят случайные 5 строк:
#         video_id                                        video_title  \
# 46   017UIPezZx0  Британский и Американский английский: разница ...
# 9    mLc9H9hwRHc        Как Учить Английские Слова | Быстро и легко
# 206  bIBkqoI1djk  Что нужно знать на уровне Intermediate | План ...
# 139  sB_I_rdB5n8  Английский на слух | Доктор Стрэндж 2: В мульт...
# 60   j0y8DkvMOVw  Как думать и говорить на английском? Эффективн...
#
#     upload_date  view_count  like_count  comment_count  duration_seconds  \
# 46   2020-08-04      42 767       2 403            138               513
# 9    2019-11-11      29 653       1 974            145               379
# 206  2022-11-23      67 800       4 025            135             1 469
# 139  2022-02-22      13 909       1 006             88               975
# 60   2020-11-03      65 786       4 126            447               894
#
#     duration
# ...

# %%
my_check_function(englishdom)
# Out:
# Размер датасета (количество строк, столбцов):
# (491, 8)
# Как выглядят случайные 5 строк:
#         video_id                                        video_title  \
# 452  FFEELB-FTSo  США: Ожидание vs реальность | Жизнь в Америке ...
# 84   JCx9CuLtwEM  Онлайн курс | Английский для начинающих | Вопр...
# 434  27DM1AO6y2c  Английский для начинающих: Рапунцель | Трениро...
# 474  ENec6XUKatc  Английский на слух: Один Дома | Английский по ...
# 428  UO32Vxr_WRo  Уроки английского языка | Как читать на англий...
#
#     upload_date  view_count  like_count  comment_count  duration_seconds  \
# 452  2021-11-30      11 923         841             66               888
# 84   2015-09-24       1 012          13              0               183
# 434  2021-08-24   1 594 095      85 524          2 016             1 067
# 474  2021-12-14     167 147       6 466            280             2 040
# 428  2021-07-22     119 424       4 120            104             1 283
#
#     duration
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# - в данных нет пропусков, дубликатов, они пригодны для анализа
#
#
# - единственное, что нужно поправить - формат данных в столбцах upload_date и duration

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Теперь изменим форматы в нужных столбцах:

# %%
skyeng['upload_date'] = pd.to_datetime(skyeng['upload_date'], format='%Y-%m-%d')
englex['upload_date'] = pd.to_datetime(englex['upload_date'], format='%Y-%m-%d')
englishdom['upload_date'] = pd.to_datetime(englishdom['upload_date'], format='%Y-%m-%d')

skyeng['duration'] = pd.to_datetime(skyeng['duration'],format='%H:%M:%S').dt.time
englex['duration'] = pd.to_datetime(englex['duration'],format='%H:%M:%S').dt.time
englishdom['duration'] = pd.to_datetime(englishdom['duration'],format='%H:%M:%S').dt.time

# %% [markdown]
# Дополнительно добавим в таблицы данные о количестве подписчиков:

# %%
skyeng['subscriber_count'] = int(skyeng_main['subscriber_count']) 
englex['subscriber_count'] = int(englex_main['subscriber_count'])
englishdom['subscriber_count'] = int(englishdom_main['subscriber_count'])

# %% [markdown]
# ### Вывод

# %% [markdown]
# - данные в столбцах upload_date и duration приведены к нужным форматам
#
#
# - в таблицы с данными о видео добавлены данные о подписчиках каждого канала

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Главные цифры

# %% [markdown]
# Рассмотрим главные цифры каналов. Для этого соединим таблицы main в одну:

# %%
main = pd.concat([skyeng_main, englex_main, englishdom_main])
main['name'] = ['Skyeng', 'Englex', 'Englishdom']

# %% [markdown]
# Для удобства чтения графиков данные о количестве просмотров и подписчиков переведём в миллионы:

# %%
main['view_count_mln'] = main['view_count'] / 1000000
main['subscriber_count_mln'] = main['subscriber_count'] / 1000000

# %% [markdown]
# Зададим цветовое решение проекта:

# %%
color = '#c4cbe3'

# %% [markdown]
# Визуализируем наши данные:

# %%
plt.figure(figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Количество:', fontweight='bold')

main = main.sort_values(by='view_count', ascending=False)

ax1 = plt.subplot(1, 3, 1)
sns.barplot(data=main,  x='view_count_mln', y='name', color=color)
plt.title('просмотров', fontweight='bold', y=1.02)
plt.xlabel('миллионы')
plt.ylabel('')

ax2 = plt.subplot(1, 3, 2)
sns.barplot(data=main, x='subscriber_count_mln', y='name', color=color)
plt.title('подписчиков', fontweight='bold', y=1.02)
plt.xlabel('миллионы')
plt.ylabel('')

ax3 = plt.subplot(1, 3, 3)
sns.barplot(data=main, x='video_count', y='name', color=color)
plt.title('видео', fontweight='bold', y=1.02)
plt.xlabel('единицы')
plt.ylabel('')

plt.tight_layout()
plt.show();

# %% [markdown]
# **Вывод**:
#
# - Skyeng опережает другие школы по всем основным показателям: у канала почти 200 млн просмотров, более 1.5 млн подписчиков и почти 1000 видео
#
#
# - у канала школы Englex почти 50 млн просмотров, а у EnglishDom практически вдвое меньше; но канал школы EnglishDom опережает конкурента по числу подпичиков и количеству видео

# %% [markdown]
# ### Даты появления видео

# %% [markdown]
# Для удобства визуализации соединим наши данные в одну таблицу:

# %%
# зададим имя для использования в визуализации
skyeng['name'] = 'Skyeng'
englex['name'] = 'Englex'
englishdom['name'] = 'Englishdom'

# зададим порядок в соответствии с главными цифрами
skyeng['order'] = 'a'
englex['order'] = 'b'
englishdom['order'] = 'c'

df = pd.concat([skyeng, englex, englishdom])

# %% [markdown]
# Построим график:

# %%
plt.figure(figsize=(20, 8))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')

sns.scatterplot(data=df, x='upload_date', y='name', color=color, s=200)
plt.title('Даты появления видео на каналах', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

plt.show();

# %% [markdown]
# **Вывод**:
#
# - наши каналы имеют разное время старта: EnglishDom начал выкладывать видео ещё в 2011 году, Skyeng в 2018, а Englex в самом конце 2019 года.
#
#
# - Skyeng и Englex продолжают выпускать видео в настоящее время, EnglishDom - прекратил в начале 2022 года

# %% [markdown]
# ### Интерес

# %% [markdown]
# Предположим, что ***просмотры - это выражение заинтересованности***.
#
# Посмотрим, как различается эта метрика у каналов разных онлайн-школ.

# %% [markdown]
# Для удобства чтения графиков большие значения переведём в миллионы:

# %%
df['view_count_mln'] = df['view_count'] / 1000000

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько миллионов человек просмотрели видео', fontweight='bold', y=1.02, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='view_count_mln', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'view_count_mln':'mean'})
            .sort_values(by='order'), y='name', x='view_count_mln', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df, x='view_count_mln', y='name', color=color)
plt.title('')
plt.xlabel('просмотры, млн')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'view_count_mln':'median'})
            .sort_values(by='order'), y='name', x='view_count_mln', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('просмотры, млн')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
#
# - в основном видео набирают небольшие количества просмотров, все видео с миллионами просмотров - "выбросы", то есть скорее исключение из правил. Но эти исключения есть у всех трёх каналов
#
#
# - по среднему и медианному количеству просмотров снова лидирует Skyeng - это около 250 тысяч в среднем, и медианное значение чуть более 100 тысяч просмотров
#
#
# - каналы Englex и Englishdom показывают более скромные результаты: 150 и 50 тысяч просмотров в среднем, и медианные значения около 30 и 10 тысяч просмотров
#
#
# Посмотрим на видео с наибольшими просмотрами:

# %%
pd.set_option('display.max_colwidth', None)
(df[['name','video_title', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='view_count', ascending=False).head(20))
# Out:
#            name  \
# 344      Skyeng
# 256      Englex
# 267      Englex
# 391      Skyeng
# 375      Skyeng
# 97       Skyeng
# 456      Skyeng
# 455      Skyeng
# 54       Englex
# 402      Skyeng
# 367      Skyeng
# 306      Skyeng
# 269      Englex
# 403      Skyeng
# 469      Skyeng
# 224      Skyeng
# 336  Englishdom
# 61       Skyeng
# 250      Englex
# 150      Skyeng
#
#                                                                               video_title  \
# 344                                 Задорнов был прав: американцы не умеют писать #shorts
# 256                                                               Разница между SUCH и SO
# 267                                                              Фразовые глаголы с BREAK
# 391                                       Эти русские слова шокируют иностранцев. Часть 1
# 375                          🇺🇸АМЕРИКАНЕЦ ПРОВЕРЯЕТ РУССКИХ НА АНГЛИЙСКИЙ. Плохие подарки
# ...

# %% [markdown]
# - как мы видим, наибольший интерес привлекли преимущественно короткие видео, выложенные в последние годы (с 2019 по 2023)
#
#
# - тематика видео: юмор, сравнение россиян, иностранцев их языков, "лайфхаки" по изучению английского

# %% [markdown]
# ### Привлечение

# %% [markdown]
# Кроме интереса, мы можем выделить ещё ***привлечение*** пользователей на канал.
#
# Рассчитаем процент привлечения как соотношение числа подписчиков и просмотров.
#
# - ***если этот показатель небольшой*** - значит, подписчиков мало, и мало кто из посмотревших подписан на канал (например если 1 человек из 100 посмотревших подписался на канал - данная метрика покажет 1%). Это значит у канала нет устоявшейся вовлечённой аудитории, а есть много случайных зрителей
#
#
# - ***если же показатель большой*** (например из 100 посмотревших подписались 100 человек - метрика будет 100%), и значит, у канала очень лояльная аудитория.
#
#
# - ***если показатель выше 100%*** - значит, подписчики у канала есть, но они не активно просматривают видео
#
# Добавляем новые данные:

# %%
df['subscr_perc'] = df['subscriber_count'] / df['view_count'] * 100

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько человек из 100 посмотревших подписаны на канал \n (процент привлечения)', 
             fontweight='bold', y=1.04, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='subscr_perc', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'subscr_perc':'mean'})
            .sort_values(by='order'), y='name', x='subscr_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='subscr_perc', y='name', color=color)
plt.title('')
plt.xlabel('подписки от просмотров, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'subscr_perc':'median'})
            .sort_values(by='order'), y='name', x='subscr_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('подписки от просмотров, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
#
# - мы видим, что каналы Skyeng и Englex очень похожи по проценту привлечения пользователей: не все подписчики просматривают видео, но показатель в целом держится в разумных пределах (средние и медианы в районе 2-3 тысяч)
#
#
# - и совсем другая ситуация с каналом Englishdom: процент привлечения зачастую измеряется тысячами процентов (среднее более 30 тысяч, медиана около 7 тысяч процентов) - это значит, подписчики у канала есть, но они неохотно просматривают большинство видео

# %% [markdown]
# ### Одобрение

# %% [markdown]
# Предположим, что ***одобрение*** - это не просто количество лайков, а соотношение лайков и просмотров.

# %% [markdown]
# Вычисляем данные для новой метрики - процент лайков от просмотров:

# %%
df['like_perc'] = df['like_count'] / df['view_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько человек из 100 посмотревших поставили лайк', fontweight='bold', y=1.02, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='like_perc', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'like_perc':'mean'})
            .sort_values(by='order'), y='name', x='like_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='like_perc', y='name', color=color)
plt.title('')
plt.xlabel('лайки от просмотров, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'like_perc':'median'})
            .sort_values(by='order'), y='name', x='like_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('лайки от просмотров, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
#
# - по метрике одобрения мы снова видим схожесть каналов Skyeng и Englex: в среднем 6-7 человек из 100 посмотревших ставят лайки, в то время как видео на канале Englishdom только 2-3 человека
#
#
# Посмотрим, какие видео получили максимум одобрения:

# %%
(df[['name','video_title', 'like_perc', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='like_perc', ascending=False).head(20))
# Out:
#        name  \
# 477  Skyeng
# 427  Skyeng
# 494  Skyeng
# 247  Englex
# 276  Englex
# 312  Englex
# 306  Englex
# 387  Skyeng
# 454  Skyeng
# 388  Skyeng
# 152  Englex
# 376  Skyeng
# 424  Skyeng
# 148  Englex
# 488  Skyeng
# 294  Englex
# 386  Skyeng
# 30   Englex
# 436  Skyeng
# 370  Skyeng
#
#                                                                            video_title  \
# 477                             Лайфхак для предлогов в английском: метод треугольника
# 427                                                         Так говорят только в школе
# 494      Когда ставить наречия: always, usually, often, sometimes и т.д. ПРОСТАЯ СХЕМА
# 247                                 Американка о 5 Частых Ошибках Русских в Английском
# 276                                      Меня все ДОСТАЛО — как сказать на английском?
# 312                                                  Как сказать ПО ТЕБЕ И НЕ СКАЖЕШЬ?
# ...

# %% [markdown]
# - складывается впечатление, что максимум одобрения имеют короткие ролики - из 20 наиболее одобряемых видео только 4 имеют длину более 1 минуты
#
#
# - также можно отметить, что все эти видео имеют довольно небольшое количество просмотров - в основном менее 100 тысяч
#
#
# - и все они выложены в последние 3 года (с 2020 по 2023)

# %% [markdown]
# ### Обсуждение

# %% [markdown]
# Добавляем данные для ещё одной новой метрики - процент комментариев от просмотров покажет нам, насколько видео обсуждаемые:

# %%
df['comment_perc'] = df['comment_count'] / df['view_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько человек из 100 посмотревших оставили комментарий', fontweight='bold', y=1.02, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='comment_perc', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_perc':'mean'})
            .sort_values(by='order'), y='name', x='comment_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='comment_perc', y='name', color=color)
plt.title('')
plt.xlabel('комментарии от просмотров, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_perc':'median'})
            .sort_values(by='order'), y='name', x='comment_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('комментарии от просмотров, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
#
# - по активности аудитории в комментариях все каналы более-менее схожи между собой: аудитория крайне не активно обсуждает видео, редко когда и 1 человек из 100 посмотревших оставляет комментарий
#
#
# - у видео на каналах Skyeng и Englex в среднее и медиана - около 3 человека из 1000 тысячи посмотревших, у канала Englishdom медиана и того меньше - 1.5 человека из 1000 посмотревших оставлили свой комментарий

# %% [markdown]
# ### Ажиотаж/негатив

# %% [markdown]
# Добавим ещё одну новую метрику: процент комментариев от лайков. Этот показатель поможет определить отношение активной аудитории, в каком-то смысле это **показатель ажиотажа и, возможно, негатива в комментариях**: если мы увидим "выбросы" - это повод насторожиться: в комментариях может быть не совсем дружественная дискуссия.
#
# Добавим новые данные в датафрейм:

# %%
df['comment_like_perc'] = df['comment_count'] / df['like_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько человек из 100 лайкнувших оставили комментарий', fontweight='bold', y=1.02, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='comment_like_perc', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_like_perc':'mean'})
            .sort_values(by='order'), y='name', x='comment_like_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='comment_like_perc', y='name', color=color)
plt.title('')
plt.xlabel('комментарии от лайков, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_like_perc':'median'})
            .sort_values(by='order'), y='name', x='comment_like_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('комментарии от лайков, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
#
# - не похоже, что у нас есть негатив в комментариях, а есть только активность. От 0 до 50 человек из 100 лайкнувших оставили свои комментарии. Для сравнения приведём данные из одного из моих предыдущих проектов: дискуссионный выпуск - это например интервью с Дмитрием Киселёвым на канале Юрия Дудя* - имеет показатель по этой метрике свыше 60%.
#
#
# - мы видим некоторое отличие канала Englishdom, но медиана для всех каналов показывает примерно одно и то же: 5 человек из 100 лайкнувших оставили комментарий
#
# *признан иноагентом

# %% [markdown]
# ### Ищем взаимосвязи (корреляция)

# %% [markdown]
# Теперь посмотрим, какие признаки взаимосвязаны между собой:

# %%
plt.figure(figsize=(20,10))
sns.set(font_scale=1.2)
plt.style.use('seaborn-white')
plt.title('Корреляция признаков', fontweight='bold', y=1.02)

table = df.drop(columns=['view_count_mln'])
table['year'] = df['upload_year'] = pd.to_datetime(df['upload_date']).dt.year

corr_m = table.corr()

sns.heatmap(data=corr_m, square=True, annot=True, cmap='PuBuGn', fmt=".2f", linewidths=3, linecolor='white', 
            mask=np.triu(corr_m))
plt.show();

# %% [markdown]
# **Вывод**:
#
# Мы видим несколько сильных взаимосвязей:
# - с увеличением количества просмотров значительно растёт количество лайков
# - с увеличением комментариев растёт показатель ажиотажа
#
# Обе эти взаимосвязи вполне ожидаемы, они, можно сказать, технически связаны между собой. А вот третья взаимосвязь представляет интерес:
# - на недавно выложенные видео аудитория реагирует с большим одобрением
#
# Что видим отрицательного:
# - привлечение подписчиков падает в последние годы (другими словами разрыв между количеством просмотров и количеством подписчиков сокращается, что ожидаемо, ведь количество подписчиков мы знаем только одно - за последний год)
# - при увеличении уровня привлечения подписчиков уровень одобрения снижается. То есть чем больше человек из 100 посмотревших подписаны на канал, тем меньше человек из 100 посмотревших поставили лайк

# %% [markdown]
# ### Длительность видео и реакция аудитории

# %% [markdown]
# Ранее из разделов про интерес и одобрение мы заметили, что аудитория часто любит короткие видео. Рассмотрим эту ситуацию подробнее.

# %%
plt.figure(figsize=(20, 8))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Продолжительность видео и реакция аудитории', fontweight='bold', y=1.02)

df['duration_minutes'] = df['duration_seconds'] / 60

ax=sns.scatterplot(data=df, x='duration_minutes', y='name', 
                    hue='like_perc', size="view_count", sizes=(100, 500), palette='PuBuGn_r')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('размер - интерес, цвет - одобрение', y=1.02)
plt.xlabel('продолжительность видео в минутах')
plt.ylabel('')

plt.show();

# %% [markdown]
# **Вывод**:
#
# - большинство видео имеют продолжительность до 30 минут
#
#
# - аудитория чаще одобряет видео продолжительностью до 20 минут
#
#
# - в некоторых случаях продолжительные видео могут вызывать интерес, как например, видео длиной около 50 минут на канале Eaglex, но это скорее исключение
#
#
# - у каналов Skyeng и Englishdom разные ситуации: Skyeng даже на продолжительных видео имеет хороший уровень одобрения, а у Englishdom с увеличением длины свыше 40 минут одобрение падает
#
# Посмотрим, что за видео имеют самую большую продолжительность:

# %%
pd.set_option('display.max_colwidth', None)
(df[['name','video_title', 'duration', 'like_perc', 'view_count', 'upload_date']]
 .sort_values(by='duration', ascending=False).head(20))
# Out:
#           name  \
# 3       Skyeng
# 3   Englishdom
# 4       Skyeng
# 1       Skyeng
# 2       Skyeng
# 5       Skyeng
# 0       Skyeng
# 2   Englishdom
# 0   Englishdom
# 7   Englishdom
# 1   Englishdom
# 6       Skyeng
# 4   Englishdom
# 10  Englishdom
# 8   Englishdom
# 6   Englishdom
# 5   Englishdom
# 9   Englishdom
# 11  Englishdom
# 7       Skyeng
#
#                                                                                         video_title  \
# 3                                                 Все, что вы хотели знать про инглиш с сэром Жорой
# 3                                                       Вебинар | Собеседование на английском языке
# 4                                            Как ПОНЯТЬ английский язык и учить слова БЕЗ СТРАДАНИЙ
# 1      Говори, как носитель: как улучшить английское произношение с Джорданом и Алексеем Конобеевым
# 2            Кураж-Бамбей: о происхождении «бугагашеньки», сложностях перевода и любимых персонажах
# ...

# %% [markdown]
# - мы видим здесь две школы: Skyeng и Englishdom. У Englishdom все довольно продолжительные видео из этого списка выпущены в 2016-2019 годах, а у Skyeng в 2021-2022.
#
# Кажется, всё дело во времени выхода видео. Проверим эту гипотезу.

# %% [markdown]
# ### Год выхода и реакция аудитории

# %%
plt.figure(figsize=(20, 8))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Дата выпуска видео и реакция аудитории', fontweight='bold', y=1.02)

ax=sns.scatterplot(data=df, x='upload_date', y='name', 
                    hue='like_perc', size="view_count", sizes=(100, 500), palette='PuBuGn_r')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('размер - интерес, цвет - одобрение', y=1.02)
plt.xlabel('время выхода видео')
plt.ylabel('')

plt.show();

# %% [markdown]
# **Вывод**:
#
# - аудитория с течением лет активнее реагирует на видео
#
#
# - одобрение увеличивается с 2018 года, а всплески повышенного интереса мы видим с 2020 года

# %% [markdown]
# ## Выводы

# %% [markdown]
# **Главные цифры**:
#
# - Skyeng опережает другие школы по всем основным показателям: у канала почти 200 млн просмотров, более 1.5 млн подписчиков и почти 1000 видео
#
#
# - у канала школы Englex почти 50 млн просмотров, а у EnglishDom практически вдвое меньше; но канал школы EnglishDom опережает конкурента по числу подпичиков и количеству видео
#
# **Даты появления видео**:
#
# - каналы имеют разное время старта: EnglishDom начал выкладывать видео ещё в 2011 году, Skyeng в 2018, а Englex в самом конце 2019 года.
#
#
# - Skyeng и Englex продолжают выпускать видео в настоящее время, EnglishDom - прекратил в начале 2022 года
#
# **Интерес**:
#
# - в основном видео набирают небольшое количество просмотров, все видео с миллионами просмотров - "выбросы", то есть скорее исключение из правил. Но эти исключения есть у всех трёх каналов
#
#
# - по среднему и медианному количеству просмотров снова лидирует Skyeng - это около 250 тысяч в среднем, и медианное значение чуть более 100 тысяч просмотров
#
#
# - каналы Englex и Englishdom показывают более скромные результаты: 150 и 50 тысяч просмотров в среднем, и медианные значения около 30 и 10 тысяч просмотров
#
#
# - наибольший интерес привлекли преимущественно короткие видео, выложенные в последние годы (с 2019 по 2023)
#
# - тематика наиболее заинтересовавших аудиторию видео: юмор; сравнение россиян, иностранцев их языков; "лайфхаки" по изучению английского
#
# **Привлечение**:
#
# - мы видим, что каналы Skyeng и Englex очень похожи по проценту привлечения пользователей: не все подписчики просматривают видео, но показатель в целом держится в разумных пределах (средние и медианы в районе 2-3 тысяч)
#
#
# - и совсем другая ситуация с каналом Englishdom: процент привлечения зачастую измеряется тысячами процентов (среднее более 30 тысяч, медиана около 7 тысяч процентов) - это значит, подписчики у канала есть, но они неохотно просматривают большинство видео
#
# **Одобрение**:
#
# - по метрике одобрения мы снова видим схожесть каналов Skyeng и Englex: в среднем 6-7 человек из 100 посмотревших ставят лайки, в то время как видео на канале Englishdom только 2-3 человека
#
#
# - складывается впечатление, что максимум одобрения имеют короткие ролики - из 20 наиболее одобряемых видео только 4 имеют длину более 1 минуты
#
# - также можно отметить, что все эти видео имеют довольно небольшое количество просмотров - в основном менее 100 тысяч
#
# - и все они выложены в последние 3 года (с 2020 по 2023)
#
# **Обсуждение**:
#
# - по активности аудитории в комментариях все каналы более-менее схожи между собой: аудитория крайне не активно обсуждает видео, редко когда и 1 человек из 100 посмотревших оставляет комментарий
#
#
# - у видео на каналах Skyeng и Englex в среднее и медиана - около 3 человека из 1000 тысячи посмотревших, у канала Englishdom медиана и того меньше - 1.5 человека из 1000 посмотревших оставили свои комментарии
#
# **Ажиотаж/негатив**:
#
# - не похоже, что у нас есть негатив в комментариях, а есть только активность. От 0 до 50 человек из 100 лайкнувших оставили свои комментарии. Для сравнения приведём данные из одного из моих предыдущих проектов: дискуссионный выпуск - это например интервью с Дмитрием Киселёвым на канале Юрия Дудя (признан иноагентом) - имеет показатель по этой метрике свыше 60%.
#
#
# - мы видим некоторое отличие канала Englishdom, но медиана для всех каналов показывает примерно одно и то же: 5 человек из 100 лайкнувших оставили комментарий
#
# **Взаимосвязи**:
#
# Мы видим несколько сильных взаимосвязей:
# - с увеличением количества просмотров значительно растёт количество лайков
# - с увеличением комментариев растёт показатель ажиотажа
#
# Обе эти взаимосвязи вполне ожидаемы, они, можно сказать, технически связаны между собой. А вот третья взаимосвязь представляет интерес:
# - на недавно выложенные видео аудитория реагирует с большим одобрением
#
#
# **Длительность видео и реакция аудитории**:
#
# - большинство видео имеют продолжительность до 30 минут
#
#
# - аудитория чаще одобряет видео продолжительностью до 20 минут
#
#
# - в некоторых случаях продолжительные видео могут вызывать интерес, как например, видео длиной около 50 минут на канале Eaglex, но это скорее исключение
#
#
# - у каналов Skyeng и Englishdom разные ситуации: Skyeng даже на продолжительных видео имеет хороший уровень одобрения, а у Englishdom с увеличением длины свыше 40 минут одобрение падает. У Englishdom все довольно продолжительные видео из этого списка выпущены в 2016-2019 годах, а у Skyeng в 2021-2022.
#
# **Год выхода и реакция аудитории**:
#
# - аудитория с течением лет активнее реагирует на видео
#
#
# - одобрение увеличивается с 2018 года, а всплески повышенного интереса мы видим с 2020 года
#
# **Таким образом, мы видим несколько тенденций независимо от канала**:
# - с течением времени аудитория в youtube* только нарастает и реаигриует на видео активнее (это касается и интереса, и одобрения)
#
#
# - чаще аудитория с бОльшим интересом и одобрением реагирует на короткие видео. И, возможно, использование нового формата - shorts - разумный ход со стороны авторов контента для привлечения новой аудитории. Но в конечном счёте длина видео - не самое важное, здесь имеет значение и сам контент (на каком канале выпущен материал), и год выпуска (аудитория не любит залезать в архив, и живее откликается на современные, недавно выпущенные видео)
#
#
# - тематика английского языка тепло встречается аудиторией, но на данный момент имеет большую, но не чрезвычайно большую аудиторию по меркам youtube*.
#
#
# Поскольку **всё познаётся в сравнении**, приведу пример: наиболее крупный и известный русскоязычный канал с интервью (канал Юрия Дудя, признанного иноагентом) - в среднем имеет уровень одобрения около 2-3%, а здесь мы видим уровень 6-7%. С другой стороны, выпуски на канале с интервью набирают в среднем от 9 до 11 миллионов просмотров, а здесь мы видим медианные и средние значения от 10 до 250 тысяч просмотров в зависимости от канала.
#
# *РКН: сайт нарушает законодательство РФ
# _________________________________________________________________________________________________________________
# Дата выполнения проекта: 3 мая 2023 года
#
# Исследование выполнила: аналитик данных Малахова Наталья
#
# Мой телеграм-канал: [Дневник аналитика](https://t.me/diary_musician_analyst "Дневник аналитика")
#
# Портфолио: [GitHub](https://github.com/Malakhova-Natalya "GitHub")
#
# Спасибо за внимание! 🤍
