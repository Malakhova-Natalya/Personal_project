# %% [markdown]
# # Скрипка🎻: сравнение нескольких видеоканалов

# %% [markdown]
# ![violin_project.png](attachment:violin_project.png)

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Открытие-данных" data-toc-modified-id="Открытие-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Открытие данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Главные-цифры" data-toc-modified-id="Главные-цифры-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Главные цифры</a></span></li><li><span><a href="#Даты-появления-видео" data-toc-modified-id="Даты-появления-видео-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Даты появления видео</a></span></li><li><span><a href="#Интерес" data-toc-modified-id="Интерес-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Интерес</a></span></li><li><span><a href="#Привлечение" data-toc-modified-id="Привлечение-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Привлечение</a></span></li><li><span><a href="#Одобрение" data-toc-modified-id="Одобрение-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Одобрение</a></span></li><li><span><a href="#Обсуждение" data-toc-modified-id="Обсуждение-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Обсуждение</a></span></li><li><span><a href="#Ажиотаж/негатив" data-toc-modified-id="Ажиотаж/негатив-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Ажиотаж/негатив</a></span></li><li><span><a href="#Ищем-взаимосвязи-(корреляция)" data-toc-modified-id="Ищем-взаимосвязи-(корреляция)-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Ищем взаимосвязи (корреляция)</a></span></li><li><span><a href="#Длительность-видео-и-реакция-аудитории" data-toc-modified-id="Длительность-видео-и-реакция-аудитории-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Длительность видео и реакция аудитории</a></span></li><li><span><a href="#Год-выхода-и-реакция-аудитории" data-toc-modified-id="Год-выхода-и-реакция-аудитории-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Год выхода и реакция аудитории</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# В данном исследовании проводится ***анализ и сравнение "больших" и "маленьких" видеоканалов***🎬.
#
# ***В качестве "маленького"*** канала я взяла свой личный канал, который завела около 8-9 лет назад, чтобы видеозаписи с моих концертов не потерялись (моя первая профессия - музыкант/педагог, специальность - скрипка).
#
# ***В качестве "больших"*** каналов мы рассмотрим каналы Дэвида Гаррета и Ванессы Мэй (это одни из самых известных широкой публике скрипачей). Мы рассмотрим не классическое, а современное и популярное направление скрипичного искусства как раз для того, чтобы в качестве "больших" каналов иметь данные с наиболее широким охватом аудитории.
#
# На выделенных примерах ***мы проанализируем***, как на просторах интернета сосуществуют такие разные по размеру каналы, чем они отличаются, возможно ли их сравнивать и как это сделать.
#
# **Основные задачи**:
#
# 👩‍💻 сравнить каналы между собой, используя открытые данные
#
# 💡 подобрать новые метрики для раскрытия данных
#
# 👄 рассказать о каналах доступным и понятным языком
#
# 📈 визуализировать
#
# **Описание данных**:
#
# В исследовании используются данные из открытых источников, полученные через api youtube*. Данные были получены 4 апреля 2023 года.
#
# *РКН: сайт нарушает законодательство РФ

# %% [markdown]
# ## Открытие данных

# %% [markdown]
# Импортируем необходимые библиотеки:

# %%
import pandas as pd
import os

from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

import datetime as dt
from datetime import datetime, date, timedelta
import numpy as np

# %% [markdown]
# Открываем файлы:

# %%
if os.path.exists('/datasets/video_collection/natalya_main.xlsx'):
    natalya_main = pd.read_excel('/datasets/video_collection/natalya_main.xlsx')
else:
    natalya_main = pd.read_excel('/C:/datasets/video_collection/natalya_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/natalya_table.xlsx'):
    natalya_table = pd.read_excel('/datasets/video_collection/natalya_table.xlsx')
else:
    natalya_table = pd.read_excel('/C:/datasets/video_collection/natalya_table.xlsx')

# %%
if os.path.exists('/datasets/video_collection/david_garrett_main.xlsx'):
    david_garrett_main = pd.read_excel('/datasets/video_collection/david_garrett_main.xlsx')
else:
    david_garrett_main = pd.read_excel('/C:/datasets/video_collection/david_garrett_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/david_garrett_table.xlsx'):
    david_garrett_table = pd.read_excel('/datasets/video_collection/david_garrett_table.xlsx')
else:
    david_garrett_table = pd.read_excel('/C:/datasets/video_collection/david_garrett_table.xlsx')

# %%
if os.path.exists('/datasets/video_collection/vanessa_mae_main.xlsx'):
    vanessa_mae_main = pd.read_excel('/datasets/video_collection/vanessa_mae_main.xlsx')
else:
    vanessa_mae_main = pd.read_excel('/C:/datasets/video_collection/vanessa_mae_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/vanessa_mae_table.xlsx'):
    vanessa_mae_table = pd.read_excel('/datasets/video_collection/vanessa_mae_table.xlsx')
else:
    vanessa_mae_table = pd.read_excel('/C:/datasets/video_collection/vanessa_mae_table.xlsx')

# %% [markdown]
# Для того, чтобы было удобно рассматривать большие числа, сделаем разделение пробелами:

# %%
class _IntArrayFormatter(pd.io.formats.format.GenericArrayFormatter):

    def _format_strings(self):
        formatter = self.formatter or (lambda x: ' {:,}'.format(x).replace(',', ' '))
        fmt_values = [formatter(x) for x in self.values]
        return fmt_values

pd.io.formats.format.IntArrayFormatter = _IntArrayFormatter

# %% [markdown]
# Для ознакомления и проверки данных будем использовать собственную функцию:

# %%
def my_check_function (dataset):
    '''Функция для ознакомления и проверки даных'''
    print('Размер датасета (количество строк, столбцов):')
    print(dataset.shape)
    print('Как выглядят случайные 5 строк:')
    display(dataset.sample(5, random_state=42))
    print()
    print('Общая информация о данных, наименования столбцов, типы данных:')
    print(dataset.info())
    print()
    print('Есть ли пропуски, сколько их:')
    print(dataset.isna().sum())
    print('Доля пропущенных значений:')
    print(dataset.isna().mean())
    print()
    print('Есть ли явные дубликаты, сколько их:')
    print(dataset.duplicated().sum())
    print('Доля явных дубликатов:')
    print(dataset.duplicated().mean())
    print()
    print('Подробное описание данных:')
    display(dataset.describe())

# %% [markdown]
# Проверяем наши данные:

# %%
my_check_function(natalya_table)
# Out:
# Размер датасета (количество строк, столбцов):
# (12, 8)
# Как выглядят случайные 5 строк:
#        video_id                                        video_title  \
# 10  FjSXE7Q5CM0           Н. Паганини - Ф. Крейслер - «Кампанелла»
# 9   XxgFi_d1HDQ  П.И. Чайковский - Вариация Авроры из балета «С...
# 0   pKQs-eX6jE8  А  Эшпай  Концерт для скрипки с оркестром №1, ...
# 8   YjjWBv0FJhg  П.И. Чайковский - Концерт для скрипки с оркест...
# 5   Sb9ryf37WmE  А.Я. Эшпай - Концерт для скрипки с оркестром №...
#
#    upload_date  view_count  like_count  comment_count  duration_seconds  \
# 10  2014-05-13         354           3              0               388
# 9   2014-05-13         573           5              0               261
# 0   2014-03-19          41           0              0               505
# 8   2014-05-13         714           5              0             1 098
# 5   2014-05-12         586           3              0               745
#
#    duration
# 10  0:06:28
# ...

# %%
my_check_function(vanessa_mae_table)
# Out:
# Размер датасета (количество строк, столбцов):
# (174, 8)
# Как выглядят случайные 5 строк:
#         video_id                                        video_title  \
# 155  BGNqvAjn5SY  David Garrett: Track By Track (DE) – 3 Duets f...
# 144  MvIRa8X1Z-g          David Garrett: UNLIMITED - Live in Verona
# 101  3tBvEfJT-UQ  `Playing for my Life` The new DVD of David Gar...
# 127  KCsvKlOWITE                Bohemian Rhapsody - Rock Revolution
# 140  j67qLOvDKac              Well Dressed Guitar - Rock Revolution
#
#     upload_date  view_count  like_count  comment_count  duration_seconds  \
# 155  2022-09-20      10 531         794             92                47
# 144  2020-07-02      76 727       1 950            151                19
# 101  2011-11-02      63 596         460             33                50
# 127  2018-03-01      13 714         763             40                20
# 140  2018-03-11      16 689         947             48                20
#
#     duration
# ...

# %%
my_check_function(david_garrett_table)
# Out:
# Размер датасета (количество строк, столбцов):
# (174, 11)
# Как выглядят случайные 5 строк:
#         video_id  \
# 155  BGNqvAjn5SY
# 144  MvIRa8X1Z-g
# 101  3tBvEfJT-UQ
# 127  KCsvKlOWITE
# 140  j67qLOvDKac
#
#                                                                                             video_title  \
# 155  David Garrett: Track By Track (DE) – 3 Duets for 2 Violins and Piano: Praeludium (by Shostakovich)
# 144                                                           David Garrett: UNLIMITED - Live in Verona
# 101                                 `Playing for my Life` The new DVD of David Garrett - Trailer Part 8
# 127                                                                 Bohemian Rhapsody - Rock Revolution
# 140                                                               Well Dressed Guitar - Rock Revolution
#
#     upload_date  view_count  like_count  comment_count  duration_seconds  \
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# - в данных нет пропусков, дубликатов, они пригодны для анализа
#
#
# - единственное, что нужно поправить - формат данных в столбцах upload_date и duration
#
# Если зайти на канал [Дэвида Гарретта](https://www.youtube.com/@davidgarrettmusic/featured "Дэвида Гарретта"), то мы увидим, что у него максимум просмотров - это 122 млн, в то время как в нашем датасете это 6 млн. По всей видимости, все видео с маркировкой "vevo" технически не смогли войти в датасет (с тем, что такое vevo можно кратко ознакомиться [здесь](https://yandex.ru/q/life/173696001/ "здесь")). Что ж, мы поработаем с теми данными, которые находятся на самом youtube*.
#
# *РКН: сайт нарушает законодательство РФ

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Для удобства сократим названия наших датасетов:

# %%
n = natalya_table
dg = david_garrett_table
vm = vanessa_mae_table

n_main = natalya_main
dg_main = david_garrett_main
vm_main = vanessa_mae_main

# %% [markdown]
# Теперь изменим форматы в нужных столбцах:

# %%
n['upload_date'] = pd.to_datetime(n['upload_date'], format='%Y-%m-%d')
dg['upload_date'] = pd.to_datetime(dg['upload_date'], format='%Y-%m-%d')
vm['upload_date'] = pd.to_datetime(vm['upload_date'], format='%Y-%m-%d')

n['duration'] = pd.to_datetime(n['duration'],format='%H:%M:%S').dt.time
dg['duration'] = pd.to_datetime(dg['duration'],format='%H:%M:%S').dt.time
vm['duration'] = pd.to_datetime(vm['duration'],format='%H:%M:%S').dt.time

# %% [markdown]
# Дополнительно добавим в таблицы данные о количестве подписчиков:

# %%
n['subscriber_count'] = int(n_main['subscriber_count']) 
dg['subscriber_count'] = int(dg_main['subscriber_count'])
vm['subscriber_count'] = int(vm_main['subscriber_count'])

# %% [markdown]
# ### Вывод

# %% [markdown]
# - для удобства дальнейшего исследования названия датасетов были сокращены
#
#
# - данные в столбцах upload_date и duration приведены к нужным форматам
#
#
# - в таблицы с данными о видео добавлены данные о подписчиках каждого канала

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Главные цифры

# %% [markdown]
# Рассмотрим главные цифры каналов. Для этого соединим таблицы main в одну:

# %%
main = pd.concat([n_main, dg_main, vm_main])
main['name'] = ['Наталья', 'Дэвид Гарретт', 'Ванесса Мэй']

# %% [markdown]
# Для удобства чтения графиков данные о количестве просмотров и подписчиков переведём в миллионы:

# %%
main['view_count_mln'] = main['view_count'] / 1000000
main['subscriber_count_mln'] = main['subscriber_count'] / 1000000

# %% [markdown]
# Зададим цветовое решение проекта:

# %%
color = '#c4cbe3'

# %% [markdown]
# Визуализируем наши данные:

# %%
plt.figure(figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Количество:', fontweight='bold')

main = main.sort_values(by='view_count', ascending=False)

ax1 = plt.subplot(1, 3, 1)
sns.barplot(data=main,  x='view_count_mln', y='name', color=color)
plt.title('просмотров', fontweight='bold', y=1.02)
plt.xlabel('миллионы')
plt.ylabel('')

ax2 = plt.subplot(1, 3, 2)
sns.barplot(data=main, x='subscriber_count_mln', y='name', color=color)
plt.title('подписчиков', fontweight='bold', y=1.02)
plt.xlabel('миллионы')
plt.ylabel('')

ax3 = plt.subplot(1, 3, 3)
sns.barplot(data=main, x='video_count', y='name', color=color)
plt.title('видео', fontweight='bold', y=1.02)
plt.xlabel('единицы')
plt.ylabel('')

plt.tight_layout()
plt.show();

# %% [markdown]
# **Вывод**:
#
# - как мы видим, на фоне больших каналов маленький даже не виден. Так происходит со всеми показателями, кроме количества видео
#
#
# - у нас есть уверенный лидер по всем направлениям: Дэвид Гарретт

# %% [markdown]
# ### Даты появления видео

# %% [markdown]
# Для удобства визуализации соединим наши данные в одну таблицу:

# %%
# зададим имя для использования в визуализации
dg['name'] = 'Дэвид Гарретт'
vm['name'] = 'Ванесса Мэй'
n['name'] = 'Наталья'

# зададим порядок в соответствии с главными цифрами
dg['order'] = 'a'
vm['order'] = 'b'
n['order'] = 'c'

df = pd.concat([dg, vm, n])

# %% [markdown]
# Построим график:

# %%
plt.figure(figsize=(20, 8))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')

sns.scatterplot(data=df, x='upload_date', y='name', color=color, s=200)
plt.title('Даты появления видео на каналах', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

plt.show();

# %% [markdown]
# **Вывод**:
#
# - как мы видим, Дэвид Гарретт давно и достаточно активно ведёт свой канал
#
#
# - в отличие от него Ванесса Мэй в одну дату выложила все видео разом
#
#
# - практически та же ситуация с моим каналом

# %% [markdown]
# ### Интерес

# %% [markdown]
# Предположим, что ***просмотры - это выражение заинтересованности*** со стороны пользователей видеоплатформы.
#
# Если человек наткнулся на видео, но оно ему неинтересно - скорее всего он его переключит, и видеоплатформа не зарегистрирует просмотр этого видео. А если же пользователь нашёл (специально или случайно) какое-то видео и просмотрел его - будем считать, что это было проявление интереса к видео со стороны пользователя.

# %% [markdown]
# Для удобства чтения графиков большие значения переведём в миллионы:

# %%
df['view_count_mln'] = df['view_count'] / 1000000

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько миллионов человек просмотрели видео', fontweight='bold', y=1.02, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='view_count_mln', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'view_count_mln':'mean'})
            .sort_values(by='order'), y='name', x='view_count_mln', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df, x='view_count_mln', y='name', color=color)
plt.title('')
plt.xlabel('просмотры, млн')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'view_count_mln':'median'})
            .sort_values(by='order'), y='name', x='view_count_mln', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('просмотры, млн')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
# - Ванесса Мэй лидер по просмотрам. Если у Дэвида Гарретта было лидерство по суммарному количеству просмотров (во многом благодаря большому количеству видео), то у Ванессы Мэй немного выложенных записей, но каждая запись в среднем активно просматривается.
#
#
# - у её канала самое большое среднее (почти 3.5 млн просмотров на ролик) и медиана (около 700 тыс просмотров на ролик). Такая существенная разница возникла из-за "выброса" - видео, набравшего более 20 млн просмотров. Наверняка это известный даже не музыкантам "Шторм"
#
#
# Проверим:

# %%
vm[['video_title', 'view_count']].sort_values(by='view_count', ascending=False).head(1)
# Out:
#                             video_title  view_count
# 5  Vanessa-Mae - Storm (Official Video)  22 952 038

# %% [markdown]
# Да, это он. Вивальди "Времена года" - "Шторм". Почти 23 млн просмотров.

# %% [markdown]
# ### Привлечение

# %% [markdown]
# Кроме интереса, мы можем выделить ещё ***привлечение*** пользователей на канал.
#
# Вот у исполнителя появился канал на видеоплатформе. Появились первые видео, появились первые просмотры. А сколько человек подписалось на канал? Сопоставимы ли уровни просмотров и подписчиков?
#
# Рассчитаем процент привлечения как соотношение числа подписчиков и просмотров.
#
# - ***если этот показатель небольшой*** - значит, подписчиков мало, и мало кто из посмотревших подписан на канал (например если 1 человек из 100 посмотревших подписался на канал - данная метрика покажет 1%). Это значит у канала нет устоявшейся вовлечённой аудитории.
#
#
# - ***если же показатель большой*** (например из 100 посмотревших подписались 100 человек - метрика будет 100%), и значит, у канала очень лояльная аудитория.
#
# Добавляем новые данные:

# %%
df['subscr_perc'] = df['subscriber_count'] / df['view_count'] * 100

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько человек из 100 посмотревших подписаны на канал \n (процент привлечения)', 
             fontweight='bold', y=1.04, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='subscr_perc', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'subscr_perc':'mean'})
            .sort_values(by='order'), y='name', x='subscr_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='subscr_perc', y='name', color=color)
plt.title('')
plt.xlabel('подписки от просмотров, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'subscr_perc':'median'})
            .sort_values(by='order'), y='name', x='subscr_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('подписки от просмотров, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
#
# - на канале Дэвида Гарретта аудитория очень вовлечена. Наша метрика буквально зашкаливает - тут даже не 100%, а максимум 400 000% привлечения! И в среднем это тоже тысячи процентов. Это значит у канала очень много подписчиков, и они не всегда просматривают выходящие видео. Однако свои подписки сохраняют. Хорошо или плохо это для канала? В данном случае скорее хорошо - ведь возможно благодаря большому числу подписчиков Дэвид Гарретт имеет лидерство по суммарному числу просмотров (а всё-таки просмотры - это первоочередная метирика для видеоплатформы).
#
#
# - получается, у нашей метрики есть две крайности - с одной стороны, у Дэвида Гарретта много лояльных подписчиков, а другие каналы на графиках мы просто не видим - все показатели застыли около нуля.

# %% [markdown]
# ### Одобрение

# %% [markdown]
# На данный момент мы выяснили, что Дэвид Гарретт активнее ведёт канал, имеет лояльную аудиторию и лидер по всем суммарным показателям.
#
# Но в среднем каждое видео Ванессы Мэй имеет бОльшее количество просмотров.
#
# Зададимся вопросами:
# - а как же оценивает публика эти каналы? если больше просмотров - больше и лайков? а в той же степени?
#
# - какой процент от просмотревших видео ставят лайк?
#
# - и увидим ли мы на графиках наш "маленький" канал? или у него вообще нет шансов? :-)

# %% [markdown]
# Вычисляем данные для новой метрики - процент лайков от просмотров:

# %%
df['like_perc'] = df['like_count'] / df['view_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько человек из 100 посмотревших поставили лайк', fontweight='bold', y=1.02, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='like_perc', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'like_perc':'mean'})
            .sort_values(by='order'), y='name', x='like_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='like_perc', y='name', color=color)
plt.title('')
plt.xlabel('лайки от просмотров, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'like_perc':'median'})
            .sort_values(by='order'), y='name', x='like_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('лайки от просмотров, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
# - нет, оказывается, если каждое видео активнее смотрят - это не значит, что его в такой же степени активно отмечают лайками. Например, на предыдущем графике мы видели "выброс" - Ванесса Мэй "Шторм". А на этом графике у канала Ванессы Мэй нет такого аномального "выброса". Да, просмотров там много и лайков тоже много, но если посмотреть именно на процент, то мы увидим, что публика на просторах видеоплатформы в среднем лояльнее к Дэвиду Гаррету. Его видео в среднем отмечают лайком 3-4 человека из 100 посмотревших. А видео Ванессы Мэй лайкает в среднем только 1 человек из 100.
#
#
# - Дэвид Гарретт, похоже, собрал на своём канале довольно лояльную к себе аудиторию - посмотрите на верхнюю череду точек на первом графике. Его видео отмечают лайком до 14-15 человек из 100 посмотревших
#
#
# - если мы смотрим не на прямые показатели-счётчики (количество просмотров, количество лайков и т.п.), а на чуть более сложные метрики - соотношение таких показателей, как в данном случае, то мы впервые замечаем "маленький" канал. Ого, "маленький" канал в среднем лайкает 0.7-0.8 человека из 100 посмотревших. А посмотрите - тут даже небольшой "выброс" есть - однажды почти 4 человека из 100 просмотревших поставили лайк! Да это же больше чем у самой Ванессы Мэй 😅😀 (конечно, всё это шутка, но с долей правды - новая метрика действительно творит чудеса и по-новому раскрывает наши данные).

# %% [markdown]
# ### Обсуждение

# %% [markdown]
# Добавляем данные для ещё одной новой метрики - процент комментариев от просмотров покажет нам, насколько видео обсуждаемые:

# %%
df['comment_perc'] = df['comment_count'] / df['view_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько человек из 100 посмотревших оставили комментарий', fontweight='bold', y=1.02, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='comment_perc', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_perc':'mean'})
            .sort_values(by='order'), y='name', x='comment_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='comment_perc', y='name', color=color)
plt.title('')
plt.xlabel('комментарии от просмотров, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_perc':'median'})
            .sort_values(by='order'), y='name', x='comment_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('комментарии от просмотров, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
# - опять мы видим Дэвида Гарретта в лидерах
#
#
# - мы видим заметное отличие в поведении аудитории: если тому же Дэвиду Гаррету ставят лайки в среднем 3-4 человека из 100 просмотревших видео, то комментарии к видео оставляют в 10 раз реже
#
#
# - и это ещё активный канал. В менее активных каналах, где одномоментно выложены видео, обсуждение и вовсе будто не происходит. В среднем 1 человек из 1000 просмотревших (или и того меньше) оставил свой комментарий под каким-либо видео на таких каналах

# %% [markdown]
# ### Ажиотаж/негатив

# %% [markdown]
# Добавим ещё одну новую метрику: процент комментариев от лайков. Этот показатель поможет определить отношение активной аудитории, в каком-то смысле это **показатель ажиотажа и, возможно, негатива в комментариях**: если мы увидим "выбросы" - это повод насторожиться: в комментариях может быть не совсем дружественная дискуссия.
#
# Добавим новые данные в датафрейм:

# %%
df['comment_like_perc'] = df['comment_count'] / df['like_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 10))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Сколько человек из 100 лайкнувших оставили комментарий', fontweight='bold', y=1.02, x=0.35)

spec = gridspec.GridSpec(ncols=3, nrows=2, figure=fig)

ax1 = fig.add_subplot(spec[0, :-1])
sns.scatterplot(data=df.sort_values(by='order'), x='comment_like_perc', y='name', s=200, color=color)
plt.title('')
plt.xlabel('')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_like_perc':'mean'})
            .sort_values(by='order'), y='name', x='comment_like_perc', color=color)
plt.title('Среднее', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

ax3 = fig.add_subplot(spec[1, :-1])
sns.boxplot(data=df.sort_values(by='order'), x='comment_like_perc', y='name', color=color)
plt.title('')
plt.xlabel('комментарии от лайков, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[1, -1], sharex=ax2)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_like_perc':'median'})
            .sort_values(by='order'), y='name', x='comment_like_perc', color=color)
plt.title('Медиана', fontweight='bold', y=1.02)
plt.xlabel('комментарии от лайков, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# **Вывод**:
# - не похоже, что у нас есть негатив в комментариях, а есть только активность. От 0 до 20 человек из 100 лайкнувших оставили свои комментарии. Для сравнения приведём данные из моего предыдущего проекта: дискуссионный выпуск - это например интервью с Дмитрием Киселёвым на канале Юрия Дудя* - имеет показатель по этой метрике свыше 60%. А здесь от 0 до 20%.
#
#
# - как обычно, Дэвид Гарретт в лидерах: его канал имеет наиболее активную аудиторию.
#
# *признан иноагентом

# %% [markdown]
# ### Ищем взаимосвязи (корреляция)

# %% [markdown]
# Теперь посмотрим, какие признаки взаимосвязаны между собой:

# %%
plt.figure(figsize=(20,10))
sns.set(font_scale=1.2)
plt.style.use('seaborn-white')
plt.title('Корреляция признаков', fontweight='bold', y=1.02)

table = df.drop(columns=['view_count_mln'])
table['year'] = df['upload_year'] = pd.to_datetime(df['upload_date']).dt.year

corr_m = table.corr()

sns.heatmap(data=corr_m, square=True, annot=True, cmap='PuBuGn', fmt=".2f", linewidths=3, linecolor='white', 
            mask=np.triu(corr_m))
plt.show();

# %% [markdown]
# **Вывод**:
#
# Мы видим несколько сильных взаимосвязей:
# - с увеличением количества просмотров значительно растёт количество лайков и комментариев
# - с увеличением лайков растёт количество комментариев, и обсуждение растёт вместе с одобрением
# - на недавно выложенные видео аудитория реагирует активнее
#
# Что видим отрицательного:
# - при увеличении продолжительности видео немного падает число подписчиков  и одобрение

# %% [markdown]
# ### Длительность видео и реакция аудитории

# %% [markdown]
# Рассмотрим эту ситуацию подробнее. Как же связаны длительность видео с откликом аудитории?

# %%
plt.figure(figsize=(20, 8))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Продолжительность видео и реакция аудитории', fontweight='bold', y=1.02)

df['duration_minutes'] = df['duration_seconds'] / 60

ax=sns.scatterplot(data=df, x='duration_minutes', y='name', 
                    hue='comment_perc', size="like_perc", sizes=(100, 500), palette='PuBuGn_r')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('размер - одобрение, цвет - обсуждение', y=1.02)
plt.xlabel('продолжительность видео в минутах')
plt.ylabel('')

plt.show();

# %% [markdown]
# **Вывод**:
#
# - аудтория любит короткие видео
#
#
# - как мы видим, самые большие и яркие точки - наиболее одобряемые и обсуждаемые видео - находятся на канале Дэвида Гарретта и имеют небольшую продолжительность. Плотную группу таких видео мы видим на уровне продолжительности около 1 минуты и ещё одну группу продолжительностью около 4 минут
#
#
# - видимо, такие видео с небольшой продолжительностью на канале Дэвида Гарретта и создают такую взаимосвязь. Присмотримся к ним:

# %%
pd.set_option('display.max_colwidth', None)

# %%
(df.query('order == "a" and duration_seconds < 90')
 [['video_title', 'upload_date','like_perc', 'duration_seconds']]
 .sort_values(by='like_perc', ascending=False))
# Out:
#                                                                                               video_title  \
# 153                                                   THANK YOU for all your positiv feedback for ICONIC!
# 171                                          David Garrett: Track By Track (EN) – Träumerei (by Schumann)
# 168                     David Garrett: Track By Track (EN) –Violin Sonata in A Major: Largo (By Veracini)
# 167  David Garrett: Track By Track (EN) – Concerto for 2 Violins and Cello: Largo e spiccato (by Vivaldi)
# 172                    David Garrett: Track By Track (DE) – Violin Concerto Nr.2: Allegro assai (by Bach)
# ..                                                                                                    ...
# 99                                    `Playing for my Life` The new DVD of David Garrett - Trailer Part 6
# 107                                                           David Garrett - Music track-by-track: MUSIC
# ...

# %% [markdown]
# Кажется, всё дело во времени выхода видео. Проверим эту гипотезу.

# %% [markdown]
# ### Год выхода и реакция аудитории

# %%
plt.figure(figsize=(20, 8))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Дата выпуска видео и реакция аудитории', fontweight='bold', y=1.02)

ax=sns.scatterplot(data=df, x='upload_date', y='name', 
                    hue='duration_minutes', size="like_perc", sizes=(100, 500), palette='PuBuGn_r')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('размер - одобрение, цвет - длительность', y=1.02)
plt.xlabel('время выхода видео')
plt.ylabel('')

plt.show();

# %% [markdown]
# **Вывод**:
#
# - аудитория реагирует активнее на видео, выложенные в 2020-е годы
#
#
# - как мы видим, Дэвид Гарретт активно ведёт канал (а не просто выкладывает записи как для архива), и аудитория это ценит. В 2020-х годах одобрения больше, чем в 2010-е годы. Возможно, это связано с развитием самой видеоплатформы: больше людей пользуется, больше людей втягивается и начинает выражать своё отношение.

# %% [markdown]
# ## Выводы

# %% [markdown]
# Итак, в данном исследовании были рассмотрены 3 разных видеоканала: это каналы двух всемирно известных скрипачей и мой маленький канал, который содержит несколько архивных видеозаписей.
#
# ***По суммарному количеству*** просмотров, подписчиков и количеству видео ***лидирует канал Дэвида Гарретта***. Он начал вести свой канал в 2008 году и время от времени выкладывал новые видео все прошедшие годы. Его канал можно назвать "живым". Суммарно это ***почти 300 млн просмотров, более 1 млн подписчиков*** и более 200 видео; а также здесь более лояльная и активная аудитория.
#
# Два других канала скорее являются "архивными": записи выложены в одно время одномоментно. На канале Ванессы Мэй в 2019 году, на канале Натальи в 2014 году.
#
# ***Канал Ванессы Мэй*** можно назвать крупным: суммарно ***более 40 млн просмотров, 165 тыс.подписчиков***, несмотря на небольшое количество видео - их всего 10.
#
# Мой личный канал в сравнении с такими гигантами чаще всего даже не виден на графиках: более 8 тысяч просмотров, 13 подписчиков, 12 видео.
#
# Однако даже для несопоставимых на первый взгляд вещей можно найти способ адекватного анализа и сравнения.
#
# Для проведения исследования были использованы и прямые метрики-счётчики (например, просмотры), и ***придуманы собственные метрики*** (которые показывают соотношение разных показателей).
#
# **Заинтересованность** (просмотры):
#
# - Ванесса Мэй лидер по просмотрам. Если у Дэвида Гарретта было лидерство по суммарному количеству просмотров (во многом благодаря большому количеству видео), то у Ванессы Мэй немного выложенных записей, но каждая запись в среднем активно просматривается.
#
#
# - у её канала самое большое среднее (почти 3.5 млн просмотров на ролик) и медиана (около 700 тыс просмотров на ролик). Такая существенная разница возникла из-за "выброса" - видео, набравшего более 20 млн просмотров. Это известный даже не музыкантам "Шторм".
#
# **Привлечение** (процент подписок от просмотров):
#
# - на канале Дэвида Гарретта аудитория очень вовлечена. Наша метрика буквально зашкаливает - тут даже не 100%, а максимум 400 000% привлечения! И в среднем это тоже тысячи процентов. Это значит у канала очень много подписчиков, и они не всегда просматривают выходящие видео. Однако свои подписки сохраняют. Хорошо или плохо это для канала? В данном случае скорее хорошо - ведь возможно благодаря большому числу подписчиков Дэвид Гарретт имеет лидерство по суммарному числу просмотров (а всё-таки просмотры - это первоочередная метирика для видеоплатформы).
#
#
# - вовлечения просмотревших видео пользователей в подписчики на архивных каналах мы практически не видим - все показатели застыли около нуля.
#
# **Одобрение** (процент лайков от просмотров):
#
# - публика в среднем лояльнее к Дэвиду Гаррету. Его видео в среднем отмечают лайком 3-4 человека из 100 посмотревших. А видео Ванессы Мэй лайкает в среднем только 1 человек из 100.
#
#
# - Дэвид Гарретт, похоже, собрал на своём канале довольно лояльную к себе аудиторию -некоторые его видео отмечают лайком до 14-15 человек из 100 посмотревших
#
#
# - для сравнения "маленький" канал в среднем лайкает 0.7-0.8 человека из 100 посмотревших.
#
# **Обсуждение** (процент комментариев от просмотров):
#
# - мы видим заметное отличие в поведении аудитории: если тому же Дэвиду Гаррету ставят лайки в среднем 3-4 человека из 100 просмотревших видео, то комментарии к видео оставляют в 10 раз реже - и это лидирующий показатель среди анализируемых каналов
#
#
# - в менее активных каналах, где одномоментно выложены видео, обсуждение и вовсе будто не происходит. В среднем 1 человек из 1000 просмотревших (или и того меньше) оставил свой комментарий под каким-либо видео здесь
#
# **Ажиотаж/негатив** (процент комментариев от лайков):
#
# - не похоже, что у нас есть негатив в комментариях - есть только активность. От 0 до 20 человек из 100 лайкнувших оставили свои комментарии. Для сравнения приведём данные из моего предыдущего проекта: дискуссионный выпуск - это например интервью с Дмитрием Киселёвым на канале Юрия Дудя* (* признан иноагентом) - имеет показатель по этой метрике свыше 60%. А здесь от 0 до 20%.
#
#
# - как обычно, Дэвид Гарретт в лидерах: его канал имеет наиболее активную аудиторию.
#
# **Корреляция**:
#
# Мы видим несколько сильных взаимосвязей:
# - с увеличением количества просмотров значительно растёт количество лайков и комментариев
# - с увеличением лайков растёт количество комментариев, и обсуждение растёт вместе с одобрением
# - на недавно выложенные видео аудитория реагирует активнее
#
# Что видим отрицательного:
# - при увеличении продолжительности видео немного падает число подписчиков  и одобрение
#
# **Что влияет на реакцию аудитории?**:
#
# - аудтория любит короткие видео
#
# - аудитория реагирует активнее на видео, выложенные в 2020-е годы
#
#
# - как мы видим, Дэвид Гарретт активно ведёт канал (а не просто выкладывает записи как для архива), и аудитория это ценит. В 2020-х годах одобрения больше, чем в 2010-е годы. Возможно, это связано с развитием самой видеоплатформы: больше людей пользуется, больше людей втягивается и начинает выражать своё отношение. А возможно, и развитие карьеры самого артиста повлияло на публику и собрало на его канале слушателей, довольно лояльных исполнителю.
#
# **Таким образом**, на видеоплатформе могут сосуществовать совершенно разные по объёму каналы, однако их можно сравнивать.
#
# _____________________________________________________________________________________________________________________________
# Исследование выполнила: аналитик данных Малахова Наталья
#
# Мой телеграм-канал: [Дневник аналитика](https://t.me/diary_musician_analyst "Дневник аналитика")
#
# Портфолио: [GitHub](https://github.com/Malakhova-Natalya "GitHub")
#
# Спасибо за внимание! 🤍
