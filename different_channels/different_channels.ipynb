# %% [markdown]
# # ⚖️ Сравнение реакции аудитории на различные видеоканалы🎬

# %% [markdown]
# ![2023-05-15_11-39-03.png](attachment:2023-05-15_11-39-03.png)

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Открытие-данных" data-toc-modified-id="Открытие-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Открытие данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Главные-цифры" data-toc-modified-id="Главные-цифры-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Главные цифры</a></span></li><li><span><a href="#Даты-появления-видео" data-toc-modified-id="Даты-появления-видео-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Даты появления видео</a></span></li><li><span><a href="#Интерес" data-toc-modified-id="Интерес-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Интерес</a></span></li><li><span><a href="#Вовлечение" data-toc-modified-id="Вовлечение-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Вовлечение</a></span></li><li><span><a href="#Одобрение" data-toc-modified-id="Одобрение-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Одобрение</a></span></li><li><span><a href="#Обсуждение" data-toc-modified-id="Обсуждение-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Обсуждение</a></span></li><li><span><a href="#Ажиотаж/негатив" data-toc-modified-id="Ажиотаж/негатив-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Ажиотаж/негатив</a></span></li><li><span><a href="#Ищем-взаимосвязи-(корреляция)" data-toc-modified-id="Ищем-взаимосвязи-(корреляция)-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Ищем взаимосвязи (корреляция)</a></span></li><li><span><a href="#Длительность-видео-и-реакция-аудитории" data-toc-modified-id="Длительность-видео-и-реакция-аудитории-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Длительность видео и реакция аудитории</a></span></li><li><span><a href="#Год-выхода-и-реакция-аудитории" data-toc-modified-id="Год-выхода-и-реакция-аудитории-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Год выхода и реакция аудитории</a></span></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# В данном исследовании проводится **анализ и сравнение реакции аудитории на разные по объёму и тематике видеоканалы**🎬. Здесь специально собраны очень разные каналы:
# - от "вДудя*" до "Царьграда", и от "Noize MC*" до "SHAMAN'a"
# - от широко известного "Comedy Club" до малоизвестного "Просто о сложном",
# - от развлекательного до научного-популярного контента,
# - от острых интервью, новостей и репортажей до бесед о литературе.
#
# *признаны Минюстом РФ иноагентами
#
# **Зададимся вопросами**:
#
# ❓ какие каналы из представленных вызывают больше интереса у публики?
#
# ❓ какая тематика больше привлекает зрителей: развлекающая или серьёзная?
#
# ❓ зависит ли реакция аудитории от количества подписчиков?
#
# ❓ какие каналы имеют больше одобрения - с большой аудиторией или наоборот, с маленькой? а обсуждения и негатива больше у больших каналов или у маленьких?
#
# ❓ какая тематика каналов имеет больше одобрения?
#
# ❓ что вызывает больше обсуждения и негатива - есть ли разница в тематике каналов?
#
# ❓ есть ли взаимосвязь с длительностью видео и реакцией на него аудитории?
#
# ❓ с годами реакции зрителей меняются?
#
# ❓ можно ли выявить стандартную реакцию аудитории?
#
# **Основные задачи**:
#
# 👩‍💻 сравнить реакции аудитории на различные каналы, используя открытые данные
#
# 💡 использовать самостоятельно придуманные метрики для раскрытия данных
#
# 👄 рассказать о каналах доступным и понятным языком
#
# 📈 визуализировать данные
#
# **Описание данных**:
#
# В исследовании используются данные из открытых источников, полученные через api youtube*. Данные были получены в первой половине мая 2023 года. В исследовании представлены данные о 30 различных каналах.
#
# *РКН: сайт youtube нарушает законодательство РФ

# %% [markdown]
# ## Открытие данных

# %% [markdown]
# Импортируем необходимые библиотеки:

# %%
import pandas as pd
import os

from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns

import datetime as dt
from datetime import datetime, date, timedelta
import numpy as np

# %% [markdown]
# Открываем файлы:

# %%
if os.path.exists('/datasets/video_collection/wylsacom_main.xlsx'):
    wylsacom_main = pd.read_excel('/datasets/video_collection/wylsacom_main.xlsx')
else:
    wylsacom_main = pd.read_excel('/C:/datasets/video_collection/wylsacom_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/wylsacom.xlsx'):
    wylsacom = pd.read_excel('/datasets/video_collection/wylsacom.xlsx')
else:
    wylsacom = pd.read_excel('/C:/datasets/video_collection/wylsacom.xlsx')

# %%
if os.path.exists('/datasets/video_collection/vdud_main.xlsx'):
    vdud_main = pd.read_excel('/datasets/video_collection/vdud_main.xlsx')
else:
    vdud_main = pd.read_excel('/C:/datasets/video_collection/vdud_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/vdud.xlsx'):
    vdud = pd.read_excel('/datasets/video_collection/vdud.xlsx')
else:
    vdud = pd.read_excel('/C:/datasets/video_collection/vdud.xlsx')

# %%
if os.path.exists('/datasets/video_collection/comedy_club_main.xlsx'):
    comedy_club_main = pd.read_excel('/datasets/video_collection/comedy_club_main.xlsx')
else:
    comedy_club_main = pd.read_excel('/C:/datasets/video_collection/comedy_club_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/comedy_club.xlsx'):
    comedy_club = pd.read_excel('/datasets/video_collection/comedy_club.xlsx')
else:
    comedy_club = pd.read_excel('/C:/datasets/video_collection/comedy_club.xlsx')

# %%
if os.path.exists('/datasets/video_collection/varlamov_main.xlsx'):
    varlamov_main = pd.read_excel('/datasets/video_collection/varlamov_main.xlsx')
else:
    varlamov_main = pd.read_excel('/C:/datasets/video_collection/varlamov_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/varlamov.xlsx'):
    varlamov = pd.read_excel('/datasets/video_collection/varlamov.xlsx')
else:
    varlamov = pd.read_excel('/C:/datasets/video_collection/varlamov.xlsx')

# %%
if os.path.exists('/datasets/video_collection/redaktsiya_main.xlsx'):
    redaktsiya_main = pd.read_excel('/datasets/video_collection/redaktsiya_main.xlsx')
else:
    redaktsiya_main = pd.read_excel('/C:/datasets/video_collection/redaktsiya_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/redaktsiya.xlsx'):
    redaktsiya = pd.read_excel('/datasets/video_collection/redaktsiya.xlsx')
else:
    redaktsiya = pd.read_excel('/C:/datasets/video_collection/redaktsiya.xlsx')

# %%
if os.path.exists('/datasets/video_collection/sobchak_main.xlsx'):
    sobchak_main = pd.read_excel('/datasets/video_collection/sobchak_main.xlsx')
else:
    sobchak_main = pd.read_excel('/C:/datasets/video_collection/sobchak_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/sobchak.xlsx'):
    sobchak = pd.read_excel('/datasets/video_collection/sobchak.xlsx')
else:
    sobchak = pd.read_excel('/C:/datasets/video_collection/sobchak.xlsx')

# %%
if os.path.exists('/datasets/video_collection/lapenko_main.xlsx'):
    lapenko_main = pd.read_excel('/datasets/video_collection/lapenko_main.xlsx')
else:
    lapenko_main = pd.read_excel('/C:/datasets/video_collection/lapenko_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/lapenko.xlsx'):
    lapenko = pd.read_excel('/datasets/video_collection/lapenko.xlsx')
else:
    lapenko = pd.read_excel('/C:/datasets/video_collection/lapenko.xlsx')

# %%
if os.path.exists('/datasets/video_collection/apogovorit_main.xlsx'):
    apogovorit_main = pd.read_excel('/datasets/video_collection/apogovorit_main.xlsx')
else:
    apogovorit_main = pd.read_excel('/C:/datasets/video_collection/apogovorit_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/apogovorit.xlsx'):
    apogovorit = pd.read_excel('/datasets/video_collection/apogovorit.xlsx')
else:
    apogovorit = pd.read_excel('/C:/datasets/video_collection/apogovorit.xlsx')

# %%
if os.path.exists('/datasets/video_collection/nauchpok_main.xlsx'):
    nauchpok_main = pd.read_excel('/datasets/video_collection/nauchpok_main.xlsx')
else:
    nauchpok_main = pd.read_excel('/C:/datasets/video_collection/nauchpok_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/nauchpok.xlsx'):
    nauchpok = pd.read_excel('/datasets/video_collection/nauchpok.xlsx')
else:
    nauchpok = pd.read_excel('/C:/datasets/video_collection/nauchpok.xlsx')

# %%
if os.path.exists('/datasets/video_collection/rybakov_main.xlsx'):
    rybakov_main = pd.read_excel('/datasets/video_collection/rybakov_main.xlsx')
else:
    rybakov_main = pd.read_excel('/C:/datasets/video_collection/rybakov_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/rybakov.xlsx'):
    rybakov = pd.read_excel('/datasets/video_collection/rybakov.xlsx')
else:
    rybakov = pd.read_excel('/C:/datasets/video_collection/rybakov.xlsx')

# %%
if os.path.exists('/datasets/video_collection/galileo_main.xlsx'):
    galileo_main = pd.read_excel('/datasets/video_collection/galileo_main.xlsx')
else:
    galileo_main = pd.read_excel('/C:/datasets/video_collection/galileo_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/galileo.xlsx'):
    galileo = pd.read_excel('/datasets/video_collection/galileo.xlsx')
else:
    galileo = pd.read_excel('/C:/datasets/video_collection/galileo.xlsx')

# %%
if os.path.exists('/datasets/video_collection/shaman_main.xlsx'):
    shaman_main = pd.read_excel('/datasets/video_collection/shaman_main.xlsx')
else:
    shaman_main = pd.read_excel('/C:/datasets/video_collection/shaman_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/shaman.xlsx'):
    shaman = pd.read_excel('/datasets/video_collection/shaman.xlsx')
else:
    shaman = pd.read_excel('/C:/datasets/video_collection/shaman.xlsx')

# %%
if os.path.exists('/datasets/video_collection/katz_main.xlsx'):
    katz_main = pd.read_excel('/datasets/video_collection/katz_main.xlsx')
else:
    katz_main = pd.read_excel('/C:/datasets/video_collection/katz_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/katz.xlsx'):
    katz = pd.read_excel('/datasets/video_collection/katz.xlsx')
else:
    katz = pd.read_excel('/C:/datasets/video_collection/katz.xlsx')

# %%
if os.path.exists('/datasets/video_collection/skyeng_main.xlsx'):
    skyeng_main = pd.read_excel('/datasets/video_collection/skyeng_main.xlsx')
else:
    skyeng_main = pd.read_excel('/C:/datasets/video_collection/skyeng_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/skyeng.xlsx'):
    skyeng = pd.read_excel('/datasets/video_collection/skyeng.xlsx')
else:
    skyeng = pd.read_excel('/C:/datasets/video_collection/skyeng.xlsx')

# %%
if os.path.exists('/datasets/video_collection/skazhi_gord_main.xlsx'):
    skazhi_gord_main = pd.read_excel('/datasets/video_collection/skazhi_gord_main.xlsx')
else:
    skazhi_gord_main = pd.read_excel('/C:/datasets/video_collection/skazhi_gord_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/skazhi_gord.xlsx'):
    skazhi_gord = pd.read_excel('/datasets/video_collection/skazhi_gord.xlsx')
else:
    skazhi_gord = pd.read_excel('/C:/datasets/video_collection/skazhi_gord.xlsx')

# %%
if os.path.exists('/datasets/video_collection/phys_ot_pobed_main.xlsx'):
    phys_ot_pobed_main = pd.read_excel('/datasets/video_collection/phys_ot_pobed_main.xlsx')
else:
    phys_ot_pobed_main = pd.read_excel('/C:/datasets/video_collection/phys_ot_pobed_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/phys_ot_pobed.xlsx'):
    phys_ot_pobed = pd.read_excel('/datasets/video_collection/phys_ot_pobed.xlsx')
else:
    phys_ot_pobed = pd.read_excel('/C:/datasets/video_collection/phys_ot_pobed.xlsx')

# %%
if os.path.exists('/datasets/video_collection/eidelman_main.xlsx'):
    eidelman_main = pd.read_excel('/datasets/video_collection/eidelman_main.xlsx')
else:
    eidelman_main = pd.read_excel('/C:/datasets/video_collection/eidelman_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/eidelman.xlsx'):
    eidelman = pd.read_excel('/datasets/video_collection/eidelman.xlsx')
else:
    eidelman = pd.read_excel('/C:/datasets/video_collection/eidelman.xlsx')

# %%
if os.path.exists('/datasets/video_collection/strelets_main.xlsx'):
    strelets_main = pd.read_excel('/datasets/video_collection/strelets_main.xlsx')
else:
    strelets_main = pd.read_excel('/C:/datasets/video_collection/strelets_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/strelets.xlsx'):
    strelets = pd.read_excel('/datasets/video_collection/strelets.xlsx')
else:
    strelets = pd.read_excel('/C:/datasets/video_collection/strelets.xlsx')

# %%
if os.path.exists('/datasets/video_collection/noiз_mc_main.xlsx'):
    noiз_mc_main = pd.read_excel('/datasets/video_collection/noiз_mc_main.xlsx')
else:
    noiз_mc_main = pd.read_excel('/C:/datasets/video_collection/noiз_mc_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/noiз_mc.xlsx'):
    noiз_mc = pd.read_excel('/datasets/video_collection/noiз_mc.xlsx')
else:
    noiз_mc = pd.read_excel('/C:/datasets/video_collection/noiз_mc.xlsx')

# %%
if os.path.exists('/datasets/video_collection/englishdom_main.xlsx'):
    englishdom_main = pd.read_excel('/datasets/video_collection/englishdom_main.xlsx')
else:
    englishdom_main = pd.read_excel('/C:/datasets/video_collection/englishdom_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/englishdom.xlsx'):
    englishdom = pd.read_excel('/datasets/video_collection/englishdom.xlsx')
else:
    englishdom = pd.read_excel('/C:/datasets/video_collection/englishdom.xlsx')

# %%
if os.path.exists('/datasets/video_collection/forbes_main.xlsx'):
    forbes_main = pd.read_excel('/datasets/video_collection/forbes_main.xlsx')
else:
    forbes_main = pd.read_excel('/C:/datasets/video_collection/forbes_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/forbes.xlsx'):
    forbes = pd.read_excel('/datasets/video_collection/forbes.xlsx')
else:
    forbes = pd.read_excel('/C:/datasets/video_collection/forbes.xlsx')

# %%
if os.path.exists('/datasets/video_collection/englex_main.xlsx'):
    englex_main = pd.read_excel('/datasets/video_collection/englex_main.xlsx')
else:
    englex_main = pd.read_excel('/C:/datasets/video_collection/englex_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/englex.xlsx'):
    englex = pd.read_excel('/datasets/video_collection/englex.xlsx')
else:
    englex = pd.read_excel('/C:/datasets/video_collection/englex.xlsx')

# %%
if os.path.exists('/datasets/video_collection/tsargrad_main.xlsx'):
    tsargrad_main = pd.read_excel('/datasets/video_collection/tsargrad_main.xlsx')
else:
    tsargrad_main = pd.read_excel('/C:/datasets/video_collection/tsargrad_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/tsargrad.xlsx'):
    tsargrad = pd.read_excel('/datasets/video_collection/tsargrad.xlsx')
else:
    tsargrad = pd.read_excel('/C:/datasets/video_collection/tsargrad.xlsx')

# %%
if os.path.exists('/datasets/video_collection/dengi_ne_spyat_main.xlsx'):
    dengi_ne_spyat_main = pd.read_excel('/datasets/video_collection/dengi_ne_spyat_main.xlsx')
else:
    dengi_ne_spyat_main = pd.read_excel('/C:/datasets/video_collection/dengi_ne_spyat_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/dengi_ne_spyat.xlsx'):
    dengi_ne_spyat = pd.read_excel('/datasets/video_collection/dengi_ne_spyat.xlsx')
else:
    dengi_ne_spyat = pd.read_excel('/C:/datasets/video_collection/dengi_ne_spyat.xlsx')

# %%
if os.path.exists('/datasets/video_collection/osetinskaya_main.xlsx'):
    osetinskaya_main = pd.read_excel('/datasets/video_collection/osetinskaya_main.xlsx')
else:
    osetinskaya_main = pd.read_excel('/C:/datasets/video_collection/osetinskaya_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/osetinskaya.xlsx'):
    osetinskaya = pd.read_excel('/datasets/video_collection/osetinskaya.xlsx')
else:
    osetinskaya = pd.read_excel('/C:/datasets/video_collection/osetinskaya.xlsx')

# %%
if os.path.exists('/datasets/video_collection/obyektiv_main.xlsx'):
    obyektiv_main = pd.read_excel('/datasets/video_collection/obyektiv_main.xlsx')
else:
    obyektiv_main = pd.read_excel('/C:/datasets/video_collection/obyektiv_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/obyektiv.xlsx'):
    obyektiv = pd.read_excel('/datasets/video_collection/obyektiv.xlsx')
else:
    obyektiv = pd.read_excel('/C:/datasets/video_collection/obyektiv.xlsx')

# %%
if os.path.exists('/datasets/video_collection/bookchel_main.xlsx'):
    bookchel_main = pd.read_excel('/datasets/video_collection/bookchel_main.xlsx')
else:
    bookchel_main = pd.read_excel('/C:/datasets/video_collection/bookchel_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/bookchel.xlsx'):
    bookchel = pd.read_excel('/datasets/video_collection/bookchel.xlsx')
else:
    bookchel = pd.read_excel('/C:/datasets/video_collection/bookchel.xlsx')

# %%
if os.path.exists('/datasets/video_collection/prosto_main.xlsx'):
    prosto_main = pd.read_excel('/datasets/video_collection/prosto_main.xlsx')
else:
    prosto_main = pd.read_excel('/C:/datasets/video_collection/prosto_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/prosto.xlsx'):
    prosto = pd.read_excel('/datasets/video_collection/prosto.xlsx')
else:
    prosto = pd.read_excel('/C:/datasets/video_collection/prosto.xlsx')

# %%
if os.path.exists('/datasets/video_collection/private_main.xlsx'):
    private_main = pd.read_excel('/datasets/video_collection/private_main.xlsx')
else:
    private_main = pd.read_excel('/C:/datasets/video_collection/private_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/private.xlsx'):
    private = pd.read_excel('/datasets/video_collection/private.xlsx')
else:
    private = pd.read_excel('/C:/datasets/video_collection/private.xlsx')

# %%
if os.path.exists('/datasets/video_collection/punkmonk_main.xlsx'):
    punkmonk_main = pd.read_excel('/datasets/video_collection/punkmonk_main.xlsx')
else:
    punkmonk_main = pd.read_excel('/C:/datasets/video_collection/punkmonk_main.xlsx')

# %%
if os.path.exists('/datasets/video_collection/punkmonk.xlsx'):
    punkmonk = pd.read_excel('/datasets/video_collection/punkmonk.xlsx')
else:
    punkmonk = pd.read_excel('/C:/datasets/video_collection/punkmonk.xlsx')

# %% [markdown]
# Объединим данные о разных каналах:

# %%
main = (pd.concat([wylsacom_main, vdud_main, comedy_club_main, varlamov_main, redaktsiya_main, sobchak_main, 
                   lapenko_main, apogovorit_main, nauchpok_main, rybakov_main, galileo_main, shaman_main, 
                   katz_main, skyeng_main, skazhi_gord_main, phys_ot_pobed_main, eidelman_main, strelets_main, 
                   noiз_mc_main, englishdom_main, forbes_main, englex_main, tsargrad_main,dengi_ne_spyat_main,
                  osetinskaya_main, obyektiv_main, bookchel_main, prosto_main, private_main, punkmonk_main]))
main['name'] = (['Wylsacom', 'вДудь*', 'Comedy Club', 'varlamov*', 'Редакция*', 'Осторожно: Собчак','Лапенко', 
                'А поговорить*', 'Научпок','Игорь Рыбаков', 'Галилео', 'SHAMAN', 'Максим Кац*', 'Skyeng', 
                'Скажи Гордеевой*', 'Физика от Побединского','Tamara Eidelman*', 'Надежда Стрелец', 
                'Noize MC*', 'Englishdom', 'Forbes', 'Englex','Царьград ТВ', 'Деньги не спят', 
                'Это Осетинская*', 'Объектив*', 'Книжный чел', 'Просто о сложном','Private Talks','Punkmonk'])

# зададим имя 
wylsacom['name'] = 'Wylsacom'
vdud['name'] = 'вДудь*'
comedy_club['name'] = 'Comedy Club'
varlamov['name'] = 'varlamov*'
redaktsiya['name'] = 'Редакция*'
sobchak['name'] = 'Осторожно: Собчак'
lapenko['name'] = 'Лапенко'
apogovorit['name'] = 'А поговорить*'
nauchpok['name'] = 'Научпок'
rybakov['name'] = 'Игорь Рыбаков'
galileo['name'] = 'Галилео'
shaman['name'] = 'SHAMAN'
katz['name'] = 'Максим Кац*'
skyeng['name'] = 'Skyeng'
skazhi_gord['name'] = 'Скажи Гордеевой*'
phys_ot_pobed['name'] = 'Физика от Побединского'
eidelman['name'] = 'Tamara Eidelman*'
strelets['name'] = 'Надежда Стрелец'
noiз_mc['name'] = 'Noize MC*'
englishdom['name'] = 'Englishdom'
forbes['name'] = 'Forbes'
englex['name'] = 'Englex'
tsargrad['name'] = 'Царьград ТВ'
dengi_ne_spyat['name'] = 'Деньги не спят'
osetinskaya['name'] = 'Это Осетинская*'
obyektiv['name'] = 'Объектив*'
bookchel['name'] = 'Книжный чел'
prosto['name'] = 'Просто о сложном'
private['name'] = 'Private Talks'
punkmonk['name'] = 'Punkmonk'

# зададим порядок (по количеству подписчиков)
wylsacom['order'] = 'aa'
vdud['order'] = 'ab'
comedy_club['order'] = 'ac'
varlamov['order'] = 'ad'
redaktsiya['order'] = 'ae'
sobchak['order'] = 'af'
lapenko['order'] = 'ag'
apogovorit['order'] = 'ah'
nauchpok['order'] = 'ai'
rybakov['order'] = 'aj'
galileo['order'] = 'ak'
shaman['order'] = 'al'
katz['order'] = 'am'
skyeng['order'] = 'an'
skazhi_gord['order'] = 'ao'
phys_ot_pobed['order'] = 'ap'
eidelman['order'] = 'aq'
strelets['order'] = 'ar'
noiз_mc['order'] = 'as'
englishdom['order'] = 'at'
forbes['order'] = 'au'
englex['order'] = 'av'
tsargrad['order'] = 'aw'
dengi_ne_spyat['order'] = 'ax'
osetinskaya['order'] = 'ay'
obyektiv['order'] = 'az'
bookchel['order'] = 'ba'
prosto['order'] = 'bb'
private['order'] = 'bc'
punkmonk['order'] = 'bd'

# добавим данные о количестве подписчиков
wylsacom['subscriber_count'] = int(wylsacom_main['subscriber_count']) 
vdud['subscriber_count'] = int(vdud_main['subscriber_count'])
comedy_club['subscriber_count'] = int(comedy_club_main['subscriber_count'])
varlamov['subscriber_count'] = int(varlamov_main['subscriber_count'])
redaktsiya['subscriber_count'] = int(redaktsiya_main['subscriber_count']) 
sobchak['subscriber_count'] = int(sobchak_main['subscriber_count'])
lapenko['subscriber_count'] = int(lapenko_main['subscriber_count'])
apogovorit['subscriber_count'] = int(apogovorit_main['subscriber_count'])
nauchpok['subscriber_count'] = int(nauchpok_main['subscriber_count'])
rybakov['subscriber_count'] = int(rybakov_main['subscriber_count']) 
galileo['subscriber_count'] = int(galileo_main['subscriber_count'])
shaman['subscriber_count'] = int(shaman_main['subscriber_count'])
katz['subscriber_count'] = int(katz_main['subscriber_count'])
skyeng['subscriber_count'] = int(skyeng_main['subscriber_count']) 
skazhi_gord['subscriber_count'] = int(skazhi_gord_main['subscriber_count'])
phys_ot_pobed['subscriber_count'] = int(phys_ot_pobed_main['subscriber_count'])
eidelman['subscriber_count'] = int(eidelman_main['subscriber_count'])
strelets['subscriber_count'] = int(strelets_main['subscriber_count'])
noiз_mc['subscriber_count'] = int(noiз_mc_main['subscriber_count']) 
englishdom['subscriber_count'] = int(englishdom_main['subscriber_count']) 
forbes['subscriber_count'] = int(forbes_main['subscriber_count']) 
englex['subscriber_count'] = int(englex_main['subscriber_count']) 
tsargrad['subscriber_count'] = int(tsargrad_main['subscriber_count'])
dengi_ne_spyat['subscriber_count'] = int(dengi_ne_spyat_main['subscriber_count'])
osetinskaya['subscriber_count'] = int(osetinskaya_main['subscriber_count'])
obyektiv['subscriber_count'] = int(obyektiv_main['subscriber_count'])
bookchel['subscriber_count'] = int(bookchel_main['subscriber_count'])
prosto['subscriber_count'] = int(prosto_main['subscriber_count'])
private['subscriber_count'] = int(private_main['subscriber_count'])
punkmonk['subscriber_count'] = int(punkmonk_main['subscriber_count'])

df = pd.concat([wylsacom, vdud, comedy_club, varlamov, redaktsiya, sobchak, lapenko, apogovorit, nauchpok,
                rybakov, galileo, shaman, katz, skyeng, skazhi_gord, phys_ot_pobed, eidelman, strelets, 
                noiз_mc, englishdom, forbes, englex, tsargrad, dengi_ne_spyat, osetinskaya, obyektiv, 
                bookchel, prosto, private, punkmonk])

# %% [markdown]
# *авторы каналов признаны иноагентами

# %% [markdown]
# Для того, чтобы было удобно рассматривать большие числа, сделаем разделение пробелами:

# %%
class _IntArrayFormatter(pd.io.formats.format.GenericArrayFormatter):

    def _format_strings(self):
        formatter = self.formatter or (lambda x: ' {:,}'.format(x).replace(',', ' '))
        fmt_values = [formatter(x) for x in self.values]
        return fmt_values

pd.io.formats.format.IntArrayFormatter = _IntArrayFormatter

# %% [markdown]
# Для ознакомления и проверки данных будем использовать собственную функцию:

# %%
def my_check_function (dataset):
    '''Функция для ознакомления и проверки даных'''
    print('Размер датасета (количество строк, столбцов):')
    print(dataset.shape)
    print('Как выглядят случайные 5 строк:')
    display(dataset.sample(5, random_state=42))
    print()
    print('Общая информация о данных, наименования столбцов, типы данных:')
    print(dataset.info())
    print()
    print('Есть ли пропуски, сколько их:')
    print(dataset.isna().sum())
    print('Доля пропущенных значений:')
    print(dataset.isna().mean())
    print()
    print('Есть ли явные дубликаты, сколько их:')
    print(dataset.duplicated().sum())
    print('Доля явных дубликатов:')
    print(dataset.duplicated().mean())
    print()
    print('Подробное описание данных:')
    display(dataset.describe())

# %% [markdown]
# Проверяем наши данные:

# %%
my_check_function(df)
# Out:
# Размер датасета (количество строк, столбцов):
# (9058, 11)
# Как выглядят случайные 5 строк:
#         video_id                                        video_title  \
# 247  F-NLPHLlwwQ  О самообладании принцессы Дианы Спенсер — расс...
# 369  snGOM5bWjGE  Казахстан, Киргизия, Грузия: география и чувст...
# 133  vJq9x1b1g_8   Английский по Интервью - Эндрю Гарфилд | Инглекс
# 221  aTARqvANuqc  Пугающие падения каких акций впереди / Василий...
# 75   pGxh3BALOm8  «Зачем вы пустили детей? Это же спецоперация»/...
#
#     upload_date  view_count  like_count  comment_count  duration_seconds  \
# 247  2023-02-14     416 082      14 418            274                43
# 369  2022-10-06   3 379 806      59 518         23 712             2 730
# 133  2022-01-10      23 316       1 376             58             1 240
# 221  2022-10-28     181 980       6 440            616             7 806
# 75   2022-05-22   4 687 483     148 133         58 491             6 502
#
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# - в данных нет пропусков, в целом они пригодны для анализа
#
#
# - что нужно поправить: формат данных в столбцах upload_date и duration, убрать дубликаты

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Изменим форматы в нужных столбцах:

# %%
df['upload_date'] = pd.to_datetime(df['upload_date'], format='%Y-%m-%d')


df['duration'] = pd.to_datetime(df['duration'],format='%H:%M:%S').dt.time

# %% [markdown]
# Уберём явные дубликаты:

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %% [markdown]
# ### Вывод

# %% [markdown]
# - данные в столбцах upload_date и duration приведены к нужным форматам
#
#
# - явные дубликаты убраны

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Главные цифры

# %% [markdown]
# Для удобства чтения графиков данные о количестве просмотров и подписчиков переведём в миллионы:

# %%
main['view_count_mln'] = main['view_count'] / 1000000
main['subscriber_count_mln'] = main['subscriber_count'] / 1000000

# %% [markdown]
# Зададим цветовое решение проекта:

# %%
color = '#c4cbe3'

# %% [markdown]
# Визуализируем наши данные:

# %%
plt.figure(figsize=(20, 14))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Главные цифры каналов', fontweight='bold')

ax1 = plt.subplot(1, 3, 1)
sns.barplot(data=main, x='subscriber_count_mln', y='name', color=color)
plt.title('количество подписчиков', fontweight='bold', y=1.02)
plt.xlabel('миллионы')
plt.ylabel('')

ax2 = plt.subplot(1, 3, 2)
sns.barplot(data=main,  x='view_count_mln', y='name', color=color)
plt.title('суммарное количество просмотров', fontweight='bold', y=1.02)
plt.xlabel('миллионы')
plt.ylabel('')

ax3 = plt.subplot(1, 3, 3)
sns.barplot(data=main, x='video_count', y='name', color=color)
plt.title('количество видео', fontweight='bold', y=1.02)
plt.xlabel('единицы')
plt.ylabel('')

plt.tight_layout()
plt.show();

# %% [markdown]
# *авторы каналов признаны иноагентами

# %% [markdown]
# **Вывод**:
#
# - во многом суммарное количество просмотров зависит от числа подписчиков, но эта связь не всегда прямая
#
#
# - разные каналы выпускают разное количество видео: одни выпускают десятки видео, а другие - сотни и даже тысячи. Количество видео не связано напрямую с числом подписчиков и суммарным числом просмотров

# %% [markdown]
# ### Даты появления видео

# %% [markdown]
# Построим график:

# %%
plt.figure(figsize=(20, 14))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')

sns.scatterplot(data=df, x='upload_date', y='name', color=color, s=100)
plt.title('Даты появления видео на каналах', fontweight='bold', y=1.02)
plt.xlabel('')
plt.ylabel('')

plt.show();

# %% [markdown]
# *авторы каналов признаны иноагентами

# %% [markdown]
# **Вывод**:
#
# - каналы запущены в разные годы, некоторые в начале 2010-х годов, многие - после 2018 года
#
#
# - 2020-е годы - это уже эра активной жизни всех каналов вне зависимости от их тематики и размера
#
#
# - каналы с миллионной аудиторией запущены не раньше других. Нельзя сказать, что чем раньше появился канал, тем он "успешнее" с точки зрения привлечения аудитории

# %% [markdown]
# ### Интерес

# %% [markdown]
# Предположим, что ***просмотры - это выражение заинтересованности***.
#
# Посмотрим, как различается эта метрика у каналов.

# %% [markdown]
# Для удобства чтения графиков большие значения переведём в миллионы:

# %%
df['view_count_mln'] = df['view_count'] / 1000000

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 14))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Интерес', fontweight='bold')

spec = gridspec.GridSpec(ncols=6, nrows=1, figure=fig)

ax1 = fig.add_subplot(spec[0, :-4])
sns.scatterplot(data=df.sort_values(by='order'), x='view_count_mln', y='name', s=200, color=color)
plt.title('Количество просмотров', fontweight='bold')
plt.xlabel('просмотры, млн')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -4:-2])
sns.boxplot(data=df, x='view_count_mln', y='name', color=color)
plt.title('Количество просмотров', fontweight='bold')
plt.xlabel('просмотры, млн')
plt.ylabel('')

ax3 = fig.add_subplot(spec[0, -2:-1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'view_count_mln':'mean'})
            .sort_values(by='order'), y='name', x='view_count_mln', color=color)
plt.axvline(x=1, color='black', linestyle='--', label='1 млн')
plt.legend(loc='upper right')
plt.title('Среднее', fontweight='bold')
plt.xlabel('просмотры, млн')
plt.ylabel('')

ax4 = fig.add_subplot(spec[0, -1], sharex=ax3)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'view_count_mln':'median'})
            .sort_values(by='order'), y='name', x='view_count_mln', color=color)
plt.axvline(x=1, color='black', linestyle='--', label='1 млн')
plt.legend(loc='upper right')
plt.title('Медиана', fontweight='bold')
plt.xlabel('просмотры, млн')
plt.ylabel('')

plt.show()

# %% [markdown]
# *авторы каналов признаны иноагентами

# %% [markdown]
# **Вывод**:
#
# - как правило, миллионные просмотры бывают на каналах с миллионным же количеством подписчиков. Но не обязательно это работает наоборот: миллионы подписчков не всегда дают большое количество просмотров
#
#
# - по количеству просмотров сильнее всего выделяются каналы "вДудь*", "Comedy Club" - в среднем около 10 млн просмотров на одно видео
#
#
# - за ощутимый порог в 20 млн просмотров перешагнули каналы с тематикой интервью, юмор, музыка
#
#
# - кроме этого в среднем стабильный интерес (с миллионными просмотрами) вызывают каналы с репортажами, обзором новостей и интервью, созданные иноагентами с миллионной аудиторией
#
# *автор канала признан иноагентом
#
# Посмотрим на видео с наибольшими просмотрами:

# %%
pd.set_option('display.max_colwidth', None)
print(f'                       Видео с наибольшими просмотрами:')
(df[['name','video_title', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='view_count', ascending=False).head(10))
# Out:
#                        Видео с наибольшими просмотрами:
#               name  \
# 4 019       SHAMAN
# 579         вДудь*
# 4 037       SHAMAN
# 725    Comedy Club
# 682    Comedy Club
# 542         вДудь*
# 674         вДудь*
# 589         вДудь*
# 719    Comedy Club
# 4 045       SHAMAN
#
#                                                                                video_title  \
# 4 019                                                            SHAMAN - ТАНЦЫ НА СТЕКЛАХ
# 579                   Как устроена IT-столица мира / Russian Silicon Valley (English subs)
# 4 037                                            SHAMAN - ВСТАНЕМ (музыка и слова: SHAMAN)
# 725            Камеди Клаб Демис Карибидис Марина Кравец Тимур Батрутдинов «Изнасилование»
# 682                    Камеди Клаб «Кто хочет стать миллионером?» Харламов Федункив Иванов
# 542                                          Нагиев - пенсии, стих в Кремле (English subs)
# ...

# %% [markdown]
# *авторы каналов признаны иноагентами

# %% [markdown]
# ### Вовлечение

# %% [markdown]
# Кроме интереса, мы можем выделить ещё **вовлечение** подписчиков.
#
# Рассчитаем процент вовлечения как соотношение числа просмотров и подписчиков.
#
# - **если этот показатель небольшой** - значит, не все подписчики активно просмтаривают видео на канале
#
#
# - **если же показатель большой** (например из 100 подписчиков видео просмотрели 100 человек - метрика будет 100%), и значит, у канала очень лояльная, вовлечённая аудитория.
#
#
# - **если показатель выше 100%** - значит, видео на канале привлекает внешнюю аудиторию, которая не является подписчиками
#
# Добавляем новые данные:

# %%
df['subscr_perc'] = df['view_count'] / df['subscriber_count'] * 100

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 14))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Вовлечение подписчиков', fontweight='bold')

spec = gridspec.GridSpec(ncols=6, nrows=1, figure=fig)

ax1 = fig.add_subplot(spec[0, :-4])
sns.scatterplot(data=df.sort_values(by='order'), x='subscr_perc', y='name', s=200, color=color)
plt.title('Процент вовлечения', fontweight='bold')
plt.xlabel('просмотры от подписок, %')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -4:-2])
sns.boxplot(data=df.sort_values(by='order'), x='subscr_perc', y='name', color=color)
plt.title('Процент вовлечения', fontweight='bold')
plt.xlabel('просмотры от подписок, %')
plt.ylabel('')

ax3 = fig.add_subplot(spec[0, -2:-1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'subscr_perc':'mean'})
            .sort_values(by='order'), y='name', x='subscr_perc', color=color)
plt.axvline(x=50, color='grey', linestyle='--', label='50%')
plt.axvline(x=100, color='black', linestyle='--', label='100%')
plt.legend(loc='upper right')
plt.title('Среднее', fontweight='bold')
plt.xlabel('просмотры от подписок, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[0, -1], sharex=ax3)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'subscr_perc':'median'})
            .sort_values(by='order'), y='name', x='subscr_perc', color=color)
plt.axvline(x=50, color='grey', linestyle='--', label='50%')
plt.axvline(x=100, color='black', linestyle='--', label='100%')
plt.legend(loc='upper right')
plt.title('Медиана', fontweight='bold')
plt.xlabel('просмотры от подписок, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# *авторы каналов признаны иноагентами

# %% [markdown]
# **Вывод**:
#
# - вовлечение подписчиков на каналах бывает разным: где-то не вся подписавшаяся аудитория просматривает видео, выложенные на канале, и тогда процент вовлечения не доходит до 50%. А где-то - наоборот, видео привлекают внешнюю аудиторию, иногда очень большую, и метрика измеряется тысячами процентов
#
#
# - наиболее благоприятным значением метрики представляется значение от 50% (чтобы хотя бы половина подписчиков всё-таки просматривала контент) до 100%. Значения выше 100 наводят на мысль о том, что не происходит конверсия просмотров в подписки, и это возможно, говорит о каких-то проблемах: люди смотрят видео, но не планируют оставаться на этом канале.
#
#
# - на данный момент самым ярким примером ситуации, когда просмотры не конверитруются в подписки, является канал "Comedy Club". А другой крупный канал - Wylsacom - это пример обратной ситуации, когда вовлечение подписчиков в просмотр контента очень низкое

# %% [markdown]
# ### Одобрение

# %% [markdown]
# Предположим, что ***одобрение*** - это не просто количество лайков, а соотношение лайков и просмотров.

# %% [markdown]
# Вычисляем данные для новой метрики - процент лайков от просмотров:

# %%
df['like_perc'] = df['like_count'] / df['view_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 14))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Одобрение', fontweight='bold')

spec = gridspec.GridSpec(ncols=6, nrows=1, figure=fig)

ax1 = fig.add_subplot(spec[0, :-4])
sns.scatterplot(data=df.sort_values(by='order'), x='like_perc', y='name', s=200, color=color)
plt.title('Процент одобрения', fontweight='bold')
plt.xlabel('лайки от просмотров, %')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -4:-2])
sns.boxplot(data=df.sort_values(by='order'), x='like_perc', y='name', color=color)
plt.title('Процент одобрения', fontweight='bold')
plt.xlabel('лайки от просмотров, %')
plt.ylabel('')

ax3 = fig.add_subplot(spec[0, -2:-1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'like_perc':'mean'})
            .sort_values(by='order'), y='name', x='like_perc', color=color)
plt.axvline(x=2, color='grey', linestyle='--', label='2%')
plt.axvline(x=5, color='black', linestyle='--', label='5%')
plt.legend(loc='upper right')
plt.title('Среднее', fontweight='bold')
plt.xlabel('лайки от просмотров, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[0, -1], sharex=ax3)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'like_perc':'median'})
            .sort_values(by='order'), y='name', x='like_perc', color=color)
plt.axvline(x=2, color='grey', linestyle='--', label='2%')
plt.axvline(x=5, color='black', linestyle='--', label='5%')
plt.legend(loc='upper right')
plt.title('Медиана', fontweight='bold')
plt.xlabel('лайки от просмотров, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# *авторы каналов признаны иноагентами

# %% [markdown]
# **Вывод**:
#
# - аудитория по-разному реагирует на видео: метрика одобрения колеблется нуля до пары десятков процентов
#
#
# - неизменно одно: лайков всегда значительно меньше просмотров, это стандартное поведение аудитории. Основная масса значений находится в промежутке от 0 до 10 лайков на 100 просмотров (реже в промежутке от 10 до 20 лайков на 100 просмотров)
#
#
# - в среднем можно вывести такое наблюдение: если метрика по каналу меньше 2% - это небольшое одобрение, если от 2 до 5% - среднее одобрение, выше 5% - высокое одобрение
#
#
# - на данный момент наибольшее одобрение демонстрируют каналы с аудиторией от 100 тысяч до 2 млн, тематика: новости/обзор прессы, литература, развлекательное обучение, каналы с разного толка политическим уклоном
#
# Посмотрим, какие видео получили максимум одобрения:

# %%
print(f'                       Видео с наибольшими показателями одобрения:')
(df[['name','like_perc', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='like_perc', ascending=False).head(10))
# Out:
#                        Видео с наибольшими показателями одобрения:
#                  name  like_perc  view_count upload_date  duration
# 8 944   Private Talks  25.610558      74 563  2021-12-16  00:43:57
# 8 124       Объектив*  20.623338      47 005  2022-08-05  00:20:14
# 7 653  Деньги не спят  20.248200      79 291  2020-05-27  00:23:44
# 8 058       Объектив*  20.211468       2 459  2020-11-21  00:12:56
# 8 063       Объектив*  19.894183      30 808  2022-04-28  00:12:23
# 8 110       Объектив*  18.731912      52 520  2022-07-20  00:18:35
# 8 144       Объектив*  18.411840      69 124  2022-08-27  00:24:10
# 8 064       Объектив*  17.923935      25 452  2022-04-29  00:13:16
# 8 146       Объектив*  17.286671      83 064  2022-08-30  00:21:19
# 8 065       Объектив*  17.163928      35 662  2022-04-30  00:14:21

# %% [markdown]
# - складывается впечатление, что максимум одобрения имеют небольшие по длине ролики (от 12 до 45 минут)
#
#
# - также можно отметить, что эти видео часто имеют довольно небольшое количество просмотров (до 100 тысяч)

# %% [markdown]
# ### Обсуждение

# %% [markdown]
# Добавляем данные для ещё одной новой метрики - процент комментариев от просмотров покажет нам, насколько видео обсуждаемые:

# %%
df['comment_perc'] = df['comment_count'] / df['view_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 14))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Обсуждение', fontweight='bold')

spec = gridspec.GridSpec(ncols=6, nrows=1, figure=fig)

ax1 = fig.add_subplot(spec[0, :-4])
sns.scatterplot(data=df.sort_values(by='order'), x='comment_perc', y='name', s=200, color=color)
plt.title('Процент обсуждения', fontweight='bold')
plt.xlabel('комментарии от просмотров, %')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -4:-2])
sns.boxplot(data=df.sort_values(by='order'), x='comment_perc', y='name', color=color)
plt.title('Процент обсуждения', fontweight='bold')
plt.xlabel('комментарии от просмотров, %')
plt.ylabel('')

ax3 = fig.add_subplot(spec[0, -2:-1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_perc':'mean'})
            .sort_values(by='order'), y='name', x='comment_perc', color=color)
plt.axvline(x=0.2, color='grey', linestyle='--', label='0.2%')
plt.axvline(x=0.5, color='black', linestyle='--', label='0.5%')
plt.legend(loc='upper right')
plt.title('Среднее', fontweight='bold')
plt.xlabel('комментарии от просмотров, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[0, -1], sharex=ax3)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_perc':'median'})
            .sort_values(by='order'), y='name', x='comment_perc', color=color)
plt.axvline(x=0.2, color='grey', linestyle='--', label='0.2%')
plt.axvline(x=0.5, color='black', linestyle='--', label='0.5%')
plt.legend(loc='upper right')
plt.title('Медиана', fontweight='bold')
plt.xlabel('комментарии от просмотров, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# *авторы каналов признаны иноагентами

# %% [markdown]
# **Вывод**:
#
# - по активности аудитории в комментариях мы тоже можем заметить общую тенденцию: эта активность ещё на порядок ниже, чем реакция одобрения. Наиболее часто от 0 до 5 человек из 100 посмотревших оставляют комментарий
#
#
# - в среднем  если метрика по каналу меньше 0.2% - это небольшое обсуждение, если от 0.2 до 0.5% - среднее обсуждение, выше 0.5% - высокий уровень обсуждения
#
#
# - в среднем наиболее активная реакция обсуждения на канале Wylsacom (возможно, это связано с конкурсами и розыгрышами призов - и сотавление комментария это одно из условий участия) и на канале "Царьград ТВ" (возможно, это связано с около-политическим ажиотажем)
#
# Посмотрим, какие выпуски имеют наибольший показатель обсуждения:

# %%
print(f'                       Видео с наибольшими показателями обсуждения:')
(df[['name','video_title', 'comment_perc', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='comment_perc', ascending=False).head(10))
# Out:
#                        Видео с наибольшими показателями обсуждения:
#                  name  \
# 281          Wylsacom
# 7 786  Деньги не спят
# 49           Wylsacom
# 274          Wylsacom
# 117          Wylsacom
# 264          Wylsacom
# 217          Wylsacom
# 263          Wylsacom
# 188          Wylsacom
# 134          Wylsacom
#
#                                                                                                 video_title  \
# 281                                    Подборка приятных техно-подарков чтоб закончить 2020 как положено...
# 7 786  Каким будет 2022 год для рынков акций, валют и сырья? Версии мировых инвестбанков и Василия Олейника
# 49                                                                                    iPhone SE 2 не будет!
# 274                                                        Первая кастомная PS5 и все аксессуары от Sony...
# ...

# %% [markdown]
# ### Ажиотаж/негатив

# %% [markdown]
# Добавим ещё одну новую метрику: процент комментариев от лайков. Этот показатель поможет определить отношение активной аудитории, в каком-то смысле это **показатель ажиотажа и, возможно, негатива в комментариях**: если мы увидим значения свыше 50% и "выбросы" - это повод насторожиться: в комментариях может быть не совсем дружественная дискуссия.
#
# Добавим новые данные в датафрейм:

# %%
df['comment_like_perc'] = df['comment_count'] / df['like_count'] * 100

# %% [markdown]
# Визуализируем:

# %%
fig = plt.figure(constrained_layout=True, figsize=(20, 14))
sns.set(font_scale=1.5)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Ажиотаж/негатив', fontweight='bold')

spec = gridspec.GridSpec(ncols=6, nrows=1, figure=fig)

ax1 = fig.add_subplot(spec[0, :-4])
sns.scatterplot(data=df.sort_values(by='order'), x='comment_like_perc', y='name', s=200, color=color)
plt.axvline(x=50, color='black', linestyle='--', label='50%')
plt.legend(loc='upper right')
plt.title('Процент ажиотажа', fontweight='bold')
plt.xlabel('комментарии от лайков, %')
plt.ylabel('')

ax2 = fig.add_subplot(spec[0, -4:-2])
sns.boxplot(data=df.sort_values(by='order'), x='comment_like_perc', y='name', color=color)
plt.axvline(x=50, color='black', linestyle='--', label='50%')
plt.legend(loc='upper right')
plt.title('Процент ажиотажа', fontweight='bold')
plt.xlabel('комментарии от лайков, %')
plt.ylabel('')

ax3 = fig.add_subplot(spec[0, -2:-1])
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_like_perc':'mean'})
            .sort_values(by='order'), y='name', x='comment_like_perc', color=color)
plt.axvline(x=10, color='black', linestyle='--', label='10%')
plt.legend(loc='upper right')
plt.title('Среднее', fontweight='bold')
plt.xlabel('комментарии от лайков, %')
plt.ylabel('')

ax4 = fig.add_subplot(spec[0, -1], sharex=ax3)
sns.barplot(data=df.groupby(['name', 'order'], as_index=False).agg({'comment_like_perc':'median'})
            .sort_values(by='order'), y='name', x='comment_like_perc', color=color)
plt.axvline(x=10, color='black', linestyle='--', label='10%')
plt.legend(loc='upper right')
plt.title('Медиана', fontweight='bold')
plt.xlabel('комментарии от лайков, %')
plt.ylabel('')

plt.show()

# %% [markdown]
# *авторы каналов признаны иноагентами

# %% [markdown]
# **Вывод**:
#
# - за ажиотаж/негатив мы принимаем значение метрики свыше 50% - это уже явное нарушение привычной воронки поведения пользователей, когда просмотры-лайки-комментарии значительно отличаются друг от друга. Эта реакция около 50% может иметь положительный окрас (участие аудитории в обсуждении, отклик), но с увеличением значения ближе к 100% и выше - скорее всего, мы будем иметь дело уже с негативом (либо с участием в конкурсе, где условие - поставить и лайк, и комментарий).
#
#
# - эта реакция аудитории встречается не на всех, но на многих каналах и чаще всего только на некоторых конкретных видео (они видны как "выбросы" на втором графике)
#
#
# - если же рассматривать не отдельные видео, а среднее значение метрики на всём канале - то можно предположить, что 10% - это уровень, выше которого находятся каналы, для которых характерно наличие ажиотажа/негатива в комментариях. На данной выборке мы видим, что сильнее других по ажиотажу/негативу выделяется канал "Осторожно: Собчак"
#
#
# - на данной выборке мы видим что это могут быть каналы как с миллионной, так и с небольшой аудторией. Также и тематика канала может быть разной: это и интервью с репортажами, финансы, религиозный канал и литература
#
#
# Посмотрим на выпуски, где возможен не просто ажиотаж, но негатив в комментариях:

# %%
print(f'                       Видео с наибольшими показателями ажиотажа/негатива:')
(df[['name','video_title', 'comment_like_perc', 'view_count', 'upload_date', 'duration']]
 .sort_values(by='comment_like_perc', ascending=False).head(10))
# Out:
#                        Видео с наибольшими показателями ажиотажа/негатива:
#                     name  \
# 7 786     Деньги не спят
# 7 423        Царьград ТВ
# 1 876  Осторожно: Собчак
# 5 164   Скажи Гордеевой*
# 1 929  Осторожно: Собчак
# 281             Wylsacom
# 2 148  Осторожно: Собчак
# 6 542             Forbes
# 263             Wylsacom
# 264             Wylsacom
#
#                                                                                                 video_title  \
# 7 786  Каким будет 2022 год для рынков акций, валют и сырья? Версии мировых инвестбанков и Василия Олейника
# 7 423               55 – Филя ягодка опять: Киркоров сделал грудь и кубики. Прозрачные лосины уже не нужны?
# 1 876                                          ОСТОРОЖНО: СПОР! За прививку или против. Дебаты о вакцинации
# 5 164                                Елена Драпеко: «Это называется превентивный удар» // «Скажи Гордеевой»
# ...

# %% [markdown]
# *автор канала признана иноагентом

# %% [markdown]
# ### Ищем взаимосвязи (корреляция)

# %% [markdown]
# Теперь посмотрим, какие признаки взаимосвязаны между собой:

# %%
plt.figure(figsize=(20,9))
sns.set(font_scale=1.2)
plt.style.use('seaborn-white')
plt.title('Корреляция признаков', fontweight='bold')

table = df.drop(columns=['view_count_mln'])
table['year'] = df['upload_year'] = pd.to_datetime(df['upload_date']).dt.year

corr_m = table.corr()

sns.heatmap(data=corr_m, square=True, annot=True, cmap='PuBuGn', fmt=".2f", linewidths=3, linecolor='white', 
            mask=np.triu(corr_m))
plt.show();

# %% [markdown]
# **Вывод**:
#
# Мы видим несколько сильных взаимосвязей:
# - с увеличением количества просмотров значительно растёт количество лайков
# - реакции обсуждения и ажиотажа/негатива в комментариях тесно связаны между собой
#
# Также мы видим, что:
# - при увеличении количества просмотров растёт число подписчиков
# - при увеличении количества лайков растёт количество комментариев
#
# Все эти взаимосвязи вполне ожидаемы, они, можно сказать, технически связаны между собой.

# %% [markdown]
# ### Длительность видео и реакция аудитории

# %% [markdown]
# Ранее из раздела про одобрение мы заметили, что аудитория часто любит короткие видео. Рассмотрим эту ситуацию подробнее.

# %%
plt.figure(figsize=(20, 14))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Продолжительность видео и реакция аудитории', fontweight='bold')

df['duration_minutes'] = df['duration_seconds'] / 60

ax=sns.scatterplot(data=df, x='duration_minutes', y='name', 
                    hue='like_perc', size="view_count", sizes=(100, 500), palette='PuBuGn_r')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('размер - интерес, цвет - одобрение', y=1.02)
plt.xlabel('продолжительность видео в минутах')
plt.ylabel('')

plt.show();

# %% [markdown]
# *авторы каналов признаны иноагентами

# %% [markdown]
# **Вывод**:
#
# - да, есть некоторая закономерность: чаще с большим одобрением - видео небольшой длины
#
#
# - однако на разных каналах разная картина, и короткие ролики могут быть без особого одобрения - значит, сам контент, содержание видео имеет более весомое значение, чем длина видео сама по себе

# %% [markdown]
# ### Год выхода и реакция аудитории

# %%
plt.figure(figsize=(20, 14))
sns.set(font_scale=1.7)
plt.style.use('seaborn-whitegrid')
plt.suptitle('Дата выпуска видео и реакция аудитории', fontweight='bold')

ax=sns.scatterplot(data=df, x='upload_date', y='name', 
                    hue='like_perc', size="view_count", sizes=(100, 500), palette='PuBuGn_r')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.title('размер - интерес, цвет - одобрение')
plt.xlabel('время выхода видео')
plt.ylabel('')

plt.show();

# %% [markdown]
# *авторы каналов признаны иноагентами

# %% [markdown]
# **Вывод**:
#
# - с 2017-2018 года мы видим тенденцию и к увеличению числа каналов, и к увеличению количества просмотров (то есть интереса) и к увеличению реакции одобрения.
#
#
# - вероятно, это связано с развитием платформы: стало появляться больше разного контента, на платформу постепенно пришло больше зрителей, и больше людей смогли найти те каналы, которые им пришлись по душе. Поэтому я предполагаю, что с развитием платформы связано во многом развитие интереса и "потепление" реакции аудитории.

# %% [markdown]
# ## Выводы

# %% [markdown]
# **Главные цифры**:
#
# - во многом суммарное количество просмотров зависит от числа подписчиков, но эта связь не всегда прямая
#
#
# - разные каналы выпускают разное количество видео: одни выпускают десятки видео, а другие - сотни и даже тысячи. Количество видео не связано напрямую с числом подписчиков и суммарным числом просмотров
#
#
# **Даты появления видео**:
#
# - каналы запущены в разные годы, некоторые в начале 2010-х годов, многие - после 2018 года
#
#
# - 2020-е годы - это уже эра активной жизни всех каналов вне зависимости от их тематики и размера
#
#
# - каналы с миллионной аудиторией запущены не раньше других. Нельзя сказать, что чем раньше появился канал, тем он "успешнее" с точки зрения привлечения аудитории
#
# **Интерес**:
#
# - как правило, миллионные просмотры бывают на каналах с миллионным же количеством подписчиков. Но не обязательно это работает наоборот: миллионы подписчков не всегда дают большое количество просмотров
#
#
# - по количеству просмотров сильнее всего выделяются каналы "вДудь*" (признан иноагентом), "Comedy Club" - в среднем около 10 млн просмотров на одно видео
#
#
# - за ощутимый порог в 20 млн просмотров перешагнули каналы с тематикой интервью, юмор, музыка
#
#
# - кроме этого в среднем стабильный интерес (с миллионными просмотрами) вызывают каналы с репортажами, обзором новостей и интервью, созданные иноагентами с миллионной аудиторией
#
# **Вовлечение**:
#
# - вовлечение подписчиков на каналах бывает разным: где-то не вся подписавшаяся аудитория просматривает видео, выложенные на канале, и тогда процент вовлечения не доходит до 50%. А где-то - наоборот, видео привлекают внешнюю аудиторию, иногда очень большую, и метрика измеряется тысячами процентов
#
#
# - наиболее благоприятным значением метрики представляется значение от 50% (чтобы хотя бы половина подписчиков всё-таки просматривала контент) до 100%. Значения выше 100 наводят на мысль о том, что не происходит конверсия просмотров в подписки, и это возможно, говорит о каких-то проблемах: люди смотрят видео, но не планируют оставаться на этом канале.
#
#
# - на данный момент самым ярким примером ситуации, когда просмотры не конверитруются в подписки, является канал "Comedy Club". А другой крупный канал - Wylsacom - это пример обратной ситуации, когда вовлечение подписчиков в просмотр контента очень низкое
#
# **Одобрение**:
#
# - аудитория по-разному реагирует на видео: метрика одобрения колеблется нуля до пары десятков процентов
#
#
# - неизменно одно: лайков всегда значительно меньше просмотров, это стандартное поведение аудитории. Основная масса значений находится в промежутке от 0 до 10 лайков на 100 просмотров (реже в промежутке от 10 до 20 лайков на 100 просмотров)
#
#
# - в среднем можно вывести такое наблюдение: если метрика по каналу меньше 2% - это небольшое одобрение, если от 2 до 5% - среднее одобрение, выше 5% - высокое одобрение
#
# - на данный момент наибольшее одобрение демонстрируют каналы с аудиторией от 100 тысяч до 2 млн, тематика: новости/обзор прессы, литература, развлекательное обучение, каналы с разного толка политическим уклоном
#
# - складывается впечатление, что максимум одобрения имеют небольшие по длине ролики (от 12 до 45 минут)
#
#
# - также можно отметить, что эти видео часто имеют довольно небольшое количество просмотров (до 100 тысяч)
#
#
# **Обсуждение**:
#
# - по активности аудитории в комментариях мы тоже можем заметить общую тенденцию: эта активность ещё на порядок ниже, чем реакция одобрения. Наиболее часто от 0 до 5 человек из 100 посмотревших оставляют комментарий
#
#
# - в среднем  если метрика по каналу меньше 0.2% - это небольшое обсуждение, если от 0.2 до 0.5% - среднее обсуждение, выше 0.5% - высокий уровень обсуждения
#
#
# - в среднем наиболее активная реакция обсуждения на канале Wylsacom (возможно, это связано с конкурсами и розыгрышами призов - и сотавление комментария это одно из условий участия) и на канале "Царьград ТВ" (возможно, это связано с около-политическим ажиотажем)
#
# **Ажиотаж/негатив**:
#
# - за ажиотаж/негатив мы принимаем значение метрики свыше 50% - это уже явное нарушение привычной воронки поведения пользователей, когда просмотры-лайки-комментарии значительно отличаются друг от друга. Эта реакция около 50% может иметь положительный окрас (участие аудитории в обсуждении, отклик), но с увеличением значения ближе к 100% и выше - скорее всего, мы будем иметь дело уже с негативом (либо с участием в конкурсе, где условие - поставить и лайк, и комментарий).
#
#
# - эта реакция аудитории встречается не на всех, но на многих каналах и чаще всего только на некоторых конкретных видео (они видны как "выбросы" на втором графике)
#
#
# - если же рассматривать не отдельные видео, а среднее значение метрики на всём канале - то можно предположить, что 10% - это уровень, выше которого находятся каналы, для которых характерно наличие ажиотажа/негатива в комментариях. На данной выборке мы видим, что сильнее других по ажиотажу/негативу выделяется канал "Осторожно: Собчак"
#
#
# - на данной выборке мы видим что это могут быть каналы как с миллионной, так и с небольшой аудторией. Также и тематика канала может быть разной: это и интервью с репортажами, финансы, религиозный канал и литература
#
#
# **Взаимосвязи**:
#
# Мы видим несколько сильных взаимосвязей:
# - с увеличением количества просмотров значительно растёт количество лайков
# - реакции обсуждения и ажиотажа/негатива в комментариях тесно связаны между собой
#
# Также мы видим, что:
# - при увеличении количества просмотров растёт число подписчиков
# - при увеличении количества лайков растёт количество комментариев
#
# Все эти взаимосвязи вполне ожидаемы, они, можно сказать, технически связаны между собой.
#
#
# **Длительность видео и реакция аудитории**:
#
# - да, есть некоторая закономерность: чаще с большим одобрением - видео небольшой длины
#
#
# - однако на разных каналах разная картина, и короткие ролики могут быть без особого одобрения - значит, сам контент, содержание видео имеет более весомое значение, чем длина видео сама по себе
#
#
# **Год выхода и реакция аудитории**:
#
# - с 2017-2018 года мы видим тенденцию и к увеличению числа каналов, и к увеличению количества просмотров (то есть интереса) и к увеличению реакции одобрения.
#
#
# - вероятно, это связано с развитием платформы: стало появляться больше разного контента, на платформу постепенно пришло больше зрителей, и больше людей смогли найти те каналы, которые им пришлись по душе. Поэтому я предполагаю, что с развитием платформы связано во многом развитие интереса и "потепление" реакции аудитории.
#
# Теперь вспомним **изначально поставленные вопросы** и дадим на них **ответы**:
#
# ❓ какие каналы из представленных вызывают больше интереса у публики?
#
# В среднем больше всего интереса у широкой публики вызывают каналы "вДудь*" (признан иноагентом), "Comedy Club" - в среднем около 10 млн просмотров на одно видео
#
# ❓ какая тематика больше привлекает зрителей: развлекающая или серьёзная?
#
# Миллионные просмотры характерны для таких тематик, как: интервью, юмор, музыка, репортажи, обзор новстей. Так что зрителей привлекает и развлекающий, и серьёзный контент. В совокупности на данной выборке мы видим скорее преобладание серьёзной тематики.
#
# ❓ зависит ли реакция аудитории от количества подписчиков?
#
# Да, некоторые взаимосвязи мы можем выявить. Например, как правило, миллионные просмотры (то есть высокий интерес) бывают на каналах с миллионным же количеством подписчиков. Однако с другими реакциями аудитории - другие взаимосвязи.
#
# ❓ какие каналы имеют больше одобрения - с большой аудиторией или наоборот, с маленькой?
#
# Повышенное одобрение чаще встречается на каналах с аудиторией от нескольких сот тысяч подписчиков до 1-2 млн, не больше. Так что максимум одобрения скорее харатерно для средне-маленьких по объёму аудитории каналов.
#
# ❓ а обсуждения и негатива больше у больших каналов или у маленьких?
#
# У реакций обсуждения и негатива нельзя выявить однозначной взаимосвязи с количеством подписчиков. Эти реакции бывают повышенными и на каналах с миллионной аудиторией, и на каналах с сотнями тысяч подписчиков. Скорее эти метрики зависят от конкретных видео и их содержания.
#
# ❓ какая тематика каналов имеет больше одобрения?
#
# Наибольшее одобрение имеют каналы с такими тематиками, как: новости/обзор прессы, литература, развлекательное обучение, каналы с разного толка политическим уклоном.
#
# ❓ что вызывает больше обсуждения и негатива - есть ли разница в тематике каналов?
#
# Да, разница есть. На данной выборке наибольшее обсуждение происходит на канале, посвящённому обзорам новой техники. А вот наибольший ажиотаж характерен для каналов, так или иначе затрагивающих обсуждение текущих событий и политики. Эти каналы имеют такие тематики, как: интервью, репортаж, новости, финансы, консервативно-религиозный взгляд.
#
# ❓ есть ли взаимосвязь с длительностью видео и реакцией на него аудитории?
#
# В целом такая взаимосвязь есть: часто аудитория реагирует одобрительно на видео с небольшой длиной. Максимум одобрения на данной выборке имеют видео с длиной от 12 до 45 минут. Но всё-таки длина видео - это не панацея (на многих каналах и короткие ролики не имеют высокого одобрения). Гораздо важнее сам контент.
#
# ❓ с годами реакции зрителей меняются?
#
# Да, с годами аудитория стала более увлечённой и тепло реагирующей. Вероятно, это связано с развитиием платформы, с появивщимся разнообразием каналов, и с тем, что разные каналы нашли свою лояльную аудиторию.
#
# ❓ можно ли выявить стандартную реакцию аудитории?
#
# Да, можно выявить наиболее частую реакцию и некоторые закономерности, что и будет картиной "стандартной" реакции.
#
# - **одобрение**: наиболее часто 0 до 10%, реже в промежутке от 10 до 20%
#
# - в среднем если метрика по каналу меньше 2% - это небольшое одобрение, если от 2 до 5% - среднее одобрение, выше 5% - высокое одобрение
#
#
# - **обсуждение**: наиболее часто от 0 до 5%
#
# - в среднем  если метрика по каналу меньше 0.2% - это небольшое обсуждение, если от 0.2 до 0.5% - среднее обсуждение, выше 0.5% - высокий уровень обсуждения
#
#
# - за **ажиотаж/негатив** мы принимаем значение метрики свыше 50% - это уже явное нарушение привычной воронки поведения пользователей, когда просмотры-лайки-комментарии значительно отличаются друг от друга.
#
# _________________________________________________________________________________________________________________
# Дата выполнения проекта: 15 мая 2023 года
#
# Исследование выполнила: аналитик данных Малахова Наталья
#
# Мой телеграм-канал: [Дневник аналитика](https://t.me/diary_musician_analyst "Дневник аналитика")
#
# Портфолио: [GitHub](https://github.com/Malakhova-Natalya "GitHub")
#
# Спасибо за внимание! 🤍
